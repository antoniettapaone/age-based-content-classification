# %% [markdown]
# # CODICE BERT INIZIALE SULL'ITALIANO E CON TEST SPLIT

# %% [markdown]
# CODICE BERT INIZIALE SULL'ITALIANO E CON TEST SPLIT

# %%
# !pip install accelerate -U
# !pip install transformers[torch] -U
# !pip install scikit-learn
# Out:
# Collecting accelerate
#   Downloading accelerate-0.29.3-py3-none-any.whl (297 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.6/297.6 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (24.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.2.1+cu121)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.20.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.4.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.13.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.10.0->accelerate)
#   Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (4.66.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, accelerate
# Successfully installed accelerate-0.29.3 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.1.105
# Requirement already satisfied: transformers[torch] in /usr/local/lib/python3.10/dist-packages (4.40.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (3.13.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (4.66.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2.2.1+cu121)
# Requirement already satisfied: accelerate>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.29.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.21.0->transformers[torch]) (5.9.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers[torch]) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers[torch]) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (3.1.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->transformers[torch]) (12.4.127)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->transformers[torch]) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->transformers[torch]) (1.3.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.25.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.4.0)

# %%
import os
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
from transformers import BertTokenizer, BertForSequenceClassification, Trainer, TrainingArguments
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

# Montaggio di Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Percorso della cartella dei dati su Google Drive
data_path = '/content/drive/My Drive/esperimento'
# Out:
# Mounted at /content/drive

# %%
# Tokenizer di BERT
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]

# %%
# Classe Dataset
class TextDataset(Dataset):
    def __init__(self, texts, labels, tokenizer):
        self.encodings = tokenizer(texts, truncation=True, padding=True, max_length=512)
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.labels)

# %%
# Funzione per calcolare le metriche
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    return {"accuracy": accuracy_score(labels, predictions)}

# %%
def load_data(data_path):
    texts, labels, titles = [], [], []
    label_dict = {'0_bambini': 0, '1_ragazzi': 1, '2_adulti': 2}
    for label, index in label_dict.items():
        folder_path = os.path.join(data_path, label)
        for filename in os.listdir(folder_path):
            with open(os.path.join(folder_path, filename), 'r', encoding='utf-8') as file:
                texts.append(file.read())
                labels.append(index)
                titles.append(filename)  # Salva il nome del file come titolo
    return texts, labels, titles

# %%
# Caricamento e divisione dei dati
texts, labels, titles = load_data(data_path)
train_texts, test_texts, train_labels, test_labels, train_titles, test_titles = train_test_split(texts, labels, titles, test_size=0.2, random_state=42)

# Creazione dei dataset
train_dataset = TextDataset(train_texts, train_labels, tokenizer)
test_dataset = TextDataset(test_texts, test_labels, tokenizer)

# %%
# Configurazione dei parametri di training
training_args = TrainingArguments(
    output_dir='./results',
    num_train_epochs=3,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=16,
    warmup_steps=500,
    weight_decay=0.01,
    logging_dir='./logs',
    logging_steps=10,
    evaluation_strategy="epoch",
    save_strategy="epoch",
    load_best_model_at_end=True
)

# %%
# Inizializzazione del modello e del trainer
model = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=3)
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=test_dataset,
    compute_metrics=compute_metrics
)
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# Training e valutazione del modello
trainer.train()
trainer.save_model("./best_model")  # Salva il modello con la migliore accuratezza
# Out:
#     <div>
#
#       <progress value='156' max='156' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [156/156 03:48, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.703100</td>
#       <td>0.709749</td>
#       <td>0.699029</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.675500</td>
#       <td>0.786750</td>
#       <td>0.708738</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.620500</td>
#       <td>0.590616</td>
#       <td>0.796117</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
# Valutazione manuale sui dati di test
predictions = trainer.predict(test_dataset)
predicted_labels = np.argmax(predictions.predictions, axis=1)

# %%
# Calcolo del classification report
target_names = ['0_bambini', '1_ragazzi', '2_adulti']
report = classification_report(test_labels, predicted_labels, target_names=target_names, output_dict=True)

# Stampa del classification report formattato
print("\t\tPrecision\tRecall\tF1-score\tSupport")
for class_name in target_names:
    class_report = report[class_name]
    print(f"{class_name}\t{class_report['precision']:.2f}\t\t{class_report['recall']:.2f}\t{class_report['f1-score']:.2f}\t\t{class_report['support']}")

print("\n\t\t\tSupport")
print(f"Accuracy\t\t{report['accuracy']:.2f}\t{len(test_labels)}")
print(f"Macro avg\t{report['macro avg']['precision']:.2f}\t\t{report['macro avg']['recall']:.2f}\t{report['macro avg']['f1-score']:.2f}\t\t{len(test_labels)}")
print(f"Weighted avg\t{report['weighted avg']['precision']:.2f}\t\t{report['weighted avg']['recall']:.2f}\t{report['weighted avg']['f1-score']:.2f}\t\t{len(test_labels)}")

# Funzione per la stampa degli errori usando il nome del file come titolo
def print_errors(titles, test_labels, predicted_labels, target_names, max_errors=10):
    print("\nErrori nei testi di test:")
    error_count = 0
    for i, (title, true_label, predicted_label) in enumerate(zip(titles, test_labels, predicted_labels)):
        if true_label != predicted_label:
            print(f"\nTitolo: {title}")
            print(f"Etichetta reale: {target_names[true_label]}")
            print(f"Etichetta predetta: {target_names[predicted_label]}")
            error_count += 1
            if error_count >= max_errors:
                break
    if error_count == 0:
        print("Nessun errore trovato.")

# Utilizza la funzione per la stampa degli errori
print_errors(test_titles, test_labels, predicted_labels, target_names)
# Out:
# 		Precision	Recall	F1-score	Support
# 0_bambini	0.87		0.87	0.87		46
# 1_ragazzi	0.62		0.83	0.71		35
# 2_adulti	0.60		0.27	0.37		22
#
# 			Support
# Accuracy		0.73	103
# Macro avg	0.70		0.66	0.65		103
# Weighted avg	0.73		0.73	0.71		103
#
# Errori nei testi di test:
#
# Titolo: ted2020-31.txt
# Etichetta reale: 1_ragazzi
# Etichetta predetta: 2_adulti
#
# Titolo: YTP_003.txt
# Etichetta reale: 2_adulti
# Etichetta predetta: 0_bambini
#
# Titolo: filmadulti46.txt
# Etichetta reale: 2_adulti
# Etichetta predetta: 0_bambini
#
# Titolo: filmadulti42.txt
# Etichetta reale: 2_adulti
# Etichetta predetta: 1_ragazzi
#
# Titolo: testo_ytkids_0031.txt
# Etichetta reale: 0_bambini
# Etichetta predetta: 1_ragazzi
#
# Titolo: ted2020-127.txt
# Etichetta reale: 1_ragazzi
# Etichetta predetta: 2_adulti
#
# Titolo: ted2020-101.txt
# Etichetta reale: 1_ragazzi
# Etichetta predetta: 2_adulti
#
# Titolo: testo_ytkids_N030.txt
# Etichetta reale: 1_ragazzi
# Etichetta predetta: 0_bambini
#
# Titolo: ted2020-183.txt
# Etichetta reale: 2_adulti
# Etichetta predetta: 1_ragazzi
#
# Titolo: ted2020-189.txt
# Etichetta reale: 2_adulti
# Etichetta predetta: 1_ragazzi

# %% [markdown]
# # mBERT

# %% [markdown]
# # Mbert eng uncased

# %%
import os
import numpy as np
import torch
from torch.utils.data import Dataset
from transformers import BertTokenizer, BertForSequenceClassification, Trainer, TrainingArguments
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, classification_report

# Montaggio di Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Percorso della cartella dei dati su Google Drive
data_path = '/content/drive/My Drive/Esperimento_eng'

# Tokenizer di mBERT
tokenizer = BertTokenizer.from_pretrained('bert-base-multilingual-uncased')

# Classe Dataset
class TextDataset(Dataset):
    def __init__(self, texts, labels, tokenizer):
        self.encodings = tokenizer(texts, truncation=True, padding=True, max_length=512)
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.labels)

# Funzione per calcolare le metriche
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    return {"accuracy": accuracy_score(labels, predictions)}

# Funzione per caricare i dati
def load_data(data_path):
    texts, labels, titles = [], [], []
    label_dict = {'0_bambini': 0, '1_ragazzi': 1, '2_adulti': 2}
    for label, index in label_dict.items():
        folder_path = os.path.join(data_path, label)
        for filename in os.listdir(folder_path):
            with open(os.path.join(folder_path, filename), 'r', encoding='utf-8') as file:
                texts.append(file.read())
                labels.append(index)
                titles.append(filename)  # Salva il nome del file come titolo
    return texts, labels, titles

# Caricamento dei dati
texts, labels, titles = load_data(data_path)

# Inizializza dizionari per raccogliere i risultati medi
precision_sum = {class_name: 0 for class_name in ['0_bambini', '1_ragazzi', '2_adulti']}
recall_sum = {class_name: 0 for class_name in ['0_bambini', '1_ragazzi', '2_adulti']}
f1_sum = {class_name: 0 for class_name in ['0_bambini', '1_ragazzi', '2_adulti']}
support_sum = {class_name: 0 for class_name in ['0_bambini', '1_ragazzi', '2_adulti']}

accuracy_per_fold = []
macro_avg_precision_sum, macro_avg_recall_sum, macro_avg_f1_sum = 0, 0, 0
weighted_avg_precision_sum, weighted_avg_recall_sum, weighted_avg_f1_sum = 0, 0, 0

fold = 1

# K-fold cross-validation
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

for train_index, test_index in kfold.split(texts):
    print(f'\nFold {fold}')
    fold += 1

    # Divisione in train e test per il fold corrente
    train_texts = [texts[i] for i in train_index]
    test_texts = [texts[i] for i in test_index]
    train_labels = [labels[i] for i in train_index]
    test_labels = [labels[i] for i in test_index]

    # Creazione dei dataset
    train_dataset = TextDataset(train_texts, train_labels, tokenizer)
    test_dataset = TextDataset(test_texts, test_labels, tokenizer)

    # Configurazione dei parametri di training
    training_args = TrainingArguments(
        output_dir='./results',
        num_train_epochs=3,
        per_device_train_batch_size=8,
        per_device_eval_batch_size=16,
        warmup_steps=500,
        weight_decay=0.01,
        logging_dir='./logs',
        logging_steps=10,
        evaluation_strategy="epoch",
        save_strategy="epoch",
        load_best_model_at_end=True
    )

    # Inizializzazione del modello e del trainer
    model = BertForSequenceClassification.from_pretrained('bert-base-multilingual-uncased', num_labels=3)

    trainer = Trainer(
        model=model,
        args=training_args,
        train_dataset=train_dataset,
        eval_dataset=test_dataset,
        compute_metrics=compute_metrics
    )

    # Training del modello
    trainer.train()

    # Valutazione sul test del fold corrente
    predictions = trainer.predict(test_dataset)
    predicted_labels = np.argmax(predictions.predictions, axis=1)

    # Calcolo del classification report
    target_names = ['0_bambini', '1_ragazzi', '2_adulti']
    report = classification_report(test_labels, predicted_labels, target_names=target_names, output_dict=True)

    # Stampa del classification report formattato
    print("\t\tPrecision\tRecall\tF1-score\tSupport")
    for class_name in target_names:
        class_report = report[class_name]
        print(f"{class_name}\t{class_report['precision']:.2f}\t\t{class_report['recall']:.2f}\t{class_report['f1-score']:.2f}\t\t{class_report['support']}")

    print("\n\t\t\tSupport")
    print(f"Accuracy\t\t{report['accuracy']:.2f}\t{len(test_labels)}")
    print(f"Macro avg\t{report['macro avg']['precision']:.2f}\t\t{report['macro avg']['recall']:.2f}\t{report['macro avg']['f1-score']:.2f}\t\t{len(test_labels)}")
    print(f"Weighted avg\t{report['weighted avg']['precision']:.2f}\t\t{report['weighted avg']['recall']:.2f}\t{report['weighted avg']['f1-score']:.2f}\t\t{len(test_labels)}")

    # Somma i valori di precision, recall, f1 e support per ogni classe
    for class_name in target_names:
        precision_sum[class_name] += report[class_name]['precision']
        recall_sum[class_name] += report[class_name]['recall']
        f1_sum[class_name] += report[class_name]['f1-score']
        support_sum[class_name] += report[class_name]['support']

    # Somma per macro avg e weighted avg
    macro_avg_precision_sum += report['macro avg']['precision']
    macro_avg_recall_sum += report['macro avg']['recall']
    macro_avg_f1_sum += report['macro avg']['f1-score']

    weighted_avg_precision_sum += report['weighted avg']['precision']
    weighted_avg_recall_sum += report['weighted avg']['recall']
    weighted_avg_f1_sum += report['weighted avg']['f1-score']

    # Aggiungi l'accuratezza alla lista per calcolare la media finale
    accuracy_per_fold.append(report['accuracy'])

# Media dei risultati per ogni classe
print("\nRisultati medi su 5 fold:")
print("\t\tPrecision\tRecall\tF1-score\tSupport")
for class_name in target_names:
    print(f"{class_name}\t{(precision_sum[class_name]/5):.2f}\t\t{(recall_sum[class_name]/5):.2f}\t{(f1_sum[class_name]/5):.2f}\t\t{support_sum[class_name]}")

# Media per Macro avg e Weighted avg
print(f"\nMacro avg\t{(macro_avg_precision_sum/5):.2f}\t\t{(macro_avg_recall_sum/5):.2f}\t{(macro_avg_f1_sum/5):.2f}")
print(f"Weighted avg\t{(weighted_avg_precision_sum/5):.2f}\t\t{(weighted_avg_recall_sum/5):.2f}\t{(weighted_avg_f1_sum/5):.2f}")

# Stampa dell'accuratezza media finale
print(f"\nAccuratezza media su 5 fold: {np.mean(accuracy_per_fold):.2f}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Fold 1
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='135' max='135' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [135/135 03:13, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.020300</td>
#       <td>0.953747</td>
#       <td>0.688889</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.542900</td>
#       <td>0.625416</td>
#       <td>0.700000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.354300</td>
#       <td>0.381404</td>
#       <td>0.866667</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	1.00		1.00	1.00		41.0
# 1_ragazzi	0.67		0.91	0.77		22.0
# 2_adulti	0.89		0.63	0.74		27.0
#
# 			Support
# Accuracy		0.87	90
# Macro avg	0.85		0.85	0.84		90
# Weighted avg	0.89		0.87	0.87		90
#
# Fold 2
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='135' max='135' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [135/135 03:18, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.006500</td>
#       <td>0.921059</td>
#       <td>0.674157</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.604000</td>
#       <td>0.564635</td>
#       <td>0.775281</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.456500</td>
#       <td>0.334179</td>
#       <td>0.842697</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	1.00		1.00	1.00		44.0
# 1_ragazzi	0.66		0.96	0.78		26.0
# 2_adulti	0.86		0.32	0.46		19.0
#
# 			Support
# Accuracy		0.84	89
# Macro avg	0.84		0.76	0.75		89
# Weighted avg	0.87		0.84	0.82		89
#
# Fold 3
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='135' max='135' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [135/135 03:12, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.011100</td>
#       <td>0.935264</td>
#       <td>0.730337</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.612600</td>
#       <td>0.560142</td>
#       <td>0.797753</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.421300</td>
#       <td>0.365058</td>
#       <td>0.853933</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	1.00		1.00	1.00		38.0
# 1_ragazzi	0.71		1.00	0.83		32.0
# 2_adulti	1.00		0.32	0.48		19.0
#
# 			Support
# Accuracy		0.85	89
# Macro avg	0.90		0.77	0.77		89
# Weighted avg	0.90		0.85	0.83		89
#
# Fold 4
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='135' max='135' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [135/135 03:01, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.012200</td>
#       <td>0.935950</td>
#       <td>0.775281</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.579800</td>
#       <td>0.554301</td>
#       <td>0.820225</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.435800</td>
#       <td>0.328288</td>
#       <td>0.876404</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	1.00		1.00	1.00		40.0
# 1_ragazzi	0.75		1.00	0.86		33.0
# 2_adulti	1.00		0.31	0.48		16.0
#
# 			Support
# Accuracy		0.88	89
# Macro avg	0.92		0.77	0.78		89
# Weighted avg	0.91		0.88	0.85		89
#
# Fold 5
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='135' max='135' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [135/135 03:18, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.015700</td>
#       <td>0.927953</td>
#       <td>0.775281</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.586500</td>
#       <td>0.540399</td>
#       <td>0.786517</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.453400</td>
#       <td>0.320242</td>
#       <td>0.932584</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	1.00		1.00	1.00		37.0
# 1_ragazzi	0.85		1.00	0.92		33.0
# 2_adulti	1.00		0.68	0.81		19.0
#
# 			Support
# Accuracy		0.93	89
# Macro avg	0.95		0.89	0.91		89
# Weighted avg	0.94		0.93	0.93		89
#
# Risultati medi su 5 fold:
# 		Precision	Recall	F1-score	Support
# 0_bambini	1.00		1.00	1.00		200.0
# 1_ragazzi	0.73		0.97	0.83		146.0
# 2_adulti	0.95		0.45	0.59		100.0
#
# Macro avg	0.89		0.81	0.81
# Weighted avg	0.90		0.87	0.86
#
# Accuratezza media su 5 fold: 0.87

# %% [markdown]
# # mBERT ita uncased

# %%
import os
import numpy as np
import torch
from torch.utils.data import Dataset
from transformers import BertTokenizer, BertForSequenceClassification, Trainer, TrainingArguments
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, classification_report

# Montaggio di Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Percorso della cartella dei dati su Google Drive
data_path = '/content/drive/My Drive/esperimento'

# Tokenizer di mBERT
tokenizer = BertTokenizer.from_pretrained('bert-base-multilingual-uncased')

# Classe Dataset
class TextDataset(Dataset):
    def __init__(self, texts, labels, tokenizer):
        self.encodings = tokenizer(texts, truncation=True, padding=True, max_length=512)
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.labels)

# Funzione per calcolare le metriche
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    return {"accuracy": accuracy_score(labels, predictions)}

# Funzione per caricare i dati
def load_data(data_path):
    texts, labels, titles = [], [], []
    label_dict = {'0_bambini': 0, '1_ragazzi': 1, '2_adulti': 2}
    for label, index in label_dict.items():
        folder_path = os.path.join(data_path, label)
        for filename in os.listdir(folder_path):
            with open(os.path.join(folder_path, filename), 'r', encoding='utf-8') as file:
                texts.append(file.read())
                labels.append(index)
                titles.append(filename)  # Salva il nome del file come titolo
    return texts, labels, titles

# Caricamento dei dati
texts, labels, titles = load_data(data_path)

# Inizializza dizionari per raccogliere i risultati medi
precision_sum = {class_name: 0 for class_name in ['0_bambini', '1_ragazzi', '2_adulti']}
recall_sum = {class_name: 0 for class_name in ['0_bambini', '1_ragazzi', '2_adulti']}
f1_sum = {class_name: 0 for class_name in ['0_bambini', '1_ragazzi', '2_adulti']}
support_sum = {class_name: 0 for class_name in ['0_bambini', '1_ragazzi', '2_adulti']}

accuracy_per_fold = []
macro_avg_precision_sum, macro_avg_recall_sum, macro_avg_f1_sum = 0, 0, 0
weighted_avg_precision_sum, weighted_avg_recall_sum, weighted_avg_f1_sum = 0, 0, 0

fold = 1

# K-fold cross-validation
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

for train_index, test_index in kfold.split(texts):
    print(f'\nFold {fold}')
    fold += 1

    # Divisione in train e test per il fold corrente
    train_texts = [texts[i] for i in train_index]
    test_texts = [texts[i] for i in test_index]
    train_labels = [labels[i] for i in train_index]
    test_labels = [labels[i] for i in test_index]

    # Creazione dei dataset
    train_dataset = TextDataset(train_texts, train_labels, tokenizer)
    test_dataset = TextDataset(test_texts, test_labels, tokenizer)

    # Configurazione dei parametri di training
    training_args = TrainingArguments(
        output_dir='./results',
        num_train_epochs=3,
        per_device_train_batch_size=8,
        per_device_eval_batch_size=16,
        warmup_steps=500,
        weight_decay=0.01,
        logging_dir='./logs',
        logging_steps=10,
        evaluation_strategy="epoch",
        save_strategy="epoch",
        load_best_model_at_end=True
    )

    # Inizializzazione del modello e del trainer
    model = BertForSequenceClassification.from_pretrained('bert-base-multilingual-uncased', num_labels=3)

    trainer = Trainer(
        model=model,
        args=training_args,
        train_dataset=train_dataset,
        eval_dataset=test_dataset,
        compute_metrics=compute_metrics
    )

    # Training del modello
    trainer.train()

    # Valutazione sul test del fold corrente
    predictions = trainer.predict(test_dataset)
    predicted_labels = np.argmax(predictions.predictions, axis=1)

    # Calcolo del classification report
    target_names = ['0_bambini', '1_ragazzi', '2_adulti']
    report = classification_report(test_labels, predicted_labels, target_names=target_names, output_dict=True)

    # Stampa del classification report formattato
    print("\t\tPrecision\tRecall\tF1-score\tSupport")
    for class_name in target_names:
        class_report = report[class_name]
        print(f"{class_name}\t{class_report['precision']:.2f}\t\t{class_report['recall']:.2f}\t{class_report['f1-score']:.2f}\t\t{class_report['support']}")

    print("\n\t\t\tSupport")
    print(f"Accuracy\t\t{report['accuracy']:.2f}\t{len(test_labels)}")
    print(f"Macro avg\t{report['macro avg']['precision']:.2f}\t\t{report['macro avg']['recall']:.2f}\t{report['macro avg']['f1-score']:.2f}\t\t{len(test_labels)}")
    print(f"Weighted avg\t{report['weighted avg']['precision']:.2f}\t\t{report['weighted avg']['recall']:.2f}\t{report['weighted avg']['f1-score']:.2f}\t\t{len(test_labels)}")

    # Somma i valori di precision, recall, f1 e support per ogni classe
    for class_name in target_names:
        precision_sum[class_name] += report[class_name]['precision']
        recall_sum[class_name] += report[class_name]['recall']
        f1_sum[class_name] += report[class_name]['f1-score']
        support_sum[class_name] += report[class_name]['support']

    # Somma per macro avg e weighted avg
    macro_avg_precision_sum += report['macro avg']['precision']
    macro_avg_recall_sum += report['macro avg']['recall']
    macro_avg_f1_sum += report['macro avg']['f1-score']

    weighted_avg_precision_sum += report['weighted avg']['precision']
    weighted_avg_recall_sum += report['weighted avg']['recall']
    weighted_avg_f1_sum += report['weighted avg']['f1-score']

    # Aggiungi l'accuratezza alla lista per calcolare la media finale
    accuracy_per_fold.append(report['accuracy'])

# Media dei risultati per ogni classe
print("\nRisultati medi su 5 fold:")
print("\t\tPrecision\tRecall\tF1-score\tSupport")
for class_name in target_names:
    print(f"{class_name}\t{(precision_sum[class_name]/5):.2f}\t\t{(recall_sum[class_name]/5):.2f}\t{(f1_sum[class_name]/5):.2f}\t\t{support_sum[class_name]}")

# Media per Macro avg e Weighted avg
print(f"\nMacro avg\t{(macro_avg_precision_sum/5):.2f}\t\t{(macro_avg_recall_sum/5):.2f}\t{(macro_avg_f1_sum/5):.2f}")
print(f"Weighted avg\t{(weighted_avg_precision_sum/5):.2f}\t\t{(weighted_avg_recall_sum/5):.2f}\t{(weighted_avg_f1_sum/5):.2f}")

# Stampa dell'accuratezza media finale
print(f"\nAccuratezza media su 5 fold: {np.mean(accuracy_per_fold):.2f}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Fold 1
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='156' max='156' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [156/156 03:22, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.072000</td>
#       <td>0.999552</td>
#       <td>0.679612</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.829000</td>
#       <td>0.670833</td>
#       <td>0.747573</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.541900</td>
#       <td>0.579848</td>
#       <td>0.786408</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	0.87		0.89	0.88		46.0
# 1_ragazzi	0.74		0.83	0.78		35.0
# 2_adulti	0.65		0.50	0.56		22.0
#
# 			Support
# Accuracy		0.79	103
# Macro avg	0.75		0.74	0.74		103
# Weighted avg	0.78		0.79	0.78		103
#
# Fold 2
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='156' max='156' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [156/156 03:24, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.060100</td>
#       <td>1.016044</td>
#       <td>0.640777</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.748900</td>
#       <td>0.716790</td>
#       <td>0.718447</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.551000</td>
#       <td>0.760797</td>
#       <td>0.708738</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	0.74		0.98	0.84		44.0
# 1_ragazzi	0.66		0.74	0.70		31.0
# 2_adulti	0.80		0.29	0.42		28.0
#
# 			Support
# Accuracy		0.72	103
# Macro avg	0.73		0.67	0.65		103
# Weighted avg	0.73		0.72	0.68		103
#
# Fold 3
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='156' max='156' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [156/156 03:21, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.061400</td>
#       <td>1.014441</td>
#       <td>0.621359</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.745400</td>
#       <td>0.826793</td>
#       <td>0.631068</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.597400</td>
#       <td>0.852416</td>
#       <td>0.631068</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	0.62		0.89	0.73		37.0
# 1_ragazzi	0.64		0.72	0.67		39.0
# 2_adulti	0.67		0.15	0.24		27.0
#
# 			Support
# Accuracy		0.63	103
# Macro avg	0.64		0.59	0.55		103
# Weighted avg	0.64		0.63	0.58		103
#
# Fold 4
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='156' max='156' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [156/156 03:33, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.066400</td>
#       <td>1.015423</td>
#       <td>0.660194</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.806000</td>
#       <td>0.745242</td>
#       <td>0.737864</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.467200</td>
#       <td>0.657697</td>
#       <td>0.747573</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	0.85		0.79	0.82		43.0
# 1_ragazzi	0.63		0.94	0.76		36.0
# 2_adulti	1.00		0.38	0.55		24.0
#
# 			Support
# Accuracy		0.75	103
# Macro avg	0.83		0.70	0.71		103
# Weighted avg	0.81		0.75	0.73		103
#
# Fold 5
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='156' max='156' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [156/156 03:22, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.039100</td>
#       <td>0.991283</td>
#       <td>0.666667</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.776600</td>
#       <td>0.739408</td>
#       <td>0.686275</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.567800</td>
#       <td>0.639844</td>
#       <td>0.735294</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	0.74		0.95	0.83		39.0
# 1_ragazzi	0.71		0.76	0.73		38.0
# 2_adulti	0.82		0.36	0.50		25.0
#
# 			Support
# Accuracy		0.74	102
# Macro avg	0.76		0.69	0.69		102
# Weighted avg	0.75		0.74	0.71		102
#
# Risultati medi su 5 fold:
# 		Precision	Recall	F1-score	Support
# 0_bambini	0.77		0.90	0.82		209.0
# 1_ragazzi	0.67		0.80	0.73		179.0
# 2_adulti	0.79		0.33	0.45		126.0
#
# Macro avg	0.74		0.68	0.67
# Weighted avg	0.74		0.72	0.70
#
# Accuratezza media su 5 fold: 0.72

# %% [markdown]
# # mbert cased ita

# %%
import os
import numpy as np
import torch
from torch.utils.data import Dataset
from transformers import BertTokenizer, BertForSequenceClassification, Trainer, TrainingArguments
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, classification_report

# Montaggio di Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Percorso della cartella dei dati su Google Drive
data_path = '/content/drive/My Drive/esperimento'

# Tokenizer di mBERT (cased)
tokenizer = BertTokenizer.from_pretrained('bert-base-multilingual-cased')

# Classe Dataset
class TextDataset(Dataset):
    def __init__(self, texts, labels, tokenizer):
        self.encodings = tokenizer(texts, truncation=True, padding=True, max_length=512)
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.labels)

# Funzione per calcolare le metriche
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    return {"accuracy": accuracy_score(labels, predictions)}

# Funzione per caricare i dati
def load_data(data_path):
    texts, labels, titles = [], [], []
    label_dict = {'0_bambini': 0, '1_ragazzi': 1, '2_adulti': 2}
    for label, index in label_dict.items():
        folder_path = os.path.join(data_path, label)
        for filename in os.listdir(folder_path):
            with open(os.path.join(folder_path, filename), 'r', encoding='utf-8') as file:
                texts.append(file.read())
                labels.append(index)
                titles.append(filename)  # Salva il nome del file come titolo
    return texts, labels, titles

# Caricamento dei dati
texts, labels, titles = load_data(data_path)

# Inizializza dizionari per raccogliere i risultati medi
precision_sum = {class_name: 0 for class_name in ['0_bambini', '1_ragazzi', '2_adulti']}
recall_sum = {class_name: 0 for class_name in ['0_bambini', '1_ragazzi', '2_adulti']}
f1_sum = {class_name: 0 for class_name in ['0_bambini', '1_ragazzi', '2_adulti']}
support_sum = {class_name: 0 for class_name in ['0_bambini', '1_ragazzi', '2_adulti']}

accuracy_per_fold = []
macro_avg_precision_sum, macro_avg_recall_sum, macro_avg_f1_sum = 0, 0, 0
weighted_avg_precision_sum, weighted_avg_recall_sum, weighted_avg_f1_sum = 0, 0, 0

fold = 1

# K-fold cross-validation
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

for train_index, test_index in kfold.split(texts):
    print(f'\nFold {fold}')
    fold += 1

    # Divisione in train e test per il fold corrente
    train_texts = [texts[i] for i in train_index]
    test_texts = [texts[i] for i in test_index]
    train_labels = [labels[i] for i in train_index]
    test_labels = [labels[i] for i in test_index]

    # Creazione dei dataset
    train_dataset = TextDataset(train_texts, train_labels, tokenizer)
    test_dataset = TextDataset(test_texts, test_labels, tokenizer)

    # Configurazione dei parametri di training
    training_args = TrainingArguments(
        output_dir='./results',
        num_train_epochs=3,
        per_device_train_batch_size=8,
        per_device_eval_batch_size=16,
        warmup_steps=500,
        weight_decay=0.01,
        logging_dir='./logs',
        logging_steps=10,
        evaluation_strategy="epoch",
        save_strategy="epoch",
        load_best_model_at_end=True
    )

    # Inizializzazione del modello e del trainer
    model = BertForSequenceClassification.from_pretrained('bert-base-multilingual-cased', num_labels=3)

    trainer = Trainer(
        model=model,
        args=training_args,
        train_dataset=train_dataset,
        eval_dataset=test_dataset,
        compute_metrics=compute_metrics
    )

    # Training del modello
    trainer.train()

    # Valutazione sul test del fold corrente
    predictions = trainer.predict(test_dataset)
    predicted_labels = np.argmax(predictions.predictions, axis=1)

    # Calcolo del classification report
    target_names = ['0_bambini', '1_ragazzi', '2_adulti']
    report = classification_report(test_labels, predicted_labels, target_names=target_names, output_dict=True)

    # Stampa del classification report formattato
    print("\t\tPrecision\tRecall\tF1-score\tSupport")
    for class_name in target_names:
        class_report = report[class_name]
        print(f"{class_name}\t{class_report['precision']:.2f}\t\t{class_report['recall']:.2f}\t{class_report['f1-score']:.2f}\t\t{class_report['support']}")

    print("\n\t\t\tSupport")
    print(f"Accuracy\t\t{report['accuracy']:.2f}\t{len(test_labels)}")
    print(f"Macro avg\t{report['macro avg']['precision']:.2f}\t\t{report['macro avg']['recall']:.2f}\t{report['macro avg']['f1-score']:.2f}\t\t{len(test_labels)}")
    print(f"Weighted avg\t{report['weighted avg']['precision']:.2f}\t\t{report['weighted avg']['recall']:.2f}\t{report['weighted avg']['f1-score']:.2f}\t\t{len(test_labels)}")

    # Somma i valori di precision, recall, f1 e support per ogni classe
    for class_name in target_names:
        precision_sum[class_name] += report[class_name]['precision']
        recall_sum[class_name] += report[class_name]['recall']
        f1_sum[class_name] += report[class_name]['f1-score']
        support_sum[class_name] += report[class_name]['support']

    # Somma per macro avg e weighted avg
    macro_avg_precision_sum += report['macro avg']['precision']
    macro_avg_recall_sum += report['macro avg']['recall']
    macro_avg_f1_sum += report['macro avg']['f1-score']

    weighted_avg_precision_sum += report['weighted avg']['precision']
    weighted_avg_recall_sum += report['weighted avg']['recall']
    weighted_avg_f1_sum += report['weighted avg']['f1-score']

    # Aggiungi l'accuratezza alla lista per calcolare la media finale
    accuracy_per_fold.append(report['accuracy'])

# Media dei risultati per ogni classe
print("\nRisultati medi su 5 fold:")
print("\t\tPrecision\tRecall\tF1-score\tSupport")
for class_name in target_names:
    print(f"{class_name}\t{(precision_sum[class_name]/5):.2f}\t\t{(recall_sum[class_name]/5):.2f}\t{(f1_sum[class_name]/5):.2f}\t\t{support_sum[class_name]}")

# Media per Macro avg e Weighted avg
print(f"\nMacro avg\t{(macro_avg_precision_sum/5):.2f}\t\t{(macro_avg_recall_sum/5):.2f}\t{(macro_avg_f1_sum/5):.2f}")
print(f"Weighted avg\t{(weighted_avg_precision_sum/5):.2f}\t\t{(weighted_avg_recall_sum/5):.2f}\t{(weighted_avg_f1_sum/5):.2f}")

# Stampa dell'accuratezza media finale
print(f"\nAccuratezza media su 5 fold: {np.mean(accuracy_per_fold):.2f}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Fold 1
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='156' max='156' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [156/156 02:36, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.990500</td>
#       <td>0.962189</td>
#       <td>0.601942</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.836200</td>
#       <td>0.794913</td>
#       <td>0.699029</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.706700</td>
#       <td>0.953738</td>
#       <td>0.572816</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 		Precision	Recall	F1-score	Support
# 0_bambini	0.68		0.93	0.79		46.0
# 1_ragazzi	0.72		0.83	0.77		35.0
# 2_adulti	0.00		0.00	0.00		22.0
#
# 			Support
# Accuracy		0.70	103
# Macro avg	0.47		0.59	0.52		103
# Weighted avg	0.55		0.70	0.62		103
#
# Fold 2
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='156' max='156' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [156/156 02:34, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.013000</td>
#       <td>0.990306</td>
#       <td>0.563107</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.778700</td>
#       <td>0.702587</td>
#       <td>0.689320</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.725200</td>
#       <td>0.667515</td>
#       <td>0.669903</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 		Precision	Recall	F1-score	Support
# 0_bambini	0.91		0.89	0.90		44.0
# 1_ragazzi	0.50		0.97	0.66		31.0
# 2_adulti	0.00		0.00	0.00		28.0
#
# 			Support
# Accuracy		0.67	103
# Macro avg	0.47		0.62	0.52		103
# Weighted avg	0.54		0.67	0.58		103
#
# Fold 3
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='156' max='156' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [156/156 02:34, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.986200</td>
#       <td>0.999379</td>
#       <td>0.427184</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.740200</td>
#       <td>0.813439</td>
#       <td>0.679612</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.635900</td>
#       <td>0.730358</td>
#       <td>0.699029</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	0.85		0.89	0.87		37.0
# 1_ragazzi	0.64		0.72	0.67		39.0
# 2_adulti	0.55		0.41	0.47		27.0
#
# 			Support
# Accuracy		0.70	103
# Macro avg	0.68		0.67	0.67		103
# Weighted avg	0.69		0.70	0.69		103
#
# Fold 4
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='156' max='156' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [156/156 02:36, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.007800</td>
#       <td>1.016464</td>
#       <td>0.417476</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.809700</td>
#       <td>0.782928</td>
#       <td>0.699029</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.542400</td>
#       <td>0.728135</td>
#       <td>0.699029</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	0.75		0.95	0.84		43.0
# 1_ragazzi	0.65		0.61	0.63		36.0
# 2_adulti	0.64		0.38	0.47		24.0
#
# 			Support
# Accuracy		0.70	103
# Macro avg	0.68		0.65	0.65		103
# Weighted avg	0.69		0.70	0.68		103
#
# Fold 5
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='156' max='156' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [156/156 02:35, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.018600</td>
#       <td>0.938617</td>
#       <td>0.637255</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.788000</td>
#       <td>0.701932</td>
#       <td>0.735294</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.683100</td>
#       <td>0.787005</td>
#       <td>0.598039</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	0.72		0.87	0.79		39.0
# 1_ragazzi	0.71		0.89	0.79		38.0
# 2_adulti	1.00		0.28	0.44		25.0
#
# 			Support
# Accuracy		0.74	102
# Macro avg	0.81		0.68	0.67		102
# Weighted avg	0.79		0.74	0.70		102
#
# Risultati medi su 5 fold:
# 		Precision	Recall	F1-score	Support
# 0_bambini	0.78		0.91	0.84		209.0
# 1_ragazzi	0.64		0.80	0.71		179.0
# 2_adulti	0.44		0.21	0.28		126.0
#
# Macro avg	0.62		0.64	0.61
# Weighted avg	0.65		0.70	0.65
#
# Accuratezza media su 5 fold: 0.70

# %% [markdown]
# # mbert cased ita badwords

# %%
import os
import numpy as np
import torch
from torch.utils.data import Dataset
from transformers import BertTokenizer, BertForSequenceClassification, Trainer, TrainingArguments
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, classification_report
from nltk.tokenize import word_tokenize
import nltk

# Montaggio di Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Scarica risorse di NLTK per la tokenizzazione
nltk.download('punkt')

# Percorso della cartella dei dati su Google Drive
data_path = '/content/drive/My Drive/esperimento'

# Caricamento delle bad words in italiano
bad_words_path = '/content/drive/My Drive/bad_words.txt'

try:
    with open(bad_words_path, 'r', encoding='utf-8') as file:
        bad_words = set(line.strip() for line in file)
except Exception as e:
    print(f"Error loading bad words: {e}")

# Funzione per rilevare bad words
def detect_bad_words(text, bad_words):
    words = set(word_tokenize(text.lower()))  # Tokenizza e abbassa il testo
    return words.intersection(bad_words)

# Tokenizer di mBERT (cased)
tokenizer = BertTokenizer.from_pretrained('bert-base-multilingual-cased')

# Classe Dataset
class TextDataset(Dataset):
    def __init__(self, texts, labels, tokenizer):
        self.encodings = tokenizer(texts, truncation=True, padding=True, max_length=512)
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.labels)

# Funzione per calcolare le metriche
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    return {"accuracy": accuracy_score(labels, predictions)}

# Funzione per caricare i dati
def load_data(data_path):
    texts, labels, titles = [], [], []
    label_dict = {'0_bambini': 0, '1_ragazzi': 1, '2_adulti': 2}
    for label, index in label_dict.items():
        folder_path = os.path.join(data_path, label)
        for filename in os.listdir(folder_path):
            with open(os.path.join(folder_path, filename), 'r', encoding='utf-8') as file:
                texts.append(file.read())
                labels.append(index)
                titles.append(filename)  # Salva il nome del file come titolo
    return texts, labels, titles

# Caricamento dei dati
texts, labels, titles = load_data(data_path)

# Inizializza dizionari per raccogliere i risultati medi
precision_sum = {class_name: 0 for class_name in ['0_bambini', '1_ragazzi', '2_adulti']}
recall_sum = {class_name: 0 for class_name in ['0_bambini', '1_ragazzi', '2_adulti']}
f1_sum = {class_name: 0 for class_name in ['0_bambini', '1_ragazzi', '2_adulti']}
support_sum = {class_name: 0 for class_name in ['0_bambini', '1_ragazzi', '2_adulti']}

accuracy_per_fold = []
macro_avg_precision_sum, macro_avg_recall_sum, macro_avg_f1_sum = 0, 0, 0
weighted_avg_precision_sum, weighted_avg_recall_sum, weighted_avg_f1_sum = 0, 0, 0

# Lista per memorizzare i testi in cui l'etichetta è cambiata
texts_with_label_changes = []

fold = 1

# K-fold cross-validation
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

for train_index, test_index in kfold.split(texts):
    print(f'\nFold {fold}')
    fold += 1

    # Divisione in train e test per il fold corrente
    train_texts = [texts[i] for i in train_index]
    test_texts = [texts[i] for i in test_index]
    train_labels = [labels[i] for i in train_index]
    test_labels = [labels[i] for i in test_index]

    # Creazione dei dataset
    train_dataset = TextDataset(train_texts, train_labels, tokenizer)
    test_dataset = TextDataset(test_texts, test_labels, tokenizer)

    # Configurazione dei parametri di training
    training_args = TrainingArguments(
        output_dir='./results',
        num_train_epochs=3,
        per_device_train_batch_size=8,
        per_device_eval_batch_size=16,
        warmup_steps=500,
        weight_decay=0.01,
        logging_dir='./logs',
        logging_steps=10,
        evaluation_strategy="epoch",
        save_strategy="epoch",
        load_best_model_at_end=True
    )

    # Inizializzazione del modello e del trainer
    model = BertForSequenceClassification.from_pretrained('bert-base-multilingual-cased', num_labels=3)

    trainer = Trainer(
        model=model,
        args=training_args,
        train_dataset=train_dataset,
        eval_dataset=test_dataset,
        compute_metrics=compute_metrics
    )

    # Training del modello
    trainer.train()

    # Valutazione sul test del fold corrente
    predictions = trainer.predict(test_dataset)
    predicted_labels = np.argmax(predictions.predictions, axis=1)

    # Aggiungi il controllo delle bad words
    adjusted_labels = []
    detected_bad_words_list = []

    for i, text in enumerate(test_texts):
        detected_bad_words = detect_bad_words(text, bad_words)
        original_label = predicted_labels[i]
        if original_label == 0 and detected_bad_words:
            adjusted_labels.append(2)  # Cambia l'etichetta in "adulti"
            detected_bad_words_list.append((titles[test_index[i]], detected_bad_words))
            # Memorizza i testi modificati
            texts_with_label_changes.append({
                "Title": titles[test_index[i]],
                "Original Text": text,
                "Detected Bad Words": list(detected_bad_words),
                "Original Label": original_label,  # Etichetta originale (0 = bambini)
                "New Label": 2  # Nuova etichetta (2 = adulti)
            })
        else:
            adjusted_labels.append(original_label)

    # Calcolo del classification report
    target_names = ['0_bambini', '1_ragazzi', '2_adulti']
    report = classification_report(test_labels, adjusted_labels, target_names=target_names, output_dict=True)

    # Stampa del classification report formattato
    print("\t\tPrecision\tRecall\tF1-score\tSupport")
    for class_name in target_names:
        class_report = report[class_name]
        print(f"{class_name}\t{class_report['precision']:.2f}\t\t{class_report['recall']:.2f}\t{class_report['f1-score']:.2f}\t\t{class_report['support']}")

    print("\n\t\t\tSupport")
    print(f"Accuracy\t\t{report['accuracy']:.2f}\t{len(test_labels)}")
    print(f"Macro avg\t{report['macro avg']['precision']:.2f}\t\t{report['macro avg']['recall']:.2f}\t{report['macro avg']['f1-score']:.2f}\t\t{len(test_labels)}")
    print(f"Weighted avg\t{report['weighted avg']['precision']:.2f}\t\t{report['weighted avg']['recall']:.2f}\t{report['weighted avg']['f1-score']:.2f}\t\t{len(test_labels)}")

    # Somma i valori di precision, recall, f1 e support per ogni classe
    for class_name in target_names:
        precision_sum[class_name] += report[class_name]['precision']
        recall_sum[class_name] += report[class_name]['recall']
        f1_sum[class_name] += report[class_name]['f1-score']
        support_sum[class_name] += report[class_name]['support']

    # Somma per macro avg e weighted avg
    macro_avg_precision_sum += report['macro avg']['precision']
    macro_avg_recall_sum += report['macro avg']['recall']
    macro_avg_f1_sum += report['macro avg']['f1-score']

    weighted_avg_precision_sum += report['weighted avg']['precision']
    weighted_avg_recall_sum += report['weighted avg']['recall']
    weighted_avg_f1_sum += report['weighted avg']['f1-score']

    # Aggiungi l'accuratezza alla lista per calcolare la media finale
    accuracy_per_fold.append(report['accuracy'])

    # Stampa i testi in cui sono state rilevate bad words
    if detected_bad_words_list:
        print(f"Bad words rilevate nel fold {fold - 1}:")
        for title, bad_words in detected_bad_words_list:
            print(f"Titolo: {title}, Bad words: {bad_words}")

# Media dei risultati per ogni classe
print("\nRisultati medi su 5 fold:")
print("\t\tPrecision\tRecall\tF1-score\tSupport")
for class_name in target_names:
    print(f"{class_name}\t{(precision_sum[class_name]/5):.2f}\t\t{(recall_sum[class_name]/5):.2f}\t{(f1_sum[class_name]/5):.2f}\t\t{support_sum[class_name]}")

# Media per Macro avg e Weighted avg
print(f"\nMacro avg\t{(macro_avg_precision_sum/5):.2f}\t\t{(macro_avg_recall_sum/5):.2f}\t{(macro_avg_f1_sum/5):.2f}")
print(f"Weighted avg\t{(weighted_avg_precision_sum/5):.2f}\t\t{(weighted_avg_recall_sum/5):.2f}\t{(weighted_avg_f1_sum/5):.2f}")

# Stampa dell'accuratezza media finale
print(f"\nAccuratezza media su 5 fold: {np.mean(accuracy_per_fold):.2f}")

# Stampa dei testi in cui l'etichetta è stata cambiata a causa delle bad words
if texts_with_label_changes:
    print(f"\nTesti con cambiamento di etichetta a causa di bad words ({len(texts_with_label_changes)} testi):")
    for item in texts_with_label_changes:
        print(f"Titolo: {item['Title']}")
        print(f"Testo originale: {item['Original Text']}")
        print(f"Parole inappropriate rilevate: {', '.join(item['Detected Bad Words'])}")
        print(f"Etichetta originale: {item['Original Label']}, Nuova etichetta: {item['New Label']}")
        print("-" * 80)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Fold 1
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='156' max='156' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [156/156 02:36, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.990500</td>
#       <td>0.962189</td>
#       <td>0.601942</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.836200</td>
#       <td>0.794913</td>
#       <td>0.699029</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.706700</td>
#       <td>0.953738</td>
#       <td>0.572816</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	0.83		0.93	0.88		46.0
# 1_ragazzi	0.72		0.83	0.77		35.0
# 2_adulti	1.00		0.50	0.67		22.0
#
# 			Support
# Accuracy		0.81	103
# Macro avg	0.85		0.75	0.77		103
# Weighted avg	0.83		0.81	0.80		103
# Bad words rilevate nel fold 1:
# Titolo: YTP_003.txt, Bad words: {'cazzata', 'cazzetto', 'troia', 'piscio'}
# Titolo: YTP_012.txt, Bad words: {'cazzo', 'cazzi', 'bastardo'}
# Titolo: YTP_015.txt, Bad words: {'cazzo', 'minchia', 'bastardo', 'scopata'}
# Titolo: YTP_019.txt, Bad words: {'affanculo', 'cazzo', 'culo'}
# Titolo: filmadulti12.txt, Bad words: {'tette', 'fanculo'}
# Titolo: filmadulti16.txt, Bad words: {'cazzo', 'fottuto'}
# Titolo: filmadulti25.txt, Bad words: {'cazzo', 'fottuto', 'fanculo', 'minchia', 'idiota'}
# Titolo: filmadulti27.txt, Bad words: {'stronzetta', 'cazzo', 'fottuto'}
# Titolo: filmadulti46.txt, Bad words: {'puttana', 'negro'}
# Titolo: filmadulti41.txt, Bad words: {'puttana', 'culo'}
# Titolo: filmadulti42.txt, Bad words: {'stronzo', 'merda', 'idiota'}
#
# Fold 2
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='156' max='156' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [156/156 02:35, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.013000</td>
#       <td>0.990306</td>
#       <td>0.563107</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.778700</td>
#       <td>0.702587</td>
#       <td>0.689320</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.725200</td>
#       <td>0.667515</td>
#       <td>0.669903</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	0.95		0.89	0.92		44.0
# 1_ragazzi	0.50		0.97	0.66		31.0
# 2_adulti	1.00		0.07	0.13		28.0
#
# 			Support
# Accuracy		0.69	103
# Macro avg	0.82		0.64	0.57		103
# Weighted avg	0.83		0.69	0.63		103
# Bad words rilevate nel fold 2:
# Titolo: YTP_013.txt, Bad words: {'merda'}
# Titolo: YTP_017.txt, Bad words: {'merda'}
#
# Fold 3
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='156' max='156' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [156/156 02:37, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.986200</td>
#       <td>0.999379</td>
#       <td>0.427184</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.740200</td>
#       <td>0.813439</td>
#       <td>0.679612</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.635900</td>
#       <td>0.730358</td>
#       <td>0.699029</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	0.87		0.89	0.88		37.0
# 1_ragazzi	0.64		0.72	0.67		39.0
# 2_adulti	0.57		0.44	0.50		27.0
#
# 			Support
# Accuracy		0.71	103
# Macro avg	0.69		0.68	0.68		103
# Weighted avg	0.70		0.71	0.70		103
# Bad words rilevate nel fold 3:
# Titolo: YTP_004.txt, Bad words: {'merda'}
#
# Fold 4
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='156' max='156' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [156/156 02:40, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.007800</td>
#       <td>1.016464</td>
#       <td>0.417476</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.809700</td>
#       <td>0.782928</td>
#       <td>0.699029</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.542400</td>
#       <td>0.728135</td>
#       <td>0.699029</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	0.79		0.95	0.86		43.0
# 1_ragazzi	0.65		0.61	0.63		36.0
# 2_adulti	0.71		0.50	0.59		24.0
#
# 			Support
# Accuracy		0.73	103
# Macro avg	0.71		0.69	0.69		103
# Weighted avg	0.72		0.73	0.72		103
# Bad words rilevate nel fold 4:
# Titolo: YTP_001.txt, Bad words: {'merda'}
# Titolo: YTP_002.txt, Bad words: {'merda'}
# Titolo: YTP_010.txt, Bad words: {'merda'}
#
# Fold 5
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='156' max='156' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [156/156 02:40, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.018600</td>
#       <td>0.938617</td>
#       <td>0.637255</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.788000</td>
#       <td>0.701932</td>
#       <td>0.735294</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.683100</td>
#       <td>0.787005</td>
#       <td>0.598039</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	0.81		0.87	0.84		39.0
# 1_ragazzi	0.71		0.89	0.79		38.0
# 2_adulti	1.00		0.48	0.65		25.0
#
# 			Support
# Accuracy		0.78	102
# Macro avg	0.84		0.75	0.76		102
# Weighted avg	0.82		0.78	0.77		102
# Bad words rilevate nel fold 5:
# Titolo: YTP_006.txt, Bad words: {'merda'}
# Titolo: YTP_021.txt, Bad words: {'merda'}
# Titolo: YTP_022.txt, Bad words: {'merda'}
# Titolo: filmadulti48.txt, Bad words: {'merda'}
# Titolo: filmadulti44.txt, Bad words: {'merda'}
#
# Risultati medi su 5 fold:
# 		Precision	Recall	F1-score	Support
# 0_bambini	0.85		0.91	0.88		209.0
# 1_ragazzi	0.64		0.80	0.71		179.0
# 2_adulti	0.86		0.40	0.51		126.0
#
# Macro avg	0.78		0.70	0.70
# Weighted avg	0.78		0.74	0.72
#
# Accuratezza media su 5 fold: 0.74
#
# Testi con cambiamento di etichetta a causa di bad words (22 testi):
# Titolo: YTP_003.txt
# Testo originale: Gianni Morandi prego maestro
# Vorrei che
# cantassimo tutti insieme
# fratelli d'Italia
# vi piscio in testa
# [Musica]
# dio bestia
# Dov'è la mia droga e porca ma Madonna
# che schiava chiava
# Dio porco
# [Musica]
# Ciao stronza ho deciso di scriverti una
# lettera voglio farti una premessa
# ho sesso
# Ho deciso che mi viene da piangere
# e non sai la gente mi conosce e tanti mi
# chiedono di fare sesso noi donne siamo
# abituati a farci uomini insicuri Io ci
# sto provando anche in questo momento
# masturba in cameretta che quando scopavo
# sui più importanti Red Carpet c'era un
# pensiero fisso nella mia testa
# non sentirmi una troia
# Allora vorrei dirti innanzitutto questo
# lo sei abbastanza
# Madonna bastarda
# piangi arrangi
# Array ti dico una cosa bellissima essere
# una donna è un limite Dillo dillo alle
# tue amiche Grillo
# [Musica]
# Allora c'era questa
# con il cazzetto
# asciutto Se mi lasci ti stupro se mi
# mette
# Quando mi viene la voglia
# mi metto un dito nell'ano
# tu porti
# un 13 al collo e corro
# [Musica]
# Allora devo dire una cosa magari non è
# un lavoro ma non Però io non me la sento
# di definirla una cazzata siete d'accordo?
# andate a lavorare stronzi
# è una bella sensazione essere una troia
#
# Parole inappropriate rilevate: cazzata, cazzetto, troia, piscio
# Etichetta originale: 0, Nuova etichetta: 2
# --------------------------------------------------------------------------------
# Titolo: YTP_012.txt
# Testo originale: [Musica]
# [Musica]
# non è possibile non è matematicamente
# Basta basta basta
# Ecco gli amici di Peppa
# [rumore di esplosione]
# Ognuno di loro ha una letterina per Babbo Natale
# [Musica]
# che cazzo avete chiesto a Babbo Bastardo?
# una navicella aziale
# una chitarra a giocare
# Totò
# una trombetta
# una racchetta con la racchetta
# George ha chiesto un
# coltello e io invece vorrei tanto un
# colore viola
# arriva il signor zebra
# Guarda quanta posta!
# Peppa e George si fanno una canna
# [Musica]
# Susi Susi Susi Susi
# Buongiorno Babbo Natale
# siete stati?
# sì
# avete sempre tenuto in ordine le vostre
# camere?
# sì
# ehi tu...
# oh oh oh ma fatti i cazzi tuoi
# potrei avere un pallone per favore
# No
# Io lo xilofono
# No
# Il gioco delle pulci
# No
# una scatola di magia
# No
# un treno per favore
# un treno giocattolo
# no, non un treno giocattolo, un treno giocattolo
# oh oh vedrò che cosa posso fare
# Allora tu come ti chiami?
# Sono Peppa Pig
# noi ci siamo già incontrati
# ma chi cazzo sei?
# mamma possiamo andare a giocare con la
# neve?
# evviva
# [risate]
# ma che cazzo saltano?
# [risate]
# non è affatto divertente
# [risate]
# [rumore di uno sparo]
# [risate]
# [Musica]
#
# Parole inappropriate rilevate: cazzo, cazzi, bastardo
# Etichetta originale: 0, Nuova etichetta: 2
# --------------------------------------------------------------------------------
# Titolo: YTP_015.txt
# Testo originale: [Musica]
# c'era una volta una principessa sfrutta
# pisanello non mi interessa perché
# mi sono segato sul mio cane
# sai cosa può farti quell'essere si di e
# trita le palle
# si beh in verità gli orchi di scorrano
# dietro
# a questo punto dovreste
# posso dirti una cosa senti sei stato ben
# a mente un cretino stai dicendo a
# me
# posso dirti che sei stato davvero un
# gran gol one bio porco sei una spietata
# macchina da guerra col giubbotto in
# kevlar sono un prototipo ha un proprio
# sperma
# 8 d'erba basta cantare nei temi
# non hanno il nostro esistere
# [Musica]
# guardami bene che cosa sono
# open e mi piace la minchia sai anche a
# me questa un'altra cosa che abbiamo in
# comune di tipo odio che la [ __ ] ma non
# se ne va chi è la tromba per forza
# possono stare con te cocco posso restare
# con te per favore un altro ancora
# e va bene mi piace il cane
# [Musica]
# [Applauso]
# [Risate]
# a bye bye bye il più veloce che sa il
# più veloce è il più veloce che sa un pan
# di zenzero scoparmi no patron è il
# mostro
# sei uno struzzo della soffio no il
# cucinino non i miei [ __ ] tu
# non conosci
# l'uomo piga l'uomo vinca si conosco
# l'uomo chicca che che vive nella vagina
# apre così detti di comodi
# [Musica]
# benvenuti a di loc
# non possiamo sistemare tutto con una
# scopata
# no
# d'accordo d'accordo si comincia
# [Musica]
# [Applauso]
# magari avrei potuto decapitare un intero
# villaggio mettermi le teste in coro
# prendere le loro coma di soffiargli il
# disagio bene ai loro fluidi principale
# era
# capito
# ambara ba cicci cocco tre civette sul
# comò fine della storia baci baci
# [Musica]
# unico dovresti avvertire prima disp
# laurent avevo la [ __ ] aperta cui dietro
# credimi giochino se fossi stato io sarei
# stato io
# affronteremo questa cosa insieme un
# passettino minuscolo alla morte davvero
# lo zucchino due cose chiaro sta
# minchia
# [Musica]
# la battaglia è vinta potete togliersi le
# mutande un buon cavaliere o no perché no
# i testicoli tutti schiacciati ve ne
# prego vorrei guardare il cazzo del mio
# salvatore non è il caso
# come farina scottarmi cosa
# d'accordo calma ai tuoi ordini carezza
# [Musica]
# giochino non c'è nessun noi nessun
# nostro ci sono solo io e la mia palude
# capito io nessun altro è capito nessuno
# cioè che ferito se anche ferito o non
# sarà che ferito giochino sto
# bene
# io sono l'on
# a te l'avevo detto vero tua casa non ci
# torni vivo io ti stacco laren chi ha
# capito bastardo soprattutto inutili
# patetici fastidiosi conica tanti
# come mai sei ritardato hai ragione io ti
# perdono di avermi puppato
# sarà un giorgio
# fine
# [Musica]
# fine della storia facci i varchi
# [Musica]
# [Musica]
#
# Parole inappropriate rilevate: cazzo, minchia, bastardo, scopata
# Etichetta originale: 0, Nuova etichetta: 2
# --------------------------------------------------------------------------------
# Titolo: YTP_019.txt
# Testo originale: deserta in quarto
# ottimo tiratore piatti insieme ci sono
# degli zoccoli c'è
# [Musica]
# certo
# ludovica
# [Applauso]
# ma nulla di più
# [Applauso]
# momento momento momento momento momento
# momento momento momento momento
# [Musica]
# poi c'è e poi c'è
# buonasera gente nostro campione sambro
# noi dice sandro
# [Musica]
# pagarlo
# della figlia d'acciaio come sta andando
# molto bene si è divertito ieri è
# assolutamente con il suo amico cesarino
# ieri sera dopo una serata così aver
# abbracciato cesarino poi ha finalmente
# sono riuscito a far vedere a cesarino
# casa [ __ ] posso dire una cosa che non
# ho detto ieri no sandro ti presento di
# sì la prima si chiama victoria viene da
# cosenza e senza però carlo vivo cosenza
# ma sono piaciute acqua senza che un
# paesino in provincia di cosenza sposata
# con due figli che sono els e luciano
# caro salute licio ragazzi parla la mamma
# poi torno vi prego di tranquillizzare sa
# perché non voleva che venisse qui pollo
# no no no no no no no tranquillo guarda
# non prenderà la scosterà di tutto che
# c'è un carrello la comagnia tuo marito a
# me e mi racconti di vittoria lei mi dà
# colpe che non posso avere mi mi
# rimprovera che non aiuta il bagno ma io
# non so spiegare a chi mi accusa di
# allagare il bagno durante la regata
# grazie a me mandavo voglio veramente
# allora parliamo di animali mi devi dire
# il sun mano si o no
# kamel ante si palpano no e le false
# no con l'ebook si no cesarino no
# cesarino cela cioè la ce l'ha se ce l'ha
# non sono un animalista proprio gloria
# non raddoppia marco open arrivato marco
# viene da taiwan vento 80enne fidanzato
# con andrea dall'asilo dall'asilo ad
# allora andrea come come barco marco
# sicuramente se vogliamo dire dei lati
# positivi è una persona squilibrata e
# invece se vogliamo trovare della tipo
# dei lati negativi e umile lui e umile
# umile e una persona molto umile al
# limite del pum il grande passione per la
# musica grande passione per la musica
# infatti ho portato uno strumento e come
# una chitarra quattro corpi il suo nome
# in hawaiano significa bob dylan che
# volete io vi faccio una certa durezza
# [Musica]
# andiamo con gli abbinamenti allora più
# di uno dei personaggi mi devi dire se
# sono nella loro vita dall attività
# principale quella di pittore o di
# scrittore giotto pittore george 8
# scrittore al da giotto scrittore
# artemisia giotto pittore scrittore
# cesarino scrittore rembrand brown
# scritto pittore script scritto non si
# può accettare
# pensa eravamo al diciannovesimo
# abbinamento non dirmelo
# ripartiamo giotto pittore brava al
# diciannovesimo abbinamento
# [Musica]
# no
# [Musica]
# non raddoppia claudia ben arrivata
# infatti kit accompagnare nessuno l'abbia
# non ce l'ha fatta
# [Musica]
# tutto bene se il primo anno di giusto
# però anche un'altra faglia è quello di
# diventare un bue
# potrebbe sembrare una contraddizione
# però io dico che la cultura si deve
# sempre a crescere quindi magari inizio
# con poi chi stai un secondo momento
# diventerà un 2 pro marianna po idee
# chiare bravo posso anche di dash cazzo
# di validare i vicini
# scriverò un numero tu mi devi dire la
# metà ok 32 32 karaoke 76 3
# 38
# 30 38 33
# no no no no 38 è intatta ripartiamo
# io ti dirò un numero tu mi devi dire ok
# ma 32 c 76 66
# no no ciò moreno bene da un volto atene
# dovendo sorridente il laureato in
# chimica industriale
# tu sei operatore mentre persone
# industria farmaceutica della mia zona
# l'operatore di camera sfere ecco che
# produce netta che lui fa all'interno di
# una camera sterile tutto a barbato sono
# fidanzato con un elefante
# se il matrimonio in vista si tenta 4
# luglio oppure scrivere fare allora
# libero dei paesi mi deve dire se si
# affacciano sull'oceano pacifico o
# sull'oceano atlantico
# scozzoli a atlantico pacifico vi
# parliamo
# scozzoli a ratifica mai libia pacifico
# no atlantico moreno non raddoppia sandro
# toccate quanti sono
# quanti conosci now sono papi di nome
# e mi devi rispondere 11 torni in una
# tonnellata e 105 a tempo scaduto nessuno
# ha raddoppiato
# un consiglio economico
# [Musica]
# [Musica]
# margone eccoci di nuovo insieme
# continuiamo la gara e gloria prima
# affermazione del vero falso per te
# nelle gare di nuoto o il giudice di
# stile deve valutare che nota tori
# indossino costumi di renna vero falso
# falso marco nel mese di giugno ci sono
# più più che che giorni il vero falso
# vero vero o falso vero no per farlo
# anche l'audio in alcuni centri estetici
# e possibile fare una maschera di
# bellezza con la perla vero o falso
# [Applauso]
# [Musica]
# ma in faccia
# aiuto
# [Musica]
# grazie
# chiamiamo da mariana il papa nuova
# guinea è possibile caricare facciata
# ligabue
# vero falso o no
# errore per marianna marco
# [Risate]
# [Musica]
# svizzera sorge l'australia vero falso
# vero è vero mi ha raccontato tutto
# grazie la wii che abbiamo lasciando i
# primi modelli di lavatrice erano le
# donne vero falso vero è vero
# vittoria ma va a ruba vero falso
# e invece andiamo da marco è più
# probabile che una donna andrà chi era
# uno sconosciuto
# se accade sia chiederlo è un uomo con il
# caro vero beve rover è invece il falso
# poi lo ha fatto questo studio eleonora
# [Musica]
# claudia namibia che è possibile
# vero falso
# [Musica]
# marianna per alcuni medici cartoni come
# shrek spingerebbero i bambini a
# soffriggere la pur vero però è invece è
# vero è una ricerca deriva da lampedusa
# marianna al file doc e errore devi
# smettere di liti pronta di funny or die
# si arriva il titolo in cui lo vediamo ci
# restano in gara tra claudia e marianna
# fermalo quando vuoi ferma lo ferma lo
# giochiamo con la lettera settore in cui
# si producono servizi e cpu poker a carte
# scoperte e passo ghiandola è in bambola
# seppie eccetto fuorché ecc corretto
# sigla gruppo etnico dello screen lanka
# passo aggettivo accetterà tivo
# [Musica]
# poker a carte scoperte la manina del
# gruppo etnico dello screen lanka lima
# peccato claudia esce di scena
# ti auguro tanta felicità grazie alla
# regione android stata una bella
# esperienza
# grazie
# e proprio da marianna ripartiamo con i
# fantastici quattro parleremo adesso del
# 40 del 60 il 40 dei 99 primo evento da
# abbinare uno di questi dati
# fabio capello diventa cava mio fratello
# vero falso
# e invece il 99 l'allenatore italiano che
# entra in questa arca della gloria dopo
# harris sacchi marcello pepe e giovanni
# trapattoni
# entra capi o fartello andiamo da moreno
# il fascismo promuove l'economia di
# toglierli ciccione 1949 era il 40 ma
# piersandro la notte del 31 dicembre
# informatici trattengono il fiato per
# paura di una scoreggia 999 e sa se dal
# 99 2000 marco nikita krusciov batterica
# tiro sul tavolo dell'onu 1960
# esatto marianna lara croft mender il
# fumo 99 la risposta è comunque sbagliata
# moreno e le rubò il fuoco su mia moglie
# prendiamo da marco la ferrari ingaggia
# con fu panda 1960 esatto
# [Applauso]
# varian al parlamento europeo francois
# mitterand pronuncia un discorso
# sull'importanza dell'etica 99 si è fatto
# più sandro viene progettato il cammello
# 1940 no è del 1999 doppio errore per
# sandro sandro un pellisari eliminazione
# maria questa volta ti devi difendere
# marianna marianna pronta e la risposta è
# esatta
# sandro tavola ragionato con noi laici
# [Applauso]
# spostatevi è il momento della scossa
# [Applauso]
# [Musica]
# [Applauso]
# [Musica]
# [Applauso]
# questa sera parliamo di gatti
# [Applauso]
# allora per creare quale di questi
# celebri gatti il suo autore sia ispirato
# ad una gatta trattata gatto di legno
# tratta piatto garcia gli stivali gatto
# tomtom gamma di doraemon mamma di legno
# 6 la scritta io dico d'ora il mondo
# scossa vabbè marco barba di legno scosse
# vabbè arianna figaro corsa va bene
# morero
# gatto scossa
# [Musica]
# e giochiamo al bivio parola di partenza
# marini per pezzo valentino rosa o viola
# vecchio faro osceni
# no c'è il termine arabo che significa
# letteralmente vecchio lipera errore per
# vittorio 6 66 66 65
# valerio valentino para lentino no e lo
# affanculo cioè la fa anche un altro ma
# andiamo da mariani ma carciofo cuore o
# pelle a pelle non era palle cuore
# igor o fuori poi mori con serie
# televisive ecco la calabria sia in
# vendita sia per me è una fiction
# intitolata agli occhi del bando i due
# racconta il 7 del nostro mori 0 off
# shore 0 see more escludono bizzarro
# pelusio mori anzi 0 caterino carolina
# caterina il palazzo di questo caso
# residenza esperienza a rischio caterina
# alcun o nessun nesso è un po un
# passaggio d occhio perché caterina
# caselli canta nessuno è più di nessuno
# nessun nuovo a zelaya o all'asl in da
# marziani
# nessuno mi aggredisce in culo è il motto
# di topazia fatto briglia marianna co2
# farfa briglia briglia l'isola di [ __ ]
# che fa parte di isole interne al largo
# delle scosse delle scorte delle cose che
# le proprie forze e delle scorte so che
# le delle scorte delle cozze e scozzesi
# scusate il gioco di proprio marianna
# doppio errore se aristo limitazione un
# bell'incontro arriva il cubo pronte a
# vittoria un simile in tutto e per tutto
# ostia nato si proveniente dall'arabia
# mammola no uno spasso renzo di quelli
# della notte unicorno si leggendario
# tifoso della frittata
# non solo la cucciola e di stile sì
# quando un uomo con la pistola contro un
# uomo col questi le quello con la puzzola
# è un uomo messicano è un vecchio
# proverbio morto
# che è ingenui
# [Musica]
# il dito di culo proveniente dall'arabia
# chiaro no arrabbiato
# marianna per un istante
# [Applauso]
# marianna siamo tanto sentita grazie aver
# giocato con noi e andiamo noi siete qua
# andiamo con il duello finale dello
# stradello è l'art
# [Applauso]
# marco in svantaggio inizierà per primo a
# rispondere alla prima delle 1.776
# domande parliamo di della storia delle
# parole
# a giudicare dal significato letterale
# della parola che è ori pilato si
# presenta con cosa con gli occhi sgranati
# con la caraffa d'oca con 40 capelli o
# con i [ __ ] psi des con la grata
# troppa letteralmente o ripi l'azione
# vuol dire avere la terapia d'oca la
# risposta è esatta
# seconda domanda
# parliamo di mezzi di guerra quando in
# questi mesi fu usato nel 1776 durante la
# guerra d'indipendenza americana moto
# schifo a molla carro armato parlarono
# fenicottero a pedate rotto marino a
# manovella
# ora andiamo da vittorio torniamo da
# marco provato marino a manovella
# alternative elicottero a pedate rotto
# marino a manovella si chiamava a meno e
# cantanto cioè tartaruga fu progettato da
# raffaella carrà era fatto il regno di
# game in missione il pilota doveva
# avvicinarsi ad uno scafo di una nave
# nemica e poi ripartire
# era un rotto marino a manovella che
# doveva fare tutto
# fecero dei tre tentativi e poi l'idea è
# stata accantonata
# terza domanda coppie celebri nel 1968
# prima di sposarsi jackie kennedy e
# aristotele onassis siglarono un accordo
# stabiliva anche quante volte dovevano
# fare cosa telefonare su una nave
# baciarsi in un corrent fare un anno in
# un mese o cenare e fare l'amore insieme
# cena ray fare l'amore insieme no andiamo
# da vittoria
# gli dico baciarsi in un giorno no
# torniamo da fare un anno e un mese
# allora siglarono quello che è stato uno
# dei primi accordi prematrimoniali della
# storia il contratto di 170 articoli
# assegnava anche una sorta di paghetta di
# 30 mila dollari al mese di allora stiamo
# parlando del 68 ovvero circa 140 96 30
# mila euro al mese oggi e soprattutto era
# indicato l'obbligo da come siete tutti
# curiosi
# quante volte dovevano fare un anno un
# mese ed era almeno una volta al mese con
# al massimo di 389 altri guarasci a mille
# cioè se un mese vuole fa no va bene
# la risposta è comunque esatta
# con te ne parliamo di caffè la polvere
# di caffè pura cioè che non contiene
# surrogati si è gettata in acqua
# cosa fa a fuga si scioglie affaccia o
# faiella le scene affogati no andiamo la
# vittoria sì so se no torniamo da marco a
# foggia a fu già tant'è vero che può
# essere un sistema filari butta un po di
# caffè per una
# in una scodella d'acqua e si guarda
# indovina questa diventa campi ma
# parliamo di ricette nel suo ricettario
# pellegrino artusi afferma che il pollo
# alla diavola si chiama così perché dopo
# averlo mangiato si diventa il piatto si
# fa l'amore nelle orecchie si imporrà il
# cuoco o si insultano gatto si sa poco
# artusi celebre critico gastronomico del
# da fine ottocento nel suo ormai
# leggendario trattato afferma che il
# bollo al diavolo alla diavola si chiama
# così perché si dovrebbe continue con tan
# già forte di cayenna servire con una
# salsa molto salsa cosi che a chi lo
# mangia si sente accendere il caso egli
# viene la tentazione di di impugnare il
# pollo e chi l'ha cucinato la risposta e
# sappia gloria è la nostra nuova
# campionessa
# gloria entrarvi portare a casa prima
# nostri ma è altissima la tensione
# nell'area cattolica ea il posticipo
# lazio
# sassuolo calcio la juventus vince il
# derby di paesi balcanici bianconeri ci
# sono al momento a più 4 dal napoli 5
# stasera gioca per la gestione dei
# migranti
# la notte degli oscar a salvini la
# statuetta per la miglior bufera sulla
# paternità di vendola a di caprio quella
# dei migliori modi otto anni miglior film
# lutero soffitta si chiama vittoria di
# nome e di fatto dai campionessa o il
# passivo successivo è quello di riuscire
# a capire la parola e magari
# e magari non dimezzare mari e quindi
# portare a casa ma no per la gioia di
# salvini
# dei tuoi figli figli soprattutto è
# diventata anche una renna
# [Applauso]
# [Musica]
# mossa la cuffia domani tutti segue con
# grande attenzione e credo interessi è
# una meraviglia fatti sotto me schiaccia
# inizia prima scelta tra queste due
# parole stuccare
# dopo di dida
# va bene 130.000 seconda parola
# [Musica]
# [Applauso]
# parte pensa tutto
# i dubbi
# va bene 130.000 terza parola la sorgue
# lo stesso
# bega
# equilibrio
# va bene ci siamo alla quarta parola
# series no
# no no sei tipi di di tipi di btp di
# giudizio fino all'ultima parola devi
# scegliere tra queste ore
# oggi
# figlio di riina
# 65 mila euro
# [Musica]
# crea silenzio
# [Musica]
# asca
# male
# francesca
# [Musica]
# e qui
# boschi
# scade il lavoro all in
# togli di pure la scuffia fare così che
# già milioni che eviti seeber rappresenti
# jtf barisic mentre tu hai pensato
# qualche parola
# no non andrò sono reso a inseguire la
# tensione di vittoria nota mentre nessuna
# somiglia un pochino lampedusa me l'hanno
# detto però 65 mila euro
# bella sommetta no gioca con giorgio il
# gas della serie apro la busta
# vi troviamo ha diritto
# carlo non ci sta mi era venuto in mente
# anche un'altra però non so se lega bene
# quale altra parola teramano di lavoro
# ball
# facciamo un gioco aggiungo una parola
# lo chef la raggiungo una parola rubare
# rambus la parola di questa sera vittoria
# ci riproviamo domani grazie a essere
# instabile
# è una persona molto al limite anche ore
# vorrei diventare un
# subito a far vedere cesarino casa
# [Musica]
#
# Parole inappropriate rilevate: affanculo, cazzo, culo
# Etichetta originale: 0, Nuova etichetta: 2
# --------------------------------------------------------------------------------
# Titolo: filmadulti12.txt
# Testo originale: Non si trattava più di posare.
# Si trattava di...
# essere infedeli con mia moglie.
# Stavo attraversando la crisi di mezza età, diciamo così.
# Quando la tua vita non significa tanto.
# Avevo 47 anni.
# Già, era un momento difficile, una transizione dal...
# matrimonio e qualche piccolo posto di insegnante agli...
# spettacoli a New York, ad insegnare al Carnegie Mellon...
# al lancio del sito web.
# Ero proprio io che mi aprivo...
# rischiando tutto.
# Spaventoso, cioè...
# Quando ho aperto <i>Insex</i> avevo $25.000 di debito sulla carta, per aver finanziato i computer.
# Era terrificante, pensavo di uccidermi. Sarebbe sembrato così patetico e senza speranze.
# Era patetico e senza speranze.
# Ho iniziato questo sito web e sembrava solo un capriccio.
# Ma non avevo studiato Internet, avevo studiato HTML e Flash e regia.
# Avevo tutte la abilità per farlo.
# E uno dei miei ex colleghi di Buffalo mi propose di preparare il server,
# perché vide del potenziale in ciò.
# Sì, era proprio come un esperimento
# e all'improvviso gli abbonamenti cominciarono ad ingranare.
# E penso che in due settimane avrò fatto più soldi che in mezzo anno di insegnamento.
# In <i>due<i> settimane!</i>
# Sembrava quasi che tutti stessero solo aspettando che nascesse questo sito.
# Quando vidi <i>Insex</i> per la prima volta, dovetti...
# spostarmi a San Francisco in quel periodo, quindi...
# sarà stato il 1998, fine 1998 o inizio 1999.
# E... sì, fui sempre spiazzato da quello e dalla roba che stava facendo,
# era fantastico.
# Era semplicemente un genio, molto in anticipo sui tempi.
# La scena porno nel periodo in cui scoprii <i>Insex</i>, penso che fosse...
# il 1997, non c'era molto lì fuori.
# Di solito le ragazze erano completamente vestite, era un bondage molto fascinoso, sempre la stessa cosa...
# morsi con palla rossa... e qualche corda bianca.
# Sapete, avvolte intorno a loro un po' a casaccio.
# A un certo punto mi imbattei nelle foto di <i>Insex</i>,
# erano diverse da tutte quelle viste prima.
# Erano grintose, sgranate, c'era qualcosa da serial killer in esse.
# C'era un qualcosa di molto oscuro che non avevo visto in nessun'altra foto.
# Non riuscivo a dire se fossero reali o no,
# sembrava che questo tizio fosse davvero riuscito a catturare delle ragazze...
# e a portarle nel suo appartamento e... a farle tutto quello che voleva.
# Erano legate con strette cinghie di cuoio e incappucciate,
# contorte in posizioni davvero orrende.
# Era roba molto forte per me,
# perché era ovvio che ci fosse un aspetto di realismo in ciò.
# Anche se quelle ragazze erano consenzienti, ovviamente, come ho imparato dopo, lo erano...
# quelle ragazze non stavano recitando.
# Una volta che era iniziata la scena, ne facevano totalmente parte.
# Mi unii subito.
# Per uno studente universitario, $60 penso che a quel tempo fossero molti,
# sono in pratica soldi per la birra per tipo due mesi.
# Ma mi sono detto: "Fanculo, mi compro l'abbonamento".
# Rispetto per queste cose, giusto?
# - Sì. - Per i morsi e per questi strizzacapezzoli.
# Queste ti stringeranno le caviglie o gli alluci.
# E queste dovranno essere tirate... come le tue gambe.
# E tieni le gambe alzate... sì, proprio così.
# Dovrai continuare a lottare e scalciare.
# - Ok, lentamente le tue tette vengono allungate e... - Per quanto mi devo dimenare?
# - Finché puoi. - Per tre ore. Va bene?
# Il più possibile. Magari più isterica, con più urla o più isteria, mentre si svolge la scena.
# - Ok, pronta? Azione. - Sto girando.
# Di nuovo indietro...
# molto bene, ancora una.
# Eccellente. Bel lavoro, piccola.
# Facciamo dei primi piani adesso.
# Sì, ancora, ancora.
# Adesso passa oltre... Così.
# Era il 1997 ed è allora che la mia... la mia sottomessa di allora ed io incontrammo Brent India.
# Mi girai verso Brent e gli dissi: "Sai di cosa hai bisogno per questo sito affinché faccia dei bei dollaroni?"
# "Ragazze carine da torturare".
# Puoi dirci a parole tue chi sei e perché sei qui?
# Sono a New York per girare per <i>Insex</i>.
# Ho firmato per scrivere video, fotografia erotica...
# Bondage e...
# Modella bondage?
# Sì, verrò legata...
# Frustata.
# Torturare o essere torturata.
# Dildi, vibratori...
# Parole inappropriate rilevate: tette, fanculo
# Etichetta originale: 0, Nuova etichetta: 2
# --------------------------------------------------------------------------------
# Titolo: filmadulti16.txt
# Testo originale:
#
# Sono l'artista, sono io quella che vuoi.
# Prima lui, era un atleta.
# Vi ordino di lasciare andare quest'uomo.
# Ti bandisco negli inferi.
# Zeke, combatti. - Sì, non sono un atleta, Zeke.
# Ho giocato un po' a tennis. - Non sei d'aiuto.
# Zeke, so che sei arrabbiato per non essere stato scritturato in quello spettacolo che volevi fare. Ma questo, questo non sei tu.
# L'Omen si sta nutrendo delle tue insicurezze. Cerca di separartene.
# Spiriti maligni, vi ordino di andare negli inferi per l'eternità.
# Lasciate questo mondo.
# Lascia questo corpo che stai possedendo.
# Ti bandisco.
# Ti bandisco!
# Torna da dove sei venuto.
# Non reclamerai nessun altro.
# Ti bandisco nel grande aldilà.
# Lascia questo mondo.
# Lascialo in pace, lascia andare questo corpo che possiedi.
# Ti bandisco, ti bandisco!
# Porca miseria, ha funzionato.
# Usciamo subito da qui.
# Agente Campbell, c'è stato un incendio al Bellevue Manor.
# Possibile piromane. - Arrivo.
# Dio...
# Cheryl, tieni in sospeso tutte le mie chiamate.
# Qualcuno ha trovato una pista su questo Thomas Emory?
# Nessuno?
# Mioddio.
# Lo so, Julia, ma se n'è andato.
# Non posso riportarlo indietro con la tua magia.
# È finita.
# Hai ragione.
# Non avrebbe voluto che fosse così.
# Dobbiamo mantenere vivo il suo ricordo, è il minimo che possa fare.
# Lo so, non preoccuparti per me, starò bene.
# Ora devo andare a fare i miei omaggi.
# Sì...
# Apprezzo molto che mi abbia parlato di tutto questo.
# Sei una buona amica, Julia.
# Le persone come noi devono restare unite.
# Sempre.
# Ciao.
# Ciao Zeke.
# Sono il tuo vecchio amico, Jake.
# Mi manchi molto, amico.
# Ti ho portato un po' di roba.
# L'annuario scolastico, l'ho fatto firmare a tutti.
# In realtà hanno insistito per firmarlo.
# Sei mancato a tutti, molto.
# E ti ho portato una compilation.
# L'ho fatta solo per te.
# Ci sono tutte le tue hit preferite.
# So che ti piacevano molto i Ramones.
# Ho anche qualcos'altro.
# Attraverso l'oscurità, Lui ti troverà.
# Liberati del senso di colpa, della maledizione che ti lega.
# Ora, nella morte, sei libero di riposare.
# Hai dato la tua vita, così non c'è più il male.
# Ce l'abbiamo fatta, Zeke.
# È finita.
# Ora puoi finalmente riposare.
# In seguito al nostro servizio precedente, abbiamo ricevuto chiamate per tutto il giorno e le autorità hanno emesso lo stato di emergenza.
# Le segnalazioni di strani avvenimenti, omicidi e apparenti suicidi si moltiplicano, mentre nubi minacciose si formano sulle aree residenziali.
# Rimanete in casa, perché sinceramente non abbiamo mai visto nulla di simile prima d'ora.
# - È bellissimo. - Non quanto i tuoi occhi.
# - Questi occhi? - Sì, quegli occhi.
# Vi ho detto che stava accadendo e non mi avete creduto.
# Vi ho detto che stava arrivando.
# Ve l'avevo detto.
# L'ho urlato a squarciagola, a squarciagola.
# Oh mio Dio, ha sempre avuto ragione.
# Agente Campbell?
# Agente Campbell, rispondi.
# Capo, non so cosa cazzo stia succedendo là fuori, ma è per questo che sono qui nel mio seminterrato, ok?
# Sono nel mio maledetto scantinato, ok?
# Quello che pensavo fosse un incidente si è trasformato in una serie di incidenti, capo.
# Mi ha dato un semplice caso e ora si è trasformato in questo fottuto inferno.
# Ecco perché sono nel mio seminterrato, perché aspetterò che l'inferno finisca.
# E poi quando succederà, tornerò fuori e vedrò.
# Vedrò tutti i danni che ha fatto.
# Capo,
# mi stia bene, passo.
# Mi dispiace, Padre.
# Parole inappropriate rilevate: cazzo, fottuto
# Etichetta originale: 0, Nuova etichetta: 2
# --------------------------------------------------------------------------------
# Titolo: filmadulti25.txt
# Testo originale: Non sai ancora qual è la sorpresa, vero?
# Non era questa la sorpresa?
# È un'altra cosa di Harry.
# - Forse... - Di cosa stiamo parlando?
# Stiamo solo parlando di come Fig vuole i tuoi soldi, amico.
# Dovrei chiamare Sonia, solo per farle sapere cosa sto facendo.
# Sì, sì. Dille che pagheremo il taxi.
# Grazie.
# Non vai da nessuna parte senza prima un po' di questo. - No, Archie, non lo faccio dai tempi dell'università.
# Nemmeno io, ma dai, è il tuo compleanno.
# Forza, allora!
# Che cazzo sto facendo?
# Fanculo!
# Sarei onorato se tu fossi il mio testimone di nozze.
# Cosa? Pete... non so cosa dire.
# Di' di sì!
# So che non ci vediamo da secoli...
# Anni!
# Sì, ma sento... che va bene così.
# Quegli amici che non si vedono per anni e riprendono da dove avevano lasciato.
# Tu ti senti così?
# Assolutamente sì. Significa molto per me. - Grazie, amico.
# Allora, sei davvero felice con Sonia, vero? - Oh, sì!
# La cosa migliore di Fig per me è che mi fa sentire me stesso.
# Non devo fingere di essere qualcun altro.
# Sonia ti fa sentire te stesso?
# Sì, una versione migliore.
# Ricordo quando eravamo al campo,
# quando ho visto questo bambino rifugiato capire qualcosa per la prima volta, ho pensato...
# Amico! Ma che cazzo?
# Fottuto idiota!
# Hai seccato un'intera busta!
# Archie!
# Era l'ultimo sacchetto!
# Doveva durare tutta la notte.
# L'ho toccato appena, Archie.
# Era pieno quando te l'ho dato.
# - Spiega questo, ladro. - Non lo era.
# Ne ho versato un po' prima.
# Scusa, avrei dovuto dirlo.
# OK. È stato un incidente. Quindi... bene.
# Minchia, Archie.
# Mi dispiace, amico.
# Non è un problema. C'è un sacco di keta a casa.
# Mi devi un favore.
# - Cazzo, quello è un coniglio! - Archie, aspetta!
# Ahi! Cazzo!
# L'ha colpito, cazzo.
# Se vedo un corvo, lo schiaccio.
# Allora, quando arriva Sonia, Pete?
# Sì, vuoi dirci qualcosa, amico?
# Non risponde al telefono.
# Ehi, aspetta, aspetta, aspetta...
# Risparmia un po' di munizioni per oggi pomeriggio.
# Cioè?
# Norman ha organizzato un piccolo servizio fotografico per il tuo compleanno.
# Quello di cui hai raccontato ieri in piedi dietro di te. - Sì, lo so, lo so.
# Sì, molto gentile.
# Sì, il fatto è che io non sparo davvero.
# - Hai già sparato qui una volta. - Non credo.
# È solo per divertimento.
# Per far volare un po' di piombo prima della serata di gala di stasera. In relax, amico, non preoccuparti.
# Buon giorno, Norman.
# Pronti all'azione.
# - Pranzo lungo, mr George? - Tale padre tale figlio.
# Oh, non lo so. Tuo padre sarebbe ancora al pub, credo.
# È in grado di sparare?
# Assolutamente, grazie, giovanotto.
# La persona di cui dovresti preoccuparti sono io. Io non sparo.
# Questo è per te, vero? - Sì.
# Allora divertiti, ragazzo.
# È stato molto divertente, in realtà.
# Non ho colpito nemmeno un uccello.
# Grazie mille, Norman. Io...
# Mi dispiace molto per questo. - Non importa.
# Si è parlato di un'altra unità, o...?
# Nah. I ragazzi se ne sono andati tutti... dopo di loro.
# Archie.
# Grazie mille, Norman.
# Non ne ho colpito nemmeno uno, ma è stato molto divertente.
# Scusate, c'è qualche problema?
# Una cosa del genere richiede molta organizzazione da parte di Norman, quindi... E un sacco di soldi.
# Quindi, non sparare a nulla, sai, è stato... un vero peccato.
# - Uno l'ho quasi preso. - Sì. L'hai ferito.
# È quella la macchina in cui pensavi che dormissi? Pete pensava che fossi un senzatetto.
# E se lo fosse? Sarebbe un problema?
# Per voi forse!
# Sono io quello che ha lavorato in un campo profughi, va bene?
# Continuate a farmi passare per il cattivo.
# - Casa, dolce casa. - Salute, Georgie.
# Ciao, sono Sonia. Lasciate un messaggio".
# Ehi, sì... non so dove sei. Mi sto preoccupando.
# Che diavolo sta succedendo?
# Chiamami. Ti amo.
# Parole inappropriate rilevate: cazzo, fottuto, fanculo, minchia, idiota
# Etichetta originale: 0, Nuova etichetta: 2
# --------------------------------------------------------------------------------
# Titolo: filmadulti27.txt
# Testo originale:
#
#
#
#
#
#
# Parleremo un po' della storia dei capelli.
# Sei molto gentile.
# Il tuo vecchio deve andare a dormire, è molto tardi...
# - È sempre bello vederti, tesoro. - Anche per me.
# Sei...
# proprio bella.
# Ciao! Sono Anna. Lasciate un messaggio!
# Anna, sono Rosalyn. È quasi mezzogiorno! Dove sei?
# Non oggi, Satana. Non oggi.
# Anna! Oh, grazie al Cielo!
# Non riusciamo a contattare Zora. Tu l'hai sentita?
# No.
# Anna...
# - Tesoro, stai bene? - Sì.
# Ti capisco, è un periodo pesante.
# Anna...
# ci serve una conduttrice.
# - Sei sicura della cintura? - È perfetta.
# - Belle scarpe! - Grazie.
# È ora.
# Come butta, America?
# Sono Anna Bludso, la conduttrice di oggi.
# Se avete visto le pubblicità,
# vi aspettavate una persona un po' più alta,
# una modella, ma...
# scherzone! Vi beccate me!
# Bene, ok, ok...
# Benvenuti a Cult Live!
# Tutti i fan qua fuori stanno andando fuori di testa!
# Vogliono sapere chi è al primo posto!
# Ok. Beh, siamo ai due finalisti.
# Chi ha vinto?
# Che cosa non abbiamo ancora visto?
# Non abbiamo visto "Break U" di The Fellas.
# E con loro mi diverto... a volte.
# Ok! Il video arrivato in seconda posizione nella nostra classifica è...
# "Break U"!
# Il che significa che in prima posizione...
# Aspetta, aspetta! Tutti a Cult sanno
# che Anna è la fan più sfegatata di Sandra,
# perciò abbiamo pensato di fare qualcosa di speciale...
# Ciao, sorella. Ti dispiace?
# E il video in prima posizione è...
# Scusate, The Fellas...
# la mia "I Get It"!
# E... pubblicità!
# Buonanotte, a domani.
# Zora.
# Anna!
# - Ehi. - Ciao, ragazza.
# Wow. Sei stata...
# fantastica.
# Ros, hai visto Zora?
# No, è proprio sparita.
# - L'ho vista affacciata alla finestra. - Sono nel suo ufficio da ore, non è qui.
# Ros, l'ho vista!
# Anna... c'è qualcosa...
# Ros?
# Ros...
# LAVORI IN CORSO PERICOLO - VIETATO ENTRARE
# LAVORI IN CORSO PERICOLO - VIETATO ENTRARE
# Qual è il codice?!
# CODICE PORTA Aiuto! Qualcuno mi aiuti!
# No! No!
# PORTA DI SOLA USCITA DIRIGERSI VERSO L'INGRESSO
# Cazzo!
# Oh! Ma che cazzo?! Dai, amica! Non sono una di loro!
# - Ah, no? - No!
# Che ci facevi di sopra allora?
# Pensavo steste festeggiando! Volevo mescolarmi a voi stronze zombie!
# Brook, togli le extension! Non so quando sei andata da Virgie...
# Da Virgie?! Non ho mica 500 dollari! Non con La'Neka che chiede 250, poi!
# Senti, non posso morire oggi, ok? Non vado in chiesa da 15 anni!
# Anna!
# Cazzo.
# La stronza vuole ammazzarmi!
# Anna, fai fuori la stronza!
# Stronzetta, che stai facendo?
# Ho visto tutti i film horror! Non devi mica controllare che sia morta!
# Quasi ci rimanevo secca!
# Sai cosa?
# Quella stronza fuori di testa aveva gli occhi blu fissi su di te, lo sai?
# Dai, dai, dai, dai...
# Ciao... ciao, ragazza.
# Ciao...
# Hai scordato il cappotto?
# No...
# No...
# Cazzo.
# Cazzo.
# Ti prego, ti prego, ti prego... Ti prego, Dio. C'è qualcuno lassù?
# Ma che cazzo?
# Ok, ok, ok...
# VIETATO FUMARE
# FORMULA DI VIRGIE
# "Albumina porcina."
# PORCINO: AGG., DI PORCO, CHE HA SOMIGLIANZA COL PORCO
# ALBUMINA: PROTEINA SEMPLICE SOLUBILE...
# Sangue di maiale?
# È un fottuto antipasto!
# Adoro i tuoi capelli, ti stanno proprio bene!
# Grazie, mi tirano un po',
# ma spero che il mio ragazzo me li allenti un po' stanotte!
# Scherzo. Mi devono durare.
# Ok, questo era l'ultimo.
# Non ce la faccio più a trasportare le tue cose!
# Hai inscatolato dei mattoni?!
# Ah, prima di dimenticarmene,
# arriverò tardi a cena stasera, devo fare una cosa super segreta.
# Non posso dirtela. Ok, te la dico...
# "Anche adesso, se vedi la ragazza dai capelli di muschio
# passeggiare nel bosco,
# rammenta, quello è solo il suo corpo.
# Le streghe la manovrano a turno."
# "Riguardo al padrone,
# ebbe due eredi maschi
# che presero il controllo delle terre e di tutto ciò che vi cresceva,
# compresi i capelli che parevano muschio sugli alberi.
# Per come la pensavano loro, finché il loro nome rimaneva su quelle terre,
# potevano fare ciò che volevano con qualunque cosa vi nascesse...
# sia che si trattasse di piante...
# che di persone.
# Ciò che cresceva sulle loro terre, il loro papino sosteneva,
# era di loro proprietà.
# E loro erano di proprietà di ciò che vi cresceva."
# Anna.
# Che hai detto?
# Forse arrivo tardi, ho finalmente un appuntamento da Virgie!
# Mi sono proprio rotta di questo cavolo di lisciante!
# Mettimi in testa dei capelli altrui e basta!
# Linda! Linda!
# PER ZORA, VIRGIE, EDNA ED ANNA
#
# Parole inappropriate rilevate: stronzetta, cazzo, fottuto
# Etichetta originale: 0, Nuova etichetta: 2
# --------------------------------------------------------------------------------
# Titolo: filmadulti46.txt
# Testo originale: È un'uniforme da suora, non è vero?
# E ora, cosa vuoi?
# L'altra metà.
# Dammi l'altro assegno.
# Grazie.
# Vattene.
# Sono libera per mezz'ora.
# Ci rivedremo?
# Puoi vedermi stasera al Whip of Leather.
# Arrivederci.
# Mi porti la colazione o cosa?
# Sto arrivando, bello.
# La porti o no?
# Sto arrivando, bello mio.
# E smettila di chiamarmi con nomi stupidi come “bello mio”!
# Ti piaceva.
# "Doppio omicidio in un cimitero d’auto.
# L'assassino ha sparato diversi colpi contro il proprietario, A. Kalman, e un dipendente.
# La polizia sta cercando Al Pereira,
# un ex detective con una cattiva reputazione."
# Sempre nei guai.
# Sai chi è l'autentica vittima?
# - Chi? - Io!
# "La polizia sta cercando l'ex detective Al Pereira, che ha precedenti penali".
# E cosa faremo?
# Non mi interessa quello che farai tu, ma io devo sparire!
# Al, portami con te!
# Al, bello!
# Ciao.
# Ciao, Pereira. Cosa ti va da bere?
# Un numero quattro per favore. Dov'è il bagno?
# In fondo al corridoio, come sempre.
# Ehi, quello non è tuo. Appartiene a un signore che è in bagno.
# Non credo che gli dispiacerà.
# Non ti ho riconosciuto.
# Ecco, metà del mio debito. Avrò il resto molto presto.
# Molto bene, hai capito.
# Ti sarebbe piaciuto di più se i tuoi ragazzi mi avessero preso a calci nelle palle, vero?
# Beh, ovviamente sarebbe stato molto più divertente.
# - Vi sto interrompendo? - No cara.
# Questa è la mia signora.
# Tu non la conosci?
# Questa è Lina, la mia donna.
# È un piacere conoscerti. Credo che ci siamo già incontrati.
# È possibile.
# Vado molto presto a passeggiare al Rio Negro. Forse ci siamo incontrati lì?
# Può essere.
# Spero che ci rivedremo molto presto.
# Anche io.
# - Chi è lui? - Un barbone.
# ...
# --------------------------------------------------------------------------------
# Titolo: YTP_010.txt
# Testo originale: c'era una volta una principessa
# principessissima era rinchiusa in un
# castello sorvegliato da un drago
# incazzato molti cavalieri coraggiosi
# avevano tentato di scoparla
# ma senza successo ella attendeva il
# primo bacio di cesso, sì
# ma cos'è sto telefono porco...
# shaq vive in solitudine facendo il bagno nella merda
# è lì dentro credo
# che buca 3 delegati
# sai cosa può farti quell'essere si
# dietro italy bene gli orchi fanno cose
# peggiori: ti strizzano le palle
# indietro
# [urla]
# io ho un mulo parlante
# su coraggio piccoletto
# io non so parlar...
# lui parla!
# Parole inappropriate rilevate: merda
# Etichetta originale: 0, Nuova etichetta: 2
# --------------------------------------------------------------------------------
# Titolo: YTP_006.txt
# Testo originale: Bing sei felice che oggi andiamo a casa
# di Pando
# [rumore di sparo]
# no
# Bing sei felice che oggi andiamo a
# casa di Pando
# a me non me ne frega un
# cazzo
# vuoi portare un gioco a casa di
# Pando
# sceglierò il trenino
# sei pronto
# quindi ad andare a casa di Pando
# Sì sono
# pronto ad andare a casa di chi
# di Pando
# di chi
# di Pando
# di chi
# di Pando
# ma non avevo capito andassimo a casa di
# Pando a casa di chi
# di Pando
# [urla]
# andiamo a casa di
# Pando
# Ciao Pando
# Ciao Bing
# ho portato un gioco
# che gioco
# [Musica]
# trenino
# e come si gioca col trenino devi fare
# [Musica]
# [Musica]
# così che cos'era che cos'era cosa quel
# buffo ballo Così si gioca col
# [Musica]
# [Musica]
# trenino No non si gioca così sì no sì no
# sì
# puoi sapere com'è il vero rumore del
# treno Com'è il vero rumore del
# [Musica]
# [Musica]
# treno ed è più o meno uguale a come
# faccio
# [Musica]
# io
# [Musica]
# No neanche per il piffero cosa può fare
# questo treno questo treno può fare tutto
# può lavare il cesso no può cucinare flop
# no può condurre Sanremo No questo treno
# non sa F un cazzo Allora inventiamo noi
# un gioco col treno come protagonista
# Sì comunque se non ha fatto il biglietto
# dovrò farle la multa No Sì no Pronto
# Polizia ho un pazzo criminale a bordo
# del mio treno Ma hai chiamato davvero la
# polizia Sì no Quindi lo paghiamo Questo
# biglietto no guardie portatelo via
# signor Bing lei in arresto venga con noi
# ha il diritto di rimanere in silenzio
# qualsiasi cosa dirà potrà essere usata
# contro di lei in tribunale ha diritto a
# un avvocato se non può permettersi un
# avvocato gliene sarà assegnato uno
# d'ufficio aiuto flob che succede Bing
# Pando è cattivo Pando cosa'è successo
# giocavamo col trenino Sì Bing non voleva
# fare il biglietto perché lui è scemo e
# povero e anche non sa come si usa Bing
# poi ha dirottato un'anziana signora
# facendo sì che il marito non la
# ritrovasse mai più inoltre ha anche
# fatto del male e l'ha persino rapita
# Bing e ha deciso volontariamente di
# eludere il pagamento della suddetta
# sanzione amministrativa Sei una
# delusione Bing Non dire così io non sono
# scemo pezzo di merda come mi hai
# chiamato pezzo di
# merda ecco cosa sei Bing uno stupido
# morirai Dietro le
# [Applauso]
# sbarre
# [Applauso]
# ma devo dirti una cosa prima cosa hai
# presente quel barattolo in frigo di
# pesto alle fave che ci ha dato la nostra
# vicina Sì l'ho mangiato proprio oggi ero
# curioso di sapere se aggiungendo del
# antidoto scientifico avesse cambiato
# colore o Sapore quell' antidoto è un
# veleno mortale George non lo sapevo e il
# fatto che l'hai mangiato mi ha fatto
# capire che non ha cambiato né colore né
# sapore George tu mi hai avvelenato
# brutto
# defic Theodor
# Theodor chissà che succede se stacco
# questo
# cavo What the
# [Musica]
# fuck
#
# Parole inappropriate rilevate: merda
# Etichetta originale: 0, Nuova etichetta: 2
# --------------------------------------------------------------------------------
# Titolo: YTP_021.txt
# Testo originale: si potrebbe andare da MD a farsi di AMD
# si potrebbe andare a farsi la spesa
# vengo anch'io
# [Musica]
# ma perché perché diamo peso al peso si
# potrebbe fare la spesa e poniamo grande
# attenzione alla tracciabilità di questo
# gran cazzo
# [Musica]
# [Musica]
# no Ma no dai sto perdendo velocità
# No dai io cane adesso anch'io
# e Sono carichissimo No no dai
# [Musica]
# Allora ti sei deciso a fare Trading
# Allora che cazzo vuoi perché Perché fare
# Trading Company
# da 500 uomini Plus
# [Musica]
# oppure incontrare dei napoletani
# [Musica]
# Ciao ragazzi carbonara per tutti
# ce l'avete questa città
# [Musica]
# lei è Rosy tecnica con la cirrosi la
# prima a portare nelle case italiane la
# [ __ ] e farà contento anche Marcel il
# primo italiano con 100 metri di nicchia
# Ma la più felice sarà la [ __ ] di Rosy
# Susy scegli la [ __ ] scopo nei negozi TIM
# TIM
# ogni cosa che ci circonda nasce da un
# sonda e vive ogni cosa che ci circoncide
# è un sogno il mostro è un viaggio che
# evolve nel tempo trasformando e un nuovo
# mondo e un noi la tecnologia Hybrid è di
# serie su tutta la gamma
# mi scultura mamma
# per te anche
# tu che ti fai la barba anche per lavare
# la barba Dio cane ti meriti l'orgasmo
# [Musica]
# Quest'anno ho selezionato questa nuova
# ricetta di merda per voi 180 grammi di
# cocaina Asiago di
# salsa alle carote nuovi Selection gli
# hamburger McDonald
# [Musica]
# che ti porterà dentro la mafia Ascolta
# la mafia
# prima del 1992 l'Africa era solo
# un'ipotesi
# da tutti conosciuti da tutti scopata
# fino a quando un gruppo di donne e
# uomini straordinari condusse la più
# ostinata orgia per dimostrare
# l'esistenza il maxi sesso
# l'interrogatore vaginali le voci dei
# protagonisti queste Maxim il processo
# che ha sconfitti il processo che ha
# sconfitto la Madonna poverina de Dio
# [Musica]
#
# Parole inappropriate rilevate: merda
# Etichetta originale: 0, Nuova etichetta: 2
# --------------------------------------------------------------------------------
# Titolo: YTP_022.txt
# Testo originale: mai caffè all'italiana non siate sinceri
# i caschi la lingua se non dico il vero
# i caschi laschi di omero
# [Musica]
# basta stronzate sparisci serpente venga
# signora chiedo spillo è una scelta
# sicura
# [Musica]
# se cerca la carne e la cerca italiana la
# scelta migliore è un po illuda buttano è
# una scelta sicura parola di roberto
# carlino lui l'università e campus è una
# scema l'università e campus è una
# stronzata perché è da sempre una merda
# ai la più ampia offerta di frumento puoi
# scegliere tra d'ottocento tutto in
# presenza e da sublim le level e canzoni
# sono sempre disponibili e su su si
# elimini bili e sostieni gli esami dal
# tuo culo chiamano 800 400 410 810 3 300
# e sociali il cazzo il meme scegliti a
# spello le assicurazioni auto il festival
# delle auto il festival delle prostitute
# per la pizza auto ho scelto conte
# puntate punto io appunto series punto it
# quando bisogno solo sempre fatto io è un
# prezzo più basso io non lo fate un po un
# po prima della sottoscrizione sotto soli
# di sms o vivo
#
# Parole inappropriate rilevate: merda
# Etichetta originale: 0, Nuova etichetta: 2
# --------------------------------------------------------------------------------
# Titolo: filmadulti48.txt
# Testo originale: E chi è questo pollo?
# Ehi! Apri! Smetti di giocare! Apri la porta!
# Apri! Apri questa porta! Apri!
# Buona sera.
# Buona sera.
# - Spogliati. - Smettila di dire sciocchezze.
# Spogliati, Al.
# Ehi, è sempre bello vedere volti familiari.
# Mettiti nudo.
# Non posso dire di no ad un amico
# Continua.
# Togli tutto!
# L'hai sentita? Spogliati, figlio di puttana.
# Va bene.
# Ogni cosa!
# Avanti, figlio di puttana.
# Lascia fuori mia madre.
# - Togli tutto! - Lo sto facendo.
# Ci racconterà alcune cose, vero, signor Pereira?
# Non so cosa vuoi.
# Dicci perché hai ucciso Kalman e perché sei venuto qui.
# Attento.
# Se non parli, posso ferire il tuo pappagallino,
# o ficcarlo in te.
# Non so niente.
# Non so niente.
# Cosa sai del mio coinvolgimento con la droga?
# Non so niente!
# Peggio per te.
# Ci divertiremo un po'.
# Bruta, per favore.
# Per favore.
# Stai fermo o ti riempio di buchi.
# Aspetta un attimo, Bruta, aspetta un attimo.
# Colpiscilo forte.
# Forte!
# Più forte.
# Più forte.
# Forte.
# Forte! Forte!
# Figlio di puttana!
# Più forte! Forte!
# Forte. Più forte!
# Più forte! Forte! Forte! Più forte!
# Nessuno ti troverà qui. Mio marito non immaginerebbe mai l'uomo che ha ucciso
# il suo socio Rosenthal è a casa sua.
# Non pensavo che avresti ucciso il dottore così in fretta.
# No.
# - Perché, cosa c'è che non va? - Non abbiamo bisogno di farlo in questo modo.
# Andiamo in un posto più comodo.
# Veni.
# Cosa stai facendo?
# Sarò come una Geisha.
# Ti regalerò il miglior momento della tua vita.
# Non avere fretta. Fare bene l'amore è un'arte.
# Ehi, stai attenta!
# Rilassati.
# Stai attenta.
# Ci vediamo dopo, Matias.
# Credo che sia lui!
# Che ci fa qui a quest'ora?
# Sbrigati, vai in terrazza!
# Sei tu, Gene?
# Non ti aspettavo così presto.
# - Ciao cara. - Ciao.
# Come mai sei venuto così presto?
# non ne potevo più,
# quel baccano rumoroso.
# Ho finito il mio numero e sono tornato a casa.
# Non ti senti bene?
# Non è niente di importante.
# E tu perché sei venuta qui così presto?
# - Ero annoiata. - Anch'io. Non ne posso più.
# Non sopporto quel gruppo di marmocchi. Non un solo uomo.
# Qualche volta
# il pensiero di non essere un vero uomo mi addolora.
# Vedi,
# la vita è molto complicata,
# piena di fragilità.
# Ti adoro.
# Anch'io ti adoro.
# vorrei renderti veramente felice,
# In modo che non sentiresti il bisogno di altri uomini.
# Perdonami per non poter continuare fino alla fine.
# Lo fai meglio di molti altri.
# Vorrei che fossero tutti come te.
# Sai, mi piaci ogni giorno di più.
# Fermatevi!
# Paola,
# che c'è?
# Paola, ascoltami, non è niente.
# Lo so.
# Bello,
# sappi . . . che io
# ti ho amato
# con tutte le mie forze.
# Amore mio, non potevo stare senza vederti ancora.
# Sono venuta ogni mattina, aspettando di vederti apparire,
# in quella tua macchina di merda, che adoro.
# Dobbiamo finire presto così potremo essere liberi.
# Si amore mio.
# Domani stesso.
# Ci sono solo tre persone sulla lista, rimaste in vita.
# Tuo marito, il suo amante e quella signora che chiamano Bruta.
# Hai la forza che serve per finire?
#
# Parole inappropriate rilevate: merda
# Etichetta originale: 0, Nuova etichetta: 2
# --------------------------------------------------------------------------------
# Titolo: filmadulti44.txt
# Testo originale: ♪ Mentre percorro la strada di notte ♪
# ♪ Alla luce del primo mattino ♪
# ♪ Penso a un milione di canzoni che posso sedermi a scrivere ♪
# ♪ Beh, finalmente ho pensato a una bella canzone ♪
# ♪ Ed era proprio ora ♪
# ♪ Spingo sull'acceleratore, parto dalla linea ♪
# ♪ In mente ho il bluegrass ♪
# ♪ Rotolo lungo l'autostrada chilometro dopo chilometro ♪
# ♪ La destinazione uno stato del Nord da qualche parte lungo il confine ♪
# ♪ Beh, il mio viaggio sarebbe più semplice ♪
# ♪ Ad avere tempo a sufficienza ♪
# ♪ Spingo sull'acceleratore, parto dalla linea ♪
# ♪ In mente ho il bluegrass ♪
# ♪ A volte mi lascio trascinare ♪
# ♪ Su quelle vecchie strade di montagna ♪
# ♪ Una chiazza di diesel sul ginocchio, un grosso carico pesante ♪
# ♪ Beh, finalmente ho pensato a una bella canzone ♪
# ♪ Ed era proprio ora ♪
# ♪ Spingo sull'acceleratore, parto dalla linea ♪
# ♪ In mente ho il bluegrass ♪
# ♪ Rotolo lungo l'autostrada chilometro dopo chilometro ♪
# ♪ La destinazione uno stato del Nord da qualche parte lungo il confine ♪
# ♪ Beh, il mio viaggio sarebbe più semplice ♪
# ♪ Ad avere tempo a sufficienza ♪
# ♪ Spingo sull'acceleratore, parto dalla linea ♪
# Non potete aver mai visto nulla di simile.
# Come ti senti, ora?
# Continua a peggiorare.
# Mi dispiace.
# Miller, credo sia meglio ve ne andiate, ora.
# Già... beh, grazie, dottore. Grazie, signorina Hawkins.
# Miller, sai, credo si siano avverate le nostre paure peggiori.
# Il meteorite non ha ucciso quelle persone...
# Le ha trasformate in un branco di dannati mostri.
# E pensare che tutte quelle persone sono lì fuori...
# - A caccia di un alligatore. - Dannazione!
# - Dove ve ne andate?! - Andiamo!
# Merda, aspettatemi!
# Ragazza, cosa credi di fare, lì in acqua?
# In che senso?
# Non hai sentito di quell'alligatore sanguinario che tutti vanno cercando?
# Ma va', non ci sono più alligatori qui intorno.
# Così dicevano...
# Lo sceriffo dice che ce n'è uno bello grande.
# Beh, non preoccupatevi per me. Pensate a non spararvi l'un l'altro.
# Andiamo, Carl. Le donne qui intorno sono pazze.
# - Ecco perché non se ne vedono, in giro. - Immagino di sì.
# - Papà! - Emmett!
# Sali sul camion, forza!
# Andiamocene via da qui.
# Avete visto quelle cose?
# Accidenti, è molto più grave di quanto credessi.
# Avevano un aspetto orribile!
# Sono stato fortunato a vedervi arrivare.
# Ho sparato a quei bastardi due volte prima che prendessero la ragazza...
# - Ma non è servito a niente. - Una ragazza? Sai chi era?
# Non proprio.
# Mi ha sorpreso vedere quelle cose, qualunque cosa fossero.
# Erano i tori, papà!
# Vuoi scherzare!
# Sì, quello che dobbiamo fare ora è scoprire come ucciderli.
# - Ma sono già morti, Miller. - Andiamo a chiamare lo sceriffo.
# Oh, vuoi scherzare!
# Hai ragione, Haze.
# Quel ragazzo, Kowalski, è lo sceriffo più pigro che abbiamo mai avuto.
# Il punto è che dobbiamo decidere un piano d'azione.
# - Possiamo andare a casa e lavoraci lì. - Ehi, buona idea.
# Se ricordo bene, non è molto lontana da qui.
# Circa un chilometro e mezzo, immagino.
# Sapete, questa storia è pazzesca.
# Voglio dire, nessuno crederebbe mai a una storia del genere.
# Ho provato a scoraggiare gli Yankees a riversarsi qui...
# Come fosse il 4 Luglio.
# Sì, e succhiano anche il sangue della nostra gente.
# E non finisce qui.
# Potrebbe rivelarsi anche peggio di quanto credessimo.
# Che vuoi dire, Miller?
# Beh, ammesso che fosse un meteorite che resuscita i morti...
# Potrebbe avere lo stesso effetto mutante su altre forme di vita.
# Diavolo, forse è meglio dirigerci in Georgia...
# E dimenticarci di combattere questa cosa.
# Non credo abbiamo molta scelta, guardate lassù.
# Ehi, sembra l'auto del dottore. È l'auto del dottore!
# Ehi, guarda lì a lato.
# Il dottore?
# Tom, Tom!
# Tom!
# Tom!
# Tom!
# Miller!
# Più avanti c'è una casa!
# Ehi, ragazzi, guardate qui! È il dottor Ellerbe!
# - È vivo? - Sì, ma ha una brutta ferita!
# Restate qui.
# Ehi dottore, vieni con me.
# Oh mio dio!
# <i>Papi</i>! <i>Papi</i>!
# - Lascia perdere, Shawn! - <i>Papi</i>! <i>Papi</i>!
# Ehi, aprite per amor di dio! Forza!
# - Barrichiamo la porta. - Prendi il letto.
# - Controllerò stanze e finestre. - OK, io rimango qui.
# Tom! Tom!
# Tom!
# No...!
# - Shawn! - Oh mio dio!
# Aiutatemi, vi prego!
# Sentite, per ora siamo al sicuro, ma mi chiedo per quanto!
# Avremmo dovuto andare in Georgia.
# Queste finestre non li terranno a bada ancora per molto!
# Stanno solo... stanno solo aspettando.
# Se ne stanno lì in piedi.
# Cosa possiamo fare...?
# - Proviamo ad arrivare alla macchina. - No!
# Sentite...
# Posso tenerli a bada con questo mentre voi uscite dal retro.
# - No, Miller, troppo pericoloso. - Non abbiamo scelta!
# - Dovete scappare! - OK, OK, ma sta' attento.
# Non preoccupatevi per me. Andatevene e basta! Prendete questo.
# Sei pronta?
# Da questa parte.
# Rialzati, forza.
# Una barca!
# Cosa fate lì fuori?
# Cacciate rane?
# - Forse cacciano rospi assassini! - Oh, andiamo... Campbell!
# Avete visto il guardiacaccia, per caso?
# È morto.
# Corman!
# Cosa andate sognando?
# Sembra un vicolo cieco qui, sceriffo.
# Già...
# Questi giornalisti sono degli sciocchi.
# Sciocchi sognatori.
# Andiamo, Campbell.
# ♪ Ora ricordo le cose come stavano ♪
# ♪ Un paio di anni fa ♪
# ♪ Sembrava sempre che quell'attrito ♪
# ♪ Arrivasse sempre ♪
# ♪ E oh, quella mia scintilla, signore ♪
# ♪ È stata quella ad accendere la fiamma ♪
# ♪ Ha causato molto dolore ♪
# ♪ Un sacco, di dolore ♪
# ♪ Quanto mi manca casa ♪
# ♪ Sento mio figlio dire ♪
# ♪ Papà, non piangere ♪
# ♪ Possiamo tornare anche oggi ♪
# ♪ Faremo in modo che mamma ti ami ♪
# ♪ Così non sarai solo ♪
# ♪ Oh papà, oh, caro papà ♪
# ♪ Oh, quanto mi manca casa ♪
# ♪ Cosa ti ha spinto a fare quelle cose ♪
# ♪ E ferirmi, come hai fatto tu ♪
# ♪ Quando l'unico a cui stai facendo del male ♪
# ♪ È l'amore del nostro caro ragazzo ♪
# ♪ Oh, ma il tempo ♪
#
# Parole inappropriate rilevate: merda
# Etichetta originale: 0, Nuova etichetta: 2
# --------------------------------------------------------------------------------

# %% [markdown]
# # mbert cased eng

# %%
import os
import numpy as np
import torch
from torch.utils.data import Dataset
from transformers import BertTokenizer, BertForSequenceClassification, Trainer, TrainingArguments
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, classification_report

# Montaggio di Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Percorso della cartella dei dati su Google Drive
data_path = '/content/drive/My Drive/Esperimento_eng'

# Tokenizer di mBERT (cased)
tokenizer = BertTokenizer.from_pretrained('bert-base-multilingual-cased')

# Classe Dataset
class TextDataset(Dataset):
    def __init__(self, texts, labels, tokenizer):
        self.encodings = tokenizer(texts, truncation=True, padding=True, max_length=512)
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.labels)

# Funzione per calcolare le metriche
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    return {"accuracy": accuracy_score(labels, predictions)}

# Funzione per caricare i dati
def load_data(data_path):
    texts, labels, titles = [], [], []
    label_dict = {'0_bambini': 0, '1_ragazzi': 1, '2_adulti': 2}
    for label, index in label_dict.items():
        folder_path = os.path.join(data_path, label)
        for filename in os.listdir(folder_path):
            with open(os.path.join(folder_path, filename), 'r', encoding='utf-8') as file:
                texts.append(file.read())
                labels.append(index)
                titles.append(filename)  # Salva il nome del file come titolo
    return texts, labels, titles

# Caricamento dei dati
texts, labels, titles = load_data(data_path)

# Inizializza dizionari per raccogliere i risultati medi
precision_sum = {class_name: 0 for class_name in ['0_bambini', '1_ragazzi', '2_adulti']}
recall_sum = {class_name: 0 for class_name in ['0_bambini', '1_ragazzi', '2_adulti']}
f1_sum = {class_name: 0 for class_name in ['0_bambini', '1_ragazzi', '2_adulti']}
support_sum = {class_name: 0 for class_name in ['0_bambini', '1_ragazzi', '2_adulti']}

accuracy_per_fold = []
macro_avg_precision_sum, macro_avg_recall_sum, macro_avg_f1_sum = 0, 0, 0
weighted_avg_precision_sum, weighted_avg_recall_sum, weighted_avg_f1_sum = 0, 0, 0

fold = 1

# K-fold cross-validation
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

for train_index, test_index in kfold.split(texts):
    print(f'\nFold {fold}')
    fold += 1

    # Divisione in train e test per il fold corrente
    train_texts = [texts[i] for i in train_index]
    test_texts = [texts[i] for i in test_index]
    train_labels = [labels[i] for i in train_index]
    test_labels = [labels[i] for i in test_index]

    # Creazione dei dataset
    train_dataset = TextDataset(train_texts, train_labels, tokenizer)
    test_dataset = TextDataset(test_texts, test_labels, tokenizer)

    # Configurazione dei parametri di training
    training_args = TrainingArguments(
        output_dir='./results',
        num_train_epochs=3,
        per_device_train_batch_size=8,
        per_device_eval_batch_size=16,
        warmup_steps=500,
        weight_decay=0.01,
        logging_dir='./logs',
        logging_steps=10,
        evaluation_strategy="epoch",
        save_strategy="epoch",
        load_best_model_at_end=True
    )

    # Inizializzazione del modello e del trainer
    model = BertForSequenceClassification.from_pretrained('bert-base-multilingual-cased', num_labels=3)

    trainer = Trainer(
        model=model,
        args=training_args,
        train_dataset=train_dataset,
        eval_dataset=test_dataset,
        compute_metrics=compute_metrics
    )

    # Training del modello
    trainer.train()

    # Valutazione sul test del fold corrente
    predictions = trainer.predict(test_dataset)
    predicted_labels = np.argmax(predictions.predictions, axis=1)

    # Calcolo del classification report
    target_names = ['0_bambini', '1_ragazzi', '2_adulti']
    report = classification_report(test_labels, predicted_labels, target_names=target_names, output_dict=True)

    # Stampa del classification report formattato
    print("\t\tPrecision\tRecall\tF1-score\tSupport")
    for class_name in target_names:
        class_report = report[class_name]
        print(f"{class_name}\t{class_report['precision']:.2f}\t\t{class_report['recall']:.2f}\t{class_report['f1-score']:.2f}\t\t{class_report['support']}")

    print("\n\t\t\tSupport")
    print(f"Accuracy\t\t{report['accuracy']:.2f}\t{len(test_labels)}")
    print(f"Macro avg\t{report['macro avg']['precision']:.2f}\t\t{report['macro avg']['recall']:.2f}\t{report['macro avg']['f1-score']:.2f}\t\t{len(test_labels)}")
    print(f"Weighted avg\t{report['weighted avg']['precision']:.2f}\t\t{report['weighted avg']['recall']:.2f}\t{report['weighted avg']['f1-score']:.2f}\t\t{len(test_labels)}")

    # Somma i valori di precision, recall, f1 e support per ogni classe
    for class_name in target_names:
        precision_sum[class_name] += report[class_name]['precision']
        recall_sum[class_name] += report[class_name]['recall']
        f1_sum[class_name] += report[class_name]['f1-score']
        support_sum[class_name] += report[class_name]['support']

    # Somma per macro avg e weighted avg
    macro_avg_precision_sum += report['macro avg']['precision']
    macro_avg_recall_sum += report['macro avg']['recall']
    macro_avg_f1_sum += report['macro avg']['f1-score']

    weighted_avg_precision_sum += report['weighted avg']['precision']
    weighted_avg_recall_sum += report['weighted avg']['recall']
    weighted_avg_f1_sum += report['weighted avg']['f1-score']

    # Aggiungi l'accuratezza alla lista per calcolare la media finale
    accuracy_per_fold.append(report['accuracy'])

# Media dei risultati per ogni classe
print("\nRisultati medi su 5 fold:")
print("\t\tPrecision\tRecall\tF1-score\tSupport")
for class_name in target_names:
    print(f"{class_name}\t{(precision_sum[class_name]/5):.2f}\t\t{(recall_sum[class_name]/5):.2f}\t{(f1_sum[class_name]/5):.2f}\t\t{support_sum[class_name]}")

# Media dei risultati per ogni classe
print("\nRisultati medi su 5 fold:")
print("\t\tPrecision\tRecall\tF1-score\tSupport")
for class_name in target_names:
    print(f"{class_name}\t{(precision_sum[class_name]/5):.2f}\t\t{(recall_sum[class_name]/5):.2f}\t{(f1_sum[class_name]/5):.2f}\t\t{support_sum[class_name]}")

# Media per Macro avg e Weighted avg
print(f"\nMacro avg\t{(macro_avg_precision_sum/5):.2f}\t\t{(macro_avg_recall_sum/5):.2f}\t{(macro_avg_f1_sum/5):.2f}")
print(f"Weighted avg\t{(weighted_avg_precision_sum/5):.2f}\t\t{(weighted_avg_recall_sum/5):.2f}\t{(weighted_avg_f1_sum/5):.2f}")

# Stampa dell'accuratezza media finale
print(f"\nAccuratezza media su 5 fold: {np.mean(accuracy_per_fold):.2f}")
# Out:
# Mounted at /content/drive
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/996k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/625 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Fold 1
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/714M [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='135' max='135' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [135/135 02:18, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.054500</td>
#       <td>0.866264</td>
#       <td>0.577778</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.475300</td>
#       <td>0.496270</td>
#       <td>0.700000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.305800</td>
#       <td>0.363715</td>
#       <td>0.833333</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	1.00		1.00	1.00		41.0
# 1_ragazzi	0.64		0.73	0.68		22.0
# 2_adulti	0.75		0.67	0.71		27.0
#
# 			Support
# Accuracy		0.83	90
# Macro avg	0.80		0.80	0.80		90
# Weighted avg	0.84		0.83	0.83		90
#
# Fold 2
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='135' max='135' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [135/135 02:21, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.007000</td>
#       <td>0.882665</td>
#       <td>0.775281</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.478600</td>
#       <td>0.452766</td>
#       <td>0.797753</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.533100</td>
#       <td>0.305367</td>
#       <td>0.876404</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	1.00		1.00	1.00		44.0
# 1_ragazzi	0.70		1.00	0.83		26.0
# 2_adulti	1.00		0.42	0.59		19.0
#
# 			Support
# Accuracy		0.88	89
# Macro avg	0.90		0.81	0.81		89
# Weighted avg	0.91		0.88	0.86		89
#
# Fold 3
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='135' max='135' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [135/135 02:20, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.018700</td>
#       <td>0.905619</td>
#       <td>0.752809</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.502900</td>
#       <td>0.538341</td>
#       <td>0.786517</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.378000</td>
#       <td>0.383129</td>
#       <td>0.820225</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	1.00		1.00	1.00		38.0
# 1_ragazzi	0.67		1.00	0.80		32.0
# 2_adulti	1.00		0.16	0.27		19.0
#
# 			Support
# Accuracy		0.82	89
# Macro avg	0.89		0.72	0.69		89
# Weighted avg	0.88		0.82	0.77		89
#
# Fold 4
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='135' max='135' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [135/135 02:19, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.017700</td>
#       <td>0.935777</td>
#       <td>0.460674</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.378200</td>
#       <td>0.367005</td>
#       <td>0.865169</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.396200</td>
#       <td>0.294872</td>
#       <td>0.887640</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	1.00		1.00	1.00		40.0
# 1_ragazzi	0.77		1.00	0.87		33.0
# 2_adulti	1.00		0.38	0.55		16.0
#
# 			Support
# Accuracy		0.89	89
# Macro avg	0.92		0.79	0.80		89
# Weighted avg	0.91		0.89	0.87		89
#
# Fold 5
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='135' max='135' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [135/135 02:17, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.027100</td>
#       <td>0.901314</td>
#       <td>0.595506</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.515800</td>
#       <td>0.487314</td>
#       <td>0.820225</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.369400</td>
#       <td>0.274374</td>
#       <td>0.910112</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	1.00		1.00	1.00		37.0
# 1_ragazzi	0.82		0.97	0.89		33.0
# 2_adulti	0.92		0.63	0.75		19.0
#
# 			Support
# Accuracy		0.91	89
# Macro avg	0.91		0.87	0.88		89
# Weighted avg	0.92		0.91	0.91		89
#
# Risultati medi su 5 fold:
# 		Precision	Recall	F1-score	Support
# 0_bambini	1.00		1.00	1.00		200.0
# 1_ragazzi	0.72		0.94	0.81		146.0
# 2_adulti	0.93		0.45	0.57		100.0
#
# Risultati medi su 5 fold:
# 		Precision	Recall	F1-score	Support
# 0_bambini	1.00		1.00	1.00		200.0
# 1_ragazzi	0.72		0.94	0.81		146.0
# 2_adulti	0.93		0.45	0.57		100.0
#
# Macro avg	0.88		0.80	0.80
# Weighted avg	0.89		0.87	0.85
#
# Accuratezza media su 5 fold: 0.87

# %% [markdown]
# # mbert cased eng badwords

# %%
import os
import numpy as np
import torch
from torch.utils.data import Dataset
from transformers import BertTokenizer, BertForSequenceClassification, Trainer, TrainingArguments
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, classification_report
from nltk.tokenize import word_tokenize
import nltk

# Montaggio di Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Scarica risorse di NLTK per la tokenizzazione
nltk.download('punkt')

# Percorso della cartella dei dati su Google Drive
data_path = '/content/drive/My Drive/Esperimento_eng'

# Caricamento delle bad words in italiano
bad_words_path = '/content/drive/My Drive/badwords_eng_new.txt'

try:
    with open(bad_words_path, 'r', encoding='utf-8') as file:
        bad_words = set(line.strip() for line in file)
except Exception as e:
    print(f"Error loading bad words: {e}")
    bad_words = set()  # Definisci un set vuoto in caso di errore per evitare crash

# Funzione per rilevare bad words
def detect_bad_words(text, bad_words):
    words = set(word_tokenize(text.lower()))  # Tokenizza e abbassa il testo
    return words.intersection(bad_words)

# Tokenizer di mBERT (cased)
tokenizer = BertTokenizer.from_pretrained('bert-base-multilingual-cased')

# Classe Dataset
class TextDataset(Dataset):
    def __init__(self, texts, labels, tokenizer):
        self.encodings = tokenizer(texts, truncation=True, padding=True, max_length=512)
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.labels)

# Funzione per calcolare le metriche
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    return {"accuracy": accuracy_score(labels, predictions)}

# Funzione per caricare i dati
def load_data(data_path):
    texts, labels, titles = [], [], []
    label_dict = {'0_bambini': 0, '1_ragazzi': 1, '2_adulti': 2}
    for label, index in label_dict.items():
        folder_path = os.path.join(data_path, label)
        for filename in os.listdir(folder_path):
            with open(os.path.join(folder_path, filename), 'r', encoding='utf-8') as file:
                texts.append(file.read())
                labels.append(index)
                titles.append(filename)  # Salva il nome del file come titolo
    return texts, labels, titles

# Caricamento dei dati
texts, labels, titles = load_data(data_path)

# Inizializza dizionari per raccogliere i risultati medi
precision_sum = {class_name: 0 for class_name in ['0_bambini', '1_ragazzi', '2_adulti']}
recall_sum = {class_name: 0 for class_name in ['0_bambini', '1_ragazzi', '2_adulti']}
f1_sum = {class_name: 0 for class_name in ['0_bambini', '1_ragazzi', '2_adulti']}
support_sum = {class_name: 0 for class_name in ['0_bambini', '1_ragazzi', '2_adulti']}

accuracy_per_fold = []
macro_avg_precision_sum, macro_avg_recall_sum, macro_avg_f1_sum = 0, 0, 0
weighted_avg_precision_sum, weighted_avg_recall_sum, weighted_avg_f1_sum = 0, 0, 0

# Lista per memorizzare i testi in cui l'etichetta è cambiata
texts_with_label_changes = []

fold = 1

# K-fold cross-validation
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

for train_index, test_index in kfold.split(texts):
    print(f'\nFold {fold}')
    fold += 1

    # Divisione in train e test per il fold corrente
    train_texts = [texts[i] for i in train_index]
    test_texts = [texts[i] for i in test_index]
    train_labels = [labels[i] for i in train_index]
    test_labels = [labels[i] for i in test_index]

    # Creazione dei dataset
    train_dataset = TextDataset(train_texts, train_labels, tokenizer)
    test_dataset = TextDataset(test_texts, test_labels, tokenizer)

    # Configurazione dei parametri di training
    training_args = TrainingArguments(
        output_dir='./results',
        num_train_epochs=3,
        per_device_train_batch_size=8,
        per_device_eval_batch_size=16,
        warmup_steps=500,
        weight_decay=0.01,
        logging_dir='./logs',
        logging_steps=10,
        evaluation_strategy="epoch",
        save_strategy="epoch",
        load_best_model_at_end=True
    )

    # Inizializzazione del modello e del trainer
    model = BertForSequenceClassification.from_pretrained('bert-base-multilingual-cased', num_labels=3)

    trainer = Trainer(
        model=model,
        args=training_args,
        train_dataset=train_dataset,
        eval_dataset=test_dataset,
        compute_metrics=compute_metrics
    )

    # Training del modello
    trainer.train()

    # Valutazione sul test del fold corrente
    predictions = trainer.predict(test_dataset)
    predicted_labels = np.argmax(predictions.predictions, axis=1)

    # Aggiungi il controllo delle bad words
    adjusted_labels = []
    detected_bad_words_list = []

    for i, text in enumerate(test_texts):
        detected_bad_words = detect_bad_words(text, bad_words)
        original_label = predicted_labels[i]
        if original_label == 0 and detected_bad_words:
            adjusted_labels.append(2)  # Cambia l'etichetta in "adulti" se ci sono bad words
            detected_bad_words_list.append((titles[test_index[i]], detected_bad_words))

            # Memorizza i testi modificati
            texts_with_label_changes.append({
                "Title": titles[test_index[i]],
                "Original Text": text,
                "Detected Bad Words": list(detected_bad_words),
                "Original Label": original_label,  # Etichetta originale (0 = bambini)
                "New Label": 2  # Nuova etichetta (2 = adulti)
            })
        else:
            adjusted_labels.append(original_label)

    # Calcolo del classification report
    target_names = ['0_bambini', '1_ragazzi', '2_adulti']
    report = classification_report(test_labels, adjusted_labels, target_names=target_names, output_dict=True)

    # Stampa del classification report formattato
    print("\t\tPrecision\tRecall\tF1-score\tSupport")
    for class_name in target_names:
        class_report = report[class_name]
        print(f"{class_name}\t{class_report['precision']:.2f}\t\t{class_report['recall']:.2f}\t{class_report['f1-score']:.2f}\t\t{class_report['support']}")

    print("\n\t\t\tSupport")
    print(f"Accuracy\t\t{report['accuracy']:.2f}\t{len(test_labels)}")
    print(f"Macro avg\t{report['macro avg']['precision']:.2f}\t\t{report['macro avg']['recall']:.2f}\t{report['macro avg']['f1-score']:.2f}\t\t{len(test_labels)}")
    print(f"Weighted avg\t{report['weighted avg']['precision']:.2f}\t\t{report['weighted avg']['recall']:.2f}\t{report['weighted avg']['f1-score']:.2f}\t\t{len(test_labels)}")

    # Somma i valori di precision, recall, f1 e support per ogni classe
    for class_name in target_names:
        precision_sum[class_name] += report[class_name]['precision']
        recall_sum[class_name] += report[class_name]['recall']
        f1_sum[class_name] += report[class_name]['f1-score']
        support_sum[class_name] += report[class_name]['support']

    # Somma per macro avg e weighted avg
    macro_avg_precision_sum += report['macro avg']['precision']
    macro_avg_recall_sum += report['macro avg']['recall']
    macro_avg_f1_sum += report['macro avg']['f1-score']

    weighted_avg_precision_sum += report['weighted avg']['precision']
    weighted_avg_recall_sum += report['weighted avg']['recall']
    weighted_avg_f1_sum += report['weighted avg']['f1-score']

        # Aggiungi l'accuratezza alla lista per calcolare la media finale
    accuracy_per_fold.append(report['accuracy'])

        # Stampa i testi in cui sono state rilevate bad words
    if detected_bad_words_list:
        print(f"Bad words rilevate nel fold {fold - 1}:")
        for title, bad_words in detected_bad_words_list:
            print(f"Titolo: {title}, Bad words: {bad_words}")

# Media dei risultati per ogni classe
print("\nRisultati medi su 5 fold:")
print("\t\tPrecision\tRecall\tF1-score\tSupport")
for class_name in target_names:
    print(f"{class_name}\t{(precision_sum[class_name]/5):.2f}\t\t{(recall_sum[class_name]/5):.2f}\t{(f1_sum[class_name]/5):.2f}\t\t{support_sum[class_name]}")

# Media per Macro avg e Weighted avg
print(f"\nMacro avg\t{(macro_avg_precision_sum/5):.2f}\t\t{(macro_avg_recall_sum/5):.2f}\t{(macro_avg_f1_sum/5):.2f}")
print(f"Weighted avg\t{(weighted_avg_precision_sum/5):.2f}\t\t{(weighted_avg_recall_sum/5):.2f}\t{(weighted_avg_f1_sum/5):.2f}")

# Stampa dell'accuratezza media finale
print(f"\nAccuratezza media su 5 fold: {np.mean(accuracy_per_fold):.2f}")

# Stampa dei testi in cui l'etichetta è stata cambiata a causa delle bad words
if texts_with_label_changes:
    print(f"\nTesti con cambiamento di etichetta a causa di bad words ({len(texts_with_label_changes)} testi):")
    for item in texts_with_label_changes:
        print(f"Titolo: {item['Title']}")
        print(f"Testo originale: {item['Original Text']}")
        print(f"Parole inappropriate rilevate: {', '.join(item['Detected Bad Words'])}")
        print(f"Etichetta originale: {item['Original Label']}, Nuova etichetta: {item['New Label']}")
        print("-" * 80)
# Out:
# Mounted at /content/drive
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/996k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/625 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Fold 1
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/714M [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='135' max='135' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [135/135 02:14, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.038900</td>
#       <td>1.004670</td>
#       <td>0.622222</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.420500</td>
#       <td>0.491652</td>
#       <td>0.711111</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.256500</td>
#       <td>0.401443</td>
#       <td>0.833333</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	1.00		1.00	1.00		41.0
# 1_ragazzi	0.65		0.68	0.67		22.0
# 2_adulti	0.73		0.70	0.72		27.0
#
# 			Support
# Accuracy		0.83	90
# Macro avg	0.79		0.80	0.79		90
# Weighted avg	0.83		0.83	0.83		90
#
# Fold 2
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='135' max='135' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [135/135 02:26, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.007000</td>
#       <td>0.882665</td>
#       <td>0.775281</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.478600</td>
#       <td>0.452766</td>
#       <td>0.797753</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.533100</td>
#       <td>0.305367</td>
#       <td>0.876404</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	1.00		1.00	1.00		44.0
# 1_ragazzi	0.70		1.00	0.83		26.0
# 2_adulti	1.00		0.42	0.59		19.0
#
# 			Support
# Accuracy		0.88	89
# Macro avg	0.90		0.81	0.81		89
# Weighted avg	0.91		0.88	0.86		89
#
# Fold 3
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='135' max='135' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [135/135 02:20, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.018700</td>
#       <td>0.905619</td>
#       <td>0.752809</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.502900</td>
#       <td>0.538341</td>
#       <td>0.786517</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.378000</td>
#       <td>0.383129</td>
#       <td>0.820225</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	1.00		1.00	1.00		38.0
# 1_ragazzi	0.67		1.00	0.80		32.0
# 2_adulti	1.00		0.16	0.27		19.0
#
# 			Support
# Accuracy		0.82	89
# Macro avg	0.89		0.72	0.69		89
# Weighted avg	0.88		0.82	0.77		89
#
# Fold 4
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='135' max='135' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [135/135 02:21, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.017700</td>
#       <td>0.935777</td>
#       <td>0.460674</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.378200</td>
#       <td>0.367005</td>
#       <td>0.865169</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.396200</td>
#       <td>0.294872</td>
#       <td>0.887640</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	1.00		1.00	1.00		40.0
# 1_ragazzi	0.77		1.00	0.87		33.0
# 2_adulti	1.00		0.38	0.55		16.0
#
# 			Support
# Accuracy		0.89	89
# Macro avg	0.92		0.79	0.80		89
# Weighted avg	0.91		0.89	0.87		89
#
# Fold 5
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='135' max='135' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [135/135 02:17, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.027100</td>
#       <td>0.901314</td>
#       <td>0.595506</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.515800</td>
#       <td>0.487314</td>
#       <td>0.820225</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.369400</td>
#       <td>0.274374</td>
#       <td>0.910112</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	1.00		1.00	1.00		37.0
# 1_ragazzi	0.82		0.97	0.89		33.0
# 2_adulti	0.92		0.63	0.75		19.0
#
# 			Support
# Accuracy		0.91	89
# Macro avg	0.91		0.87	0.88		89
# Weighted avg	0.92		0.91	0.91		89
#
# Risultati medi su 5 fold:
# 		Precision	Recall	F1-score	Support
# 0_bambini	1.00		1.00	1.00		200.0
# 1_ragazzi	0.72		0.93	0.81		146.0
# 2_adulti	0.93		0.46	0.58		100.0
#
# Macro avg	0.88		0.80	0.80
# Weighted avg	0.89		0.87	0.85
#
# Accuratezza media su 5 fold: 0.87

# %% [markdown]
# # BERT

# %% [markdown]
# # bert uncased ita

# %%
import os
import numpy as np
import torch
from torch.utils.data import Dataset
from transformers import BertTokenizer, BertForSequenceClassification, Trainer, TrainingArguments
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, classification_report

# Montaggio di Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Percorso della cartella dei dati su Google Drive
data_path = '/content/drive/My Drive/esperimento'

# Tokenizer di BERT (inglese)
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# Classe Dataset
class TextDataset(Dataset):
    def __init__(self, texts, labels, tokenizer):
        self.encodings = tokenizer(texts, truncation=True, padding=True, max_length=512)
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.labels)

# Funzione per calcolare le metriche
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    return {"accuracy": accuracy_score(labels, predictions)}

# Funzione per caricare i dati
def load_data(data_path):
    texts, labels, titles = [], [], []
    label_dict = {'0_bambini': 0, '1_ragazzi': 1, '2_adulti': 2}
    for label, index in label_dict.items():
        folder_path = os.path.join(data_path, label)
        for filename in os.listdir(folder_path):
            with open(os.path.join(folder_path, filename), 'r', encoding='utf-8') as file:
                texts.append(file.read())
                labels.append(index)
                titles.append(filename)  # Salva il nome del file come titolo
    return texts, labels, titles

# Caricamento dei dati
texts, labels, titles = load_data(data_path)

# Inizializza dizionari per raccogliere i risultati medi
precision_sum = {class_name: 0 for class_name in ['0_bambini', '1_ragazzi', '2_adulti']}
recall_sum = {class_name: 0 for class_name in ['0_bambini', '1_ragazzi', '2_adulti']}
f1_sum = {class_name: 0 for class_name in ['0_bambini', '1_ragazzi', '2_adulti']}
support_sum = {class_name: 0 for class_name in ['0_bambini', '1_ragazzi', '2_adulti']}

accuracy_per_fold = []
macro_avg_precision_sum, macro_avg_recall_sum, macro_avg_f1_sum = 0, 0, 0
weighted_avg_precision_sum, weighted_avg_recall_sum, weighted_avg_f1_sum = 0, 0, 0

fold = 1

# K-fold cross-validation
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

for train_index, test_index in kfold.split(texts):
    print(f'\nFold {fold}')
    fold += 1

    # Divisione in train e test per il fold corrente
    train_texts = [texts[i] for i in train_index]
    test_texts = [texts[i] for i in test_index]
    train_labels = [labels[i] for i in train_index]
    test_labels = [labels[i] for i in test_index]

    # Creazione dei dataset
    train_dataset = TextDataset(train_texts, train_labels, tokenizer)
    test_dataset = TextDataset(test_texts, test_labels, tokenizer)

    # Configurazione dei parametri di training
    training_args = TrainingArguments(
        output_dir='./results',
        num_train_epochs=3,
        per_device_train_batch_size=8,
        per_device_eval_batch_size=16,
        warmup_steps=500,
        weight_decay=0.01,
        logging_dir='./logs',
        logging_steps=10,
        evaluation_strategy="epoch",
        save_strategy="epoch",
        load_best_model_at_end=True
    )

    # Inizializzazione del modello e del trainer
    model = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=3)

    trainer = Trainer(
        model=model,
        args=training_args,
        train_dataset=train_dataset,
        eval_dataset=test_dataset,
        compute_metrics=compute_metrics
    )

    # Training del modello
    trainer.train()

    # Valutazione sul test del fold corrente
    predictions = trainer.predict(test_dataset)
    predicted_labels = np.argmax(predictions.predictions, axis=1)

    # Calcolo del classification report
    target_names = ['0_bambini', '1_ragazzi', '2_adulti']
    report = classification_report(test_labels, predicted_labels, target_names=target_names, output_dict=True)

    # Stampa del classification report formattato
    print("\t\tPrecision\tRecall\tF1-score\tSupport")
    for class_name in target_names:
        class_report = report[class_name]
        print(f"{class_name}\t{class_report['precision']:.2f}\t\t{class_report['recall']:.2f}\t{class_report['f1-score']:.2f}\t\t{class_report['support']}")

    print("\n\t\t\tSupport")
    print(f"Accuracy\t\t{report['accuracy']:.2f}\t{len(test_labels)}")
    print(f"Macro avg\t{report['macro avg']['precision']:.2f}\t\t{report['macro avg']['recall']:.2f}\t{report['macro avg']['f1-score']:.2f}\t\t{len(test_labels)}")
    print(f"Weighted avg\t{report['weighted avg']['precision']:.2f}\t\t{report['weighted avg']['recall']:.2f}\t{report['weighted avg']['f1-score']:.2f}\t\t{len(test_labels)}")

    # Somma i valori di precision, recall, f1 e support per ogni classe
    for class_name in target_names:
        precision_sum[class_name] += report[class_name]['precision']
        recall_sum[class_name] += report[class_name]['recall']
        f1_sum[class_name] += report[class_name]['f1-score']
        support_sum[class_name] += report[class_name]['support']

    # Somma per macro avg e weighted avg
    macro_avg_precision_sum += report['macro avg']['precision']
    macro_avg_recall_sum += report['macro avg']['recall']
    macro_avg_f1_sum += report['macro avg']['f1-score']

    weighted_avg_precision_sum += report['weighted avg']['precision']
    weighted_avg_recall_sum += report['weighted avg']['recall']
    weighted_avg_f1_sum += report['weighted avg']['f1-score']

    # Aggiungi l'accuratezza alla lista per calcolare la media finale
    accuracy_per_fold.append(report['accuracy'])

# Media dei risultati per ogni classe
print("\nRisultati medi su 5 fold:")
print("\t\tPrecision\tRecall\tF1-score\tSupport")
for class_name in target_names:
    print(f"{class_name}\t{(precision_sum[class_name]/5):.2f}\t\t{(recall_sum[class_name]/5):.2f}\t{(f1_sum[class_name]/5):.2f}\t\t{support_sum[class_name]}")

# Media per Macro avg e Weighted avg
print(f"\nMacro avg\t{(macro_avg_precision_sum/5):.2f}\t\t{(macro_avg_recall_sum/5):.2f}\t{(macro_avg_f1_sum/5):.2f}")
print(f"Weighted avg\t{(weighted_avg_precision_sum/5):.2f}\t\t{(weighted_avg_recall_sum/5):.2f}\t{(weighted_avg_f1_sum/5):.2f}")

# Stampa dell'accuratezza media finale
print(f"\nAccuratezza media su 5 fold: {np.mean(accuracy_per_fold):.2f}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Fold 1
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='156' max='156' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [156/156 02:39, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.899900</td>
#       <td>0.878468</td>
#       <td>0.563107</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.796500</td>
#       <td>0.694538</td>
#       <td>0.747573</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.765100</td>
#       <td>0.728509</td>
#       <td>0.708738</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	0.87		0.89	0.88		46.0
# 1_ragazzi	0.62		0.86	0.72		35.0
# 2_adulti	0.75		0.27	0.40		22.0
#
# 			Support
# Accuracy		0.75	103
# Macro avg	0.75		0.67	0.67		103
# Weighted avg	0.76		0.75	0.72		103
#
# Fold 2
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='156' max='156' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [156/156 02:45, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.951900</td>
#       <td>0.863848</td>
#       <td>0.631068</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.782000</td>
#       <td>0.792349</td>
#       <td>0.640777</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.632500</td>
#       <td>0.651726</td>
#       <td>0.747573</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	0.93		0.93	0.93		44.0
# 1_ragazzi	0.55		0.87	0.68		31.0
# 2_adulti	0.90		0.32	0.47		28.0
#
# 			Support
# Accuracy		0.75	103
# Macro avg	0.79		0.71	0.69		103
# Weighted avg	0.81		0.75	0.73		103
#
# Fold 3
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='156' max='156' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [156/156 02:51, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.907800</td>
#       <td>0.857335</td>
#       <td>0.601942</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.829400</td>
#       <td>0.859559</td>
#       <td>0.582524</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.576500</td>
#       <td>0.710907</td>
#       <td>0.689320</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	0.85		0.89	0.87		37.0
# 1_ragazzi	0.61		0.59	0.60		39.0
# 2_adulti	0.58		0.56	0.57		27.0
#
# 			Support
# Accuracy		0.69	103
# Macro avg	0.68		0.68	0.68		103
# Weighted avg	0.68		0.69	0.69		103
#
# Fold 4
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='156' max='156' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [156/156 02:44, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.892100</td>
#       <td>0.865728</td>
#       <td>0.563107</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.757100</td>
#       <td>0.738874</td>
#       <td>0.737864</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.594900</td>
#       <td>0.645248</td>
#       <td>0.737864</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	0.83		0.91	0.87		43.0
# 1_ragazzi	0.65		0.86	0.74		36.0
# 2_adulti	0.75		0.25	0.38		24.0
#
# 			Support
# Accuracy		0.74	103
# Macro avg	0.74		0.67	0.66		103
# Weighted avg	0.75		0.74	0.71		103
#
# Fold 5
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='156' max='156' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [156/156 02:50, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.929000</td>
#       <td>0.864620</td>
#       <td>0.647059</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.833700</td>
#       <td>0.810057</td>
#       <td>0.637255</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.669100</td>
#       <td>0.720672</td>
#       <td>0.627451</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	0.89		0.87	0.88		39.0
# 1_ragazzi	0.52		0.39	0.45		38.0
# 2_adulti	0.43		0.60	0.50		25.0
#
# 			Support
# Accuracy		0.63	102
# Macro avg	0.61		0.62	0.61		102
# Weighted avg	0.64		0.63	0.63		102
#
# Risultati medi su 5 fold:
# 		Precision	Recall	F1-score	Support
# 0_bambini	0.87		0.90	0.89		209.0
# 1_ragazzi	0.59		0.71	0.64		179.0
# 2_adulti	0.68		0.40	0.46		126.0
#
# Macro avg	0.71		0.67	0.66
# Weighted avg	0.73		0.71	0.70
#
# Accuratezza media su 5 fold: 0.71

# %% [markdown]
# # Bert uncased eng

# %%
import os
import numpy as np
import torch
from torch.utils.data import Dataset
from transformers import BertTokenizer, BertForSequenceClassification, Trainer, TrainingArguments
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, classification_report

# Montaggio di Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Percorso della cartella dei dati su Google Drive
data_path = '/content/drive/My Drive/Esperimento_eng'

# Tokenizer di BERT (inglese)
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# Classe Dataset
class TextDataset(Dataset):
    def __init__(self, texts, labels, tokenizer):
        self.encodings = tokenizer(texts, truncation=True, padding=True, max_length=512)
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.labels)

# Funzione per calcolare le metriche
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    return {"accuracy": accuracy_score(labels, predictions)}

# Funzione per caricare i dati
def load_data(data_path):
    texts, labels, titles = [], [], []
    label_dict = {'0_bambini': 0, '1_ragazzi': 1, '2_adulti': 2}
    for label, index in label_dict.items():
        folder_path = os.path.join(data_path, label)
        for filename in os.listdir(folder_path):
            with open(os.path.join(folder_path, filename), 'r', encoding='utf-8') as file:
                texts.append(file.read())
                labels.append(index)
                titles.append(filename)  # Salva il nome del file come titolo
    return texts, labels, titles

# Caricamento dei dati
texts, labels, titles = load_data(data_path)

# Inizializza dizionari per raccogliere i risultati medi
precision_sum = {class_name: 0 for class_name in ['0_bambini', '1_ragazzi', '2_adulti']}
recall_sum = {class_name: 0 for class_name in ['0_bambini', '1_ragazzi', '2_adulti']}
f1_sum = {class_name: 0 for class_name in ['0_bambini', '1_ragazzi', '2_adulti']}
support_sum = {class_name: 0 for class_name in ['0_bambini', '1_ragazzi', '2_adulti']}

accuracy_per_fold = []
macro_avg_precision_sum, macro_avg_recall_sum, macro_avg_f1_sum = 0, 0, 0
weighted_avg_precision_sum, weighted_avg_recall_sum, weighted_avg_f1_sum = 0, 0, 0

fold = 1

# K-fold cross-validation
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

for train_index, test_index in kfold.split(texts):
    print(f'\nFold {fold}')
    fold += 1

    # Divisione in train e test per il fold corrente
    train_texts = [texts[i] for i in train_index]
    test_texts = [texts[i] for i in test_index]
    train_labels = [labels[i] for i in train_index]
    test_labels = [labels[i] for i in test_index]

    # Creazione dei dataset
    train_dataset = TextDataset(train_texts, train_labels, tokenizer)
    test_dataset = TextDataset(test_texts, test_labels, tokenizer)

    # Configurazione dei parametri di training
    training_args = TrainingArguments(
        output_dir='./results',
        num_train_epochs=3,
        per_device_train_batch_size=8,
        per_device_eval_batch_size=16,
        warmup_steps=500,
        weight_decay=0.01,
        logging_dir='./logs',
        logging_steps=10,
        evaluation_strategy="epoch",
        save_strategy="epoch",
        load_best_model_at_end=True
    )

    # Inizializzazione del modello e del trainer
    model = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=3)

    trainer = Trainer(
        model=model,
        args=training_args,
        train_dataset=train_dataset,
        eval_dataset=test_dataset,
        compute_metrics=compute_metrics
    )

    # Training del modello
    trainer.train()

    # Valutazione sul test del fold corrente
    predictions = trainer.predict(test_dataset)
    predicted_labels = np.argmax(predictions.predictions, axis=1)

    # Calcolo del classification report
    target_names = ['0_bambini', '1_ragazzi', '2_adulti']
    report = classification_report(test_labels, predicted_labels, target_names=target_names, output_dict=True)

    # Stampa del classification report formattato
    print("\t\tPrecision\tRecall\tF1-score\tSupport")
    for class_name in target_names:
        class_report = report[class_name]
        print(f"{class_name}\t{class_report['precision']:.2f}\t\t{class_report['recall']:.2f}\t{class_report['f1-score']:.2f}\t\t{class_report['support']}")

    print("\n\t\t\tSupport")
    print(f"Accuracy\t\t{report['accuracy']:.2f}\t{len(test_labels)}")
    print(f"Macro avg\t{report['macro avg']['precision']:.2f}\t\t{report['macro avg']['recall']:.2f}\t{report['macro avg']['f1-score']:.2f}\t\t{len(test_labels)}")
    print(f"Weighted avg\t{report['weighted avg']['precision']:.2f}\t\t{report['weighted avg']['recall']:.2f}\t{report['weighted avg']['f1-score']:.2f}\t\t{len(test_labels)}")

    # Somma i valori di precision, recall, f1 e support per ogni classe
    for class_name in target_names:
        precision_sum[class_name] += report[class_name]['precision']
        recall_sum[class_name] += report[class_name]['recall']
        f1_sum[class_name] += report[class_name]['f1-score']
        support_sum[class_name] += report[class_name]['support']

    # Somma per macro avg e weighted avg
    macro_avg_precision_sum += report['macro avg']['precision']
    macro_avg_recall_sum += report['macro avg']['recall']
    macro_avg_f1_sum += report['macro avg']['f1-score']

    weighted_avg_precision_sum += report['weighted avg']['precision']
    weighted_avg_recall_sum += report['weighted avg']['recall']
    weighted_avg_f1_sum += report['weighted avg']['f1-score']

    # Aggiungi l'accuratezza alla lista per calcolare la media finale
    accuracy_per_fold.append(report['accuracy'])

# Media dei risultati per ogni classe
print("\nRisultati medi su 5 fold:")
print("\t\tPrecision\tRecall\tF1-score\tSupport")
for class_name in target_names:
    print(f"{class_name}\t{(precision_sum[class_name]/5):.2f}\t\t{(recall_sum[class_name]/5):.2f}\t{(f1_sum[class_name]/5):.2f}\t\t{support_sum[class_name]}")

# Media per Macro avg e Weighted avg
print(f"\nMacro avg\t{(macro_avg_precision_sum/5):.2f}\t\t{(macro_avg_recall_sum/5):.2f}\t{(macro_avg_f1_sum/5):.2f}")
print(f"Weighted avg\t{(weighted_avg_precision_sum/5):.2f}\t\t{(weighted_avg_recall_sum/5):.2f}\t{(weighted_avg_f1_sum/5):.2f}")

# Stampa dell'accuratezza media finale
print(f"\nAccuratezza media su 5 fold: {np.mean(accuracy_per_fold):.2f}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Fold 1
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='135' max='135' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [135/135 02:26, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.986200</td>
#       <td>0.827604</td>
#       <td>0.711111</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.489400</td>
#       <td>0.497172</td>
#       <td>0.811111</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.279800</td>
#       <td>0.420436</td>
#       <td>0.866667</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	1.00		1.00	1.00		41.0
# 1_ragazzi	0.67		0.91	0.77		22.0
# 2_adulti	0.89		0.63	0.74		27.0
#
# 			Support
# Accuracy		0.87	90
# Macro avg	0.85		0.85	0.84		90
# Weighted avg	0.89		0.87	0.87		90
#
# Fold 2
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='135' max='135' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [135/135 02:27, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.930900</td>
#       <td>0.776423</td>
#       <td>0.752809</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.539200</td>
#       <td>0.466378</td>
#       <td>0.820225</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.395500</td>
#       <td>0.392092</td>
#       <td>0.831461</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	1.00		1.00	1.00		44.0
# 1_ragazzi	0.64		0.96	0.77		26.0
# 2_adulti	0.83		0.26	0.40		19.0
#
# 			Support
# Accuracy		0.83	89
# Macro avg	0.82		0.74	0.72		89
# Weighted avg	0.86		0.83	0.80		89
#
# Fold 3
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='135' max='135' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [135/135 02:32, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.938800</td>
#       <td>0.807679</td>
#       <td>0.707865</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.509400</td>
#       <td>0.479157</td>
#       <td>0.876404</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.385100</td>
#       <td>0.381991</td>
#       <td>0.853933</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	0.97		1.00	0.99		38.0
# 1_ragazzi	0.73		0.94	0.82		32.0
# 2_adulti	0.89		0.42	0.57		19.0
#
# 			Support
# Accuracy		0.85	89
# Macro avg	0.86		0.79	0.79		89
# Weighted avg	0.87		0.85	0.84		89
#
# Fold 4
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='135' max='135' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [135/135 02:27, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.934400</td>
#       <td>0.760693</td>
#       <td>0.764045</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.508900</td>
#       <td>0.468639</td>
#       <td>0.842697</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.425200</td>
#       <td>0.368519</td>
#       <td>0.887640</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	1.00		1.00	1.00		40.0
# 1_ragazzi	0.77		1.00	0.87		33.0
# 2_adulti	1.00		0.38	0.55		16.0
#
# 			Support
# Accuracy		0.89	89
# Macro avg	0.92		0.79	0.80		89
# Weighted avg	0.91		0.89	0.87		89
#
# Fold 5
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='135' max='135' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [135/135 02:30, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.932300</td>
#       <td>0.807340</td>
#       <td>0.764045</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.518600</td>
#       <td>0.483763</td>
#       <td>0.876404</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.382600</td>
#       <td>0.296617</td>
#       <td>0.910112</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	1.00		1.00	1.00		37.0
# 1_ragazzi	0.84		0.94	0.89		33.0
# 2_adulti	0.87		0.68	0.76		19.0
#
# 			Support
# Accuracy		0.91	89
# Macro avg	0.90		0.87	0.88		89
# Weighted avg	0.91		0.91	0.91		89
#
# Risultati medi su 5 fold:
# 		Precision	Recall	F1-score	Support
# 0_bambini	0.99		1.00	1.00		200.0
# 1_ragazzi	0.73		0.95	0.82		146.0
# 2_adulti	0.90		0.47	0.60		100.0
#
# Macro avg	0.87		0.81	0.81
# Weighted avg	0.89		0.87	0.86
#
# Accuratezza media su 5 fold: 0.87

# %% [markdown]
# # Bert cased eng

# %%
import os
import numpy as np
import torch
from torch.utils.data import Dataset
from transformers import BertTokenizer, BertForSequenceClassification, Trainer, TrainingArguments
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, classification_report

# Montaggio di Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Percorso della cartella dei dati su Google Drive
data_path = '/content/drive/My Drive/Esperimento_eng'

# Tokenizer di BERT (versione cased)
tokenizer = BertTokenizer.from_pretrained('bert-base-cased')

# Classe Dataset
class TextDataset(Dataset):
    def __init__(self, texts, labels, tokenizer):
        self.encodings = tokenizer(texts, truncation=True, padding=True, max_length=512)
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.labels)

# Funzione per calcolare le metriche
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    return {"accuracy": accuracy_score(labels, predictions)}

# Funzione per caricare i dati
def load_data(data_path):
    texts, labels, titles = [], [], []
    label_dict = {'0_bambini': 0, '1_ragazzi': 1, '2_adulti': 2}
    for label, index in label_dict.items():
        folder_path = os.path.join(data_path, label)
        for filename in os.listdir(folder_path):
            with open(os.path.join(folder_path, filename), 'r', encoding='utf-8') as file:
                texts.append(file.read())
                labels.append(index)
                titles.append(filename)  # Salva il nome del file come titolo
    return texts, labels, titles

# Caricamento dei dati
texts, labels, titles = load_data(data_path)

# Inizializza dizionari per raccogliere i risultati medi
precision_sum = {class_name: 0 for class_name in ['0_bambini', '1_ragazzi', '2_adulti']}
recall_sum = {class_name: 0 for class_name in ['0_bambini', '1_ragazzi', '2_adulti']}
f1_sum = {class_name: 0 for class_name in ['0_bambini', '1_ragazzi', '2_adulti']}
support_sum = {class_name: 0 for class_name in ['0_bambini', '1_ragazzi', '2_adulti']}

accuracy_per_fold = []
macro_avg_precision_sum, macro_avg_recall_sum, macro_avg_f1_sum = 0, 0, 0
weighted_avg_precision_sum, weighted_avg_recall_sum, weighted_avg_f1_sum = 0, 0, 0

fold = 1

# K-fold cross-validation
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

for train_index, test_index in kfold.split(texts):
    print(f'\nFold {fold}')
    fold += 1

    # Divisione in train e test per il fold corrente
    train_texts = [texts[i] for i in train_index]
    test_texts = [texts[i] for i in test_index]
    train_labels = [labels[i] for i in train_index]
    test_labels = [labels[i] for i in test_index]

    # Creazione dei dataset
    train_dataset = TextDataset(train_texts, train_labels, tokenizer)
    test_dataset = TextDataset(test_texts, test_labels, tokenizer)

    # Configurazione dei parametri di training
    training_args = TrainingArguments(
        output_dir='./results',
        num_train_epochs=3,
        per_device_train_batch_size=8,
        per_device_eval_batch_size=16,
        warmup_steps=500,
        weight_decay=0.01,
        logging_dir='./logs',
        logging_steps=10,
        evaluation_strategy="epoch",
        save_strategy="epoch",
        load_best_model_at_end=True
    )

    # Inizializzazione del modello e del trainer (versione cased)
    model = BertForSequenceClassification.from_pretrained('bert-base-cased', num_labels=3)

    trainer = Trainer(
        model=model,
        args=training_args,
        train_dataset=train_dataset,
        eval_dataset=test_dataset,
        compute_metrics=compute_metrics
    )

    # Training del modello
    trainer.train()

    # Valutazione sul test del fold corrente
    predictions = trainer.predict(test_dataset)
    predicted_labels = np.argmax(predictions.predictions, axis=1)

    # Calcolo del classification report
    target_names = ['0_bambini', '1_ragazzi', '2_adulti']
    report = classification_report(test_labels, predicted_labels, target_names=target_names, output_dict=True)

    # Stampa del classification report formattato
    print("\t\tPrecision\tRecall\tF1-score\tSupport")
    for class_name in target_names:
        class_report = report[class_name]
        print(f"{class_name}\t{class_report['precision']:.2f}\t\t{class_report['recall']:.2f}\t{class_report['f1-score']:.2f}\t\t{class_report['support']}")

    print("\n\t\t\tSupport")
    print(f"Accuracy\t\t{report['accuracy']:.2f}\t{len(test_labels)}")
    print(f"Macro avg\t{report['macro avg']['precision']:.2f}\t\t{report['macro avg']['recall']:.2f}\t{report['macro avg']['f1-score']:.2f}\t\t{len(test_labels)}")
    print(f"Weighted avg\t{report['weighted avg']['precision']:.2f}\t\t{report['weighted avg']['recall']:.2f}\t{report['weighted avg']['f1-score']:.2f}\t\t{len(test_labels)}")

    # Somma i valori di precision, recall, f1 e support per ogni classe
    for class_name in target_names:
        precision_sum[class_name] += report[class_name]['precision']
        recall_sum[class_name] += report[class_name]['recall']
        f1_sum[class_name] += report[class_name]['f1-score']
        support_sum[class_name] += report[class_name]['support']

    # Somma per macro avg e weighted avg
    macro_avg_precision_sum += report['macro avg']['precision']
    macro_avg_recall_sum += report['macro avg']['recall']
    macro_avg_f1_sum += report['macro avg']['f1-score']

    weighted_avg_precision_sum += report['weighted avg']['precision']
    weighted_avg_recall_sum += report['weighted avg']['recall']
    weighted_avg_f1_sum += report['weighted avg']['f1-score']

    # Aggiungi l'accuratezza alla lista per calcolare la media finale
    accuracy_per_fold.append(report['accuracy'])

# Media dei risultati per ogni classe
print("\nRisultati medi su 5 fold:")
print("\t\tPrecision\tRecall\tF1-score\tSupport")
for class_name in target_names:
    print(f"{class_name}\t{(precision_sum[class_name]/5):.2f}\t\t{(recall_sum[class_name]/5):.2f}\t{(f1_sum[class_name]/5):.2f}\t\t{support_sum[class_name]}")

# Media per Macro avg e Weighted avg
print(f"\nMacro avg\t{(macro_avg_precision_sum/5):.2f}\t\t{(macro_avg_recall_sum/5):.2f}\t{(macro_avg_f1_sum/5):.2f}")
print(f"Weighted avg\t{(weighted_avg_precision_sum/5):.2f}\t\t{(weighted_avg_recall_sum/5):.2f}\t{(weighted_avg_f1_sum/5):.2f}")

# Stampa dell'accuratezza media finale
print(f"\nAccuratezza media su 5 fold: {np.mean(accuracy_per_fold):.2f}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/436k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Fold 1
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/436M [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='135' max='135' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [135/135 02:30, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.978700</td>
#       <td>0.901758</td>
#       <td>0.700000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.435900</td>
#       <td>0.464189</td>
#       <td>0.777778</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.263600</td>
#       <td>0.369538</td>
#       <td>0.855556</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	1.00		1.00	1.00		41.0
# 1_ragazzi	0.67		0.82	0.73		22.0
# 2_adulti	0.82		0.67	0.73		27.0
#
# 			Support
# Accuracy		0.86	90
# Macro avg	0.83		0.83	0.82		90
# Weighted avg	0.86		0.86	0.86		90
#
# Fold 2
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='135' max='135' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [135/135 02:24, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.990300</td>
#       <td>0.833634</td>
#       <td>0.786517</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.414600</td>
#       <td>0.384708</td>
#       <td>0.808989</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.388300</td>
#       <td>0.331041</td>
#       <td>0.853933</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	1.00		1.00	1.00		44.0
# 1_ragazzi	0.67		1.00	0.80		26.0
# 2_adulti	1.00		0.32	0.48		19.0
#
# 			Support
# Accuracy		0.85	89
# Macro avg	0.89		0.77	0.76		89
# Weighted avg	0.90		0.85	0.83		89
#
# Fold 3
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='135' max='135' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [135/135 02:27, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.987100</td>
#       <td>0.827489</td>
#       <td>0.764045</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.400500</td>
#       <td>0.404945</td>
#       <td>0.842697</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.326200</td>
#       <td>0.334170</td>
#       <td>0.853933</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	1.00		1.00	1.00		38.0
# 1_ragazzi	0.71		1.00	0.83		32.0
# 2_adulti	1.00		0.32	0.48		19.0
#
# 			Support
# Accuracy		0.85	89
# Macro avg	0.90		0.77	0.77		89
# Weighted avg	0.90		0.85	0.83		89
#
# Fold 4
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='135' max='135' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [135/135 02:30, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.992100</td>
#       <td>0.817409</td>
#       <td>0.808989</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.387600</td>
#       <td>0.388015</td>
#       <td>0.853933</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.422600</td>
#       <td>0.299795</td>
#       <td>0.876404</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	1.00		1.00	1.00		40.0
# 1_ragazzi	0.76		0.97	0.85		33.0
# 2_adulti	0.86		0.38	0.52		16.0
#
# 			Support
# Accuracy		0.88	89
# Macro avg	0.87		0.78	0.79		89
# Weighted avg	0.89		0.88	0.86		89
#
# Fold 5
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='135' max='135' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [135/135 02:25, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.991300</td>
#       <td>0.821279</td>
#       <td>0.786517</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.404100</td>
#       <td>0.356052</td>
#       <td>0.910112</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.358000</td>
#       <td>0.277880</td>
#       <td>0.887640</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	1.00		1.00	1.00		37.0
# 1_ragazzi	0.87		0.82	0.84		33.0
# 2_adulti	0.71		0.79	0.75		19.0
#
# 			Support
# Accuracy		0.89	89
# Macro avg	0.86		0.87	0.86		89
# Weighted avg	0.89		0.89	0.89		89
#
# Risultati medi su 5 fold:
# 		Precision	Recall	F1-score	Support
# 0_bambini	1.00		1.00	1.00		200.0
# 1_ragazzi	0.74		0.92	0.81		146.0
# 2_adulti	0.88		0.49	0.59		100.0
#
# Macro avg	0.87		0.80	0.80
# Weighted avg	0.89		0.87	0.85
#
# Accuratezza media su 5 fold: 0.87

# %% [markdown]
# # Bert cased eng badwords

# %%
import os
import numpy as np
import torch
from torch.utils.data import Dataset
from transformers import BertTokenizer, BertForSequenceClassification, Trainer, TrainingArguments
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, classification_report
from nltk.tokenize import word_tokenize
import nltk

# Montaggio di Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Scarica risorse di NLTK per la tokenizzazione
nltk.download('punkt')

# Percorso della cartella dei dati su Google Drive
data_path = '/content/drive/My Drive/Esperimento_eng'

# Caricamento delle bad words in inglese
bad_words_path = '/content/drive/My Drive/badwords_eng_new.txt'

try:
    with open(bad_words_path, 'r', encoding='utf-8') as file:
        bad_words = set(line.strip() for line in file)
except Exception as e:
    print(f"Error loading bad words: {e}")

# Funzione per rilevare bad words
def detect_bad_words(text, bad_words):
    words = set(word_tokenize(text.lower()))  # Tokenizza e abbassa il testo
    return words.intersection(bad_words)

# Tokenizer di BERT (versione cased)
tokenizer = BertTokenizer.from_pretrained('bert-base-cased')

# Classe Dataset
class TextDataset(Dataset):
    def __init__(self, texts, labels, tokenizer):
        self.encodings = tokenizer(texts, truncation=True, padding=True, max_length=512)
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.labels)

# Funzione per calcolare le metriche
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    return {"accuracy": accuracy_score(labels, predictions)}

# Funzione per caricare i dati
def load_data(data_path):
    texts, labels, titles = [], [], []
    label_dict = {'0_bambini': 0, '1_ragazzi': 1, '2_adulti': 2}
    for label, index in label_dict.items():
        folder_path = os.path.join(data_path, label)
        for filename in os.listdir(folder_path):
            with open(os.path.join(folder_path, filename), 'r', encoding='utf-8') as file:
                texts.append(file.read())
                labels.append(index)
                titles.append(filename)  # Salva il nome del file come titolo
    return texts, labels, titles

# Caricamento dei dati
texts, labels, titles = load_data(data_path)

# Inizializza dizionari per raccogliere i risultati medi
precision_sum = {class_name: 0 for class_name in ['0_bambini', '1_ragazzi', '2_adulti']}
recall_sum = {class_name: 0 for class_name in ['0_bambini', '1_ragazzi', '2_adulti']}
f1_sum = {class_name: 0 for class_name in ['0_bambini', '1_ragazzi', '2_adulti']}
support_sum = {class_name: 0 for class_name in ['0_bambini', '1_ragazzi', '2_adulti']}

accuracy_per_fold = []
macro_avg_precision_sum, macro_avg_recall_sum, macro_avg_f1_sum = 0, 0, 0
weighted_avg_precision_sum, weighted_avg_recall_sum, weighted_avg_f1_sum = 0, 0, 0

fold = 1

# K-fold cross-validation
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

for train_index, test_index in kfold.split(texts):
    print(f'\nFold {fold}')
    fold += 1

    # Divisione in train e test per il fold corrente
    train_texts = [texts[i] for i in train_index]
    test_texts = [texts[i] for i in test_index]
    train_labels = [labels[i] for i in train_index]
    test_labels = [labels[i] for i in test_index]

    # Creazione dei dataset
    train_dataset = TextDataset(train_texts, train_labels, tokenizer)
    test_dataset = TextDataset(test_texts, test_labels, tokenizer)

    # Configurazione dei parametri di training
    training_args = TrainingArguments(
        output_dir='./results',
        num_train_epochs=3,
        per_device_train_batch_size=8,
        per_device_eval_batch_size=16,
        warmup_steps=500,
        weight_decay=0.01,
        logging_dir='./logs',
        logging_steps=10,
        evaluation_strategy="epoch",
        save_strategy="epoch",
        load_best_model_at_end=True
    )

    # Inizializzazione del modello e del trainer (versione cased)
    model = BertForSequenceClassification.from_pretrained('bert-base-cased', num_labels=3)

    trainer = Trainer(
        model=model,
        args=training_args,
        train_dataset=train_dataset,
        eval_dataset=test_dataset,
        compute_metrics=compute_metrics
    )

    # Training del modello
    trainer.train()

    # Valutazione sul test del fold corrente
    predictions = trainer.predict(test_dataset)
    predicted_labels = np.argmax(predictions.predictions, axis=1)

    # Aggiungi il controllo delle bad words
    adjusted_labels = []
    detected_bad_words_list = []

    for i, text in enumerate(test_texts):
        detected_bad_words = detect_bad_words(text, bad_words)
        original_label = predicted_labels[i]
        if original_label == 0 and detected_bad_words:
            adjusted_labels.append(2)  # Cambia l'etichetta in "adulti"
            detected_bad_words_list.append((titles[test_index[i]], detected_bad_words))
        else:
            adjusted_labels.append(original_label)

    # Calcolo del classification report
    target_names = ['0_bambini', '1_ragazzi', '2_adulti']
    report = classification_report(test_labels, adjusted_labels, target_names=target_names, output_dict=True)

    # Stampa del classification report formattato
    print("\t\tPrecision\tRecall\tF1-score\tSupport")
    for class_name in target_names:
        class_report = report[class_name]
        print(f"{class_name}\t{class_report['precision']:.2f}\t\t{class_report['recall']:.2f}\t{class_report['f1-score']:.2f}\t\t{class_report['support']}")

    print("\n\t\t\tSupport")
    print(f"Accuracy\t\t{report['accuracy']:.2f}\t{len(test_labels)}")
    print(f"Macro avg\t{report['macro avg']['precision']:.2f}\t\t{report['macro avg']['recall']:.2f}\t{report['macro avg']['f1-score']:.2f}\t\t{len(test_labels)}")
    print(f"Weighted avg\t{report['weighted avg']['precision']:.2f}\t\t{report['weighted avg']['recall']:.2f}\t{report['weighted avg']['f1-score']:.2f}\t\t{len(test_labels)}")

    # Somma i valori di precision, recall, f1 e support per ogni classe
    for class_name in target_names:
        precision_sum[class_name] += report[class_name]['precision']
        recall_sum[class_name] += report[class_name]['recall']
        f1_sum[class_name] += report[class_name]['f1-score']
        support_sum[class_name] += report[class_name]['support']

    # Somma per macro avg e weighted avg
    macro_avg_precision_sum += report['macro avg']['precision']
    macro_avg_recall_sum += report['macro avg']['recall']
    macro_avg_f1_sum += report['macro avg']['f1-score']

    weighted_avg_precision_sum += report['weighted avg']['precision']
    weighted_avg_recall_sum += report['weighted avg']['recall']
    weighted_avg_f1_sum += report['weighted avg']['f1-score']

    # Aggiungi l'accuratezza alla lista per calcolare la media finale
    accuracy_per_fold.append(report['accuracy'])

    # Stampa i testi in cui sono state rilevate bad words
    if detected_bad_words_list:
        print(f"Bad words rilevate nel fold {fold - 1}:")
        for title, bad_words in detected_bad_words_list:
            print(f"Titolo: {title}, Bad words: {bad_words}")

# Media dei risultati per ogni classe
print("\nRisultati medi su 5 fold:")
print("\t\tPrecision\tRecall\tF1-score\tSupport")
for class_name in target_names:
    print(f"{class_name}\t{(precision_sum[class_name]/5):.2f}\t\t{(recall_sum[class_name]/5):.2f}\t{(f1_sum[class_name]/5):.2f}\t\t{support_sum[class_name]}")

# Media per Macro avg e Weighted avg
print(f"\nMacro avg\t{(macro_avg_precision_sum/5):.2f}\t\t{(macro_avg_recall_sum/5):.2f}\t{(macro_avg_f1_sum/5):.2f}")
print(f"Weighted avg\t{(weighted_avg_precision_sum/5):.2f}\t\t{(weighted_avg_recall_sum/5):.2f}\t{(weighted_avg_f1_sum/5):.2f}")

# Stampa dell'accuratezza media finale
print(f"\nAccuratezza media su 5 fold: {np.mean(accuracy_per_fold):.2f}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Fold 1
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='135' max='135' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [135/135 02:07, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.978700</td>
#       <td>0.901758</td>
#       <td>0.700000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.435900</td>
#       <td>0.464189</td>
#       <td>0.777778</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.263600</td>
#       <td>0.369538</td>
#       <td>0.855556</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	1.00		1.00	1.00		41.0
# 1_ragazzi	0.67		0.82	0.73		22.0
# 2_adulti	0.82		0.67	0.73		27.0
#
# 			Support
# Accuracy		0.86	90
# Macro avg	0.83		0.83	0.82		90
# Weighted avg	0.86		0.86	0.86		90
#
# Fold 2
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='135' max='135' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [135/135 02:05, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.990300</td>
#       <td>0.833634</td>
#       <td>0.786517</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.414600</td>
#       <td>0.384708</td>
#       <td>0.808989</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.388300</td>
#       <td>0.331041</td>
#       <td>0.853933</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	1.00		1.00	1.00		44.0
# 1_ragazzi	0.67		1.00	0.80		26.0
# 2_adulti	1.00		0.32	0.48		19.0
#
# 			Support
# Accuracy		0.85	89
# Macro avg	0.89		0.77	0.76		89
# Weighted avg	0.90		0.85	0.83		89
#
# Fold 3
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='135' max='135' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [135/135 02:04, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.987100</td>
#       <td>0.827489</td>
#       <td>0.764045</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.400500</td>
#       <td>0.404945</td>
#       <td>0.842697</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.326200</td>
#       <td>0.334170</td>
#       <td>0.853933</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	1.00		1.00	1.00		38.0
# 1_ragazzi	0.71		1.00	0.83		32.0
# 2_adulti	1.00		0.32	0.48		19.0
#
# 			Support
# Accuracy		0.85	89
# Macro avg	0.90		0.77	0.77		89
# Weighted avg	0.90		0.85	0.83		89
#
# Fold 4
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='135' max='135' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [135/135 02:06, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.992100</td>
#       <td>0.817409</td>
#       <td>0.808989</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.387600</td>
#       <td>0.388015</td>
#       <td>0.853933</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.422600</td>
#       <td>0.299795</td>
#       <td>0.876404</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	1.00		1.00	1.00		40.0
# 1_ragazzi	0.76		0.97	0.85		33.0
# 2_adulti	0.86		0.38	0.52		16.0
#
# 			Support
# Accuracy		0.88	89
# Macro avg	0.87		0.78	0.79		89
# Weighted avg	0.89		0.88	0.86		89
#
# Fold 5
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='135' max='135' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [135/135 02:05, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.991300</td>
#       <td>0.821279</td>
#       <td>0.786517</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.404100</td>
#       <td>0.356052</td>
#       <td>0.910112</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.358000</td>
#       <td>0.277880</td>
#       <td>0.887640</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	1.00		1.00	1.00		37.0
# 1_ragazzi	0.87		0.82	0.84		33.0
# 2_adulti	0.71		0.79	0.75		19.0
#
# 			Support
# Accuracy		0.89	89
# Macro avg	0.86		0.87	0.86		89
# Weighted avg	0.89		0.89	0.89		89
#
# Risultati medi su 5 fold:
# 		Precision	Recall	F1-score	Support
# 0_bambini	1.00		1.00	1.00		200.0
# 1_ragazzi	0.74		0.92	0.81		146.0
# 2_adulti	0.88		0.49	0.59		100.0
#
# Macro avg	0.87		0.80	0.80
# Weighted avg	0.89		0.87	0.85
#
# Accuratezza media su 5 fold: 0.87

# %% [markdown]
# # Bert cased ita

# %%
import os
import numpy as np
import torch
from torch.utils.data import Dataset
from transformers import BertTokenizer, BertForSequenceClassification, Trainer, TrainingArguments
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, classification_report

# Montaggio di Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Percorso della cartella dei dati su Google Drive
data_path = '/content/drive/My Drive/esperimento'

# Tokenizer di BERT (versione cased per inglese)
tokenizer = BertTokenizer.from_pretrained('bert-base-cased')

# Classe Dataset
class TextDataset(Dataset):
    def __init__(self, texts, labels, tokenizer):
        self.encodings = tokenizer(texts, truncation=True, padding=True, max_length=512)
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.labels)

# Funzione per calcolare le metriche
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    return {"accuracy": accuracy_score(labels, predictions)}

# Funzione per caricare i dati
def load_data(data_path):
    texts, labels, titles = [], [], []
    label_dict = {'0_bambini': 0, '1_ragazzi': 1, '2_adulti': 2}
    for label, index in label_dict.items():
        folder_path = os.path.join(data_path, label)
        for filename in os.listdir(folder_path):
            with open(os.path.join(folder_path, filename), 'r', encoding='utf-8') as file:
                texts.append(file.read())
                labels.append(index)
                titles.append(filename)  # Salva il nome del file come titolo
    return texts, labels, titles

# Caricamento dei dati
texts, labels, titles = load_data(data_path)

# Inizializza dizionari per raccogliere i risultati medi
precision_sum = {class_name: 0 for class_name in ['0_bambini', '1_ragazzi', '2_adulti']}
recall_sum = {class_name: 0 for class_name in ['0_bambini', '1_ragazzi', '2_adulti']}
f1_sum = {class_name: 0 for class_name in ['0_bambini', '1_ragazzi', '2_adulti']}
support_sum = {class_name: 0 for class_name in ['0_bambini', '1_ragazzi', '2_adulti']}

accuracy_per_fold = []
macro_avg_precision_sum, macro_avg_recall_sum, macro_avg_f1_sum = 0, 0, 0
weighted_avg_precision_sum, weighted_avg_recall_sum, weighted_avg_f1_sum = 0, 0, 0

fold = 1

# K-fold cross-validation
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

for train_index, test_index in kfold.split(texts):
    print(f'\nFold {fold}')
    fold += 1

    # Divisione in train e test per il fold corrente
    train_texts = [texts[i] for i in train_index]
    test_texts = [texts[i] for i in test_index]
    train_labels = [labels[i] for i in train_index]
    test_labels = [labels[i] for i in test_index]

    # Creazione dei dataset
    train_dataset = TextDataset(train_texts, train_labels, tokenizer)
    test_dataset = TextDataset(test_texts, test_labels, tokenizer)

    # Configurazione dei parametri di training
    training_args = TrainingArguments(
        output_dir='./results',
        num_train_epochs=3,
        per_device_train_batch_size=8,
        per_device_eval_batch_size=16,
        warmup_steps=500,
        weight_decay=0.01,
        logging_dir='./logs',
        logging_steps=10,
        evaluation_strategy="epoch",
        save_strategy="epoch",
        load_best_model_at_end=True
    )

    # Inizializzazione del modello e del trainer
    model = BertForSequenceClassification.from_pretrained('bert-base-cased', num_labels=3)

    trainer = Trainer(
        model=model,
        args=training_args,
        train_dataset=train_dataset,
        eval_dataset=test_dataset,
        compute_metrics=compute_metrics
    )

    # Training del modello
    trainer.train()

    # Valutazione sul test del fold corrente
    predictions = trainer.predict(test_dataset)
    predicted_labels = np.argmax(predictions.predictions, axis=1)

    # Calcolo del classification report
    target_names = ['0_bambini', '1_ragazzi', '2_adulti']
    report = classification_report(test_labels, predicted_labels, target_names=target_names, output_dict=True)

    # Stampa del classification report formattato
    print("\t\tPrecision\tRecall\tF1-score\tSupport")
    for class_name in target_names:
        class_report = report[class_name]
        print(f"{class_name}\t{class_report['precision']:.2f}\t\t{class_report['recall']:.2f}\t{class_report['f1-score']:.2f}\t\t{class_report['support']}")

    print("\n\t\t\tSupport")
    print(f"Accuracy\t\t{report['accuracy']:.2f}\t{len(test_labels)}")
    print(f"Macro avg\t{report['macro avg']['precision']:.2f}\t\t{report['macro avg']['recall']:.2f}\t{report['macro avg']['f1-score']:.2f}\t\t{len(test_labels)}")
    print(f"Weighted avg\t{report['weighted avg']['precision']:.2f}\t\t{report['weighted avg']['recall']:.2f}\t{report['weighted avg']['f1-score']:.2f}\t\t{len(test_labels)}")

    # Somma i valori di precision, recall, f1 e support per ogni classe
    for class_name in target_names:
        precision_sum[class_name] += report[class_name]['precision']
        recall_sum[class_name] += report[class_name]['recall']
        f1_sum[class_name] += report[class_name]['f1-score']
        support_sum[class_name] += report[class_name]['support']

    # Somma per macro avg e weighted avg
    macro_avg_precision_sum += report['macro avg']['precision']
    macro_avg_recall_sum += report['macro avg']['recall']
    macro_avg_f1_sum += report['macro avg']['f1-score']

    weighted_avg_precision_sum += report['weighted avg']['precision']
    weighted_avg_recall_sum += report['weighted avg']['recall']
    weighted_avg_f1_sum += report['weighted avg']['f1-score']

    # Aggiungi l'accuratezza alla lista per calcolare la media finale
    accuracy_per_fold.append(report['accuracy'])

# Media dei risultati per ogni classe
print("\nRisultati medi su 5 fold:")
print("\t\tPrecision\tRecall\tF1-score\tSupport")
for class_name in target_names:
    print(f"{class_name}\t{(precision_sum[class_name]/5):.2f}\t\t{(recall_sum[class_name]/5):.2f}\t{(f1_sum[class_name]/5):.2f}\t\t{support_sum[class_name]}")

# Media per Macro avg e Weighted avg
print(f"\nMacro avg\t{(macro_avg_precision_sum/5):.2f}\t\t{(macro_avg_recall_sum/5):.2f}\t{(macro_avg_f1_sum/5):.2f}")
print(f"Weighted avg\t{(weighted_avg_precision_sum/5):.2f}\t\t{(weighted_avg_recall_sum/5):.2f}\t{(weighted_avg_f1_sum/5):.2f}")

# Stampa dell'accuratezza media finale
print(f"\nAccuratezza media su 5 fold: {np.mean(accuracy_per_fold):.2f}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Fold 1
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='156' max='156' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [156/156 02:50, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.146200</td>
#       <td>1.052214</td>
#       <td>0.466019</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.802600</td>
#       <td>0.733716</td>
#       <td>0.757282</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.659700</td>
#       <td>1.024455</td>
#       <td>0.592233</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	0.77		0.96	0.85		46.0
# 1_ragazzi	0.81		0.71	0.76		35.0
# 2_adulti	0.60		0.41	0.49		22.0
#
# 			Support
# Accuracy		0.76	103
# Macro avg	0.73		0.69	0.70		103
# Weighted avg	0.75		0.76	0.74		103
#
# Fold 2
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='156' max='156' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [156/156 02:44, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.119400</td>
#       <td>1.083310</td>
#       <td>0.388350</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.758600</td>
#       <td>0.715793</td>
#       <td>0.728155</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.626100</td>
#       <td>0.717078</td>
#       <td>0.699029</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	0.82		0.95	0.88		44.0
# 1_ragazzi	0.59		0.87	0.70		31.0
# 2_adulti	1.00		0.21	0.35		28.0
#
# 			Support
# Accuracy		0.73	103
# Macro avg	0.80		0.68	0.65		103
# Weighted avg	0.80		0.73	0.68		103
#
# Fold 3
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='156' max='156' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [156/156 02:44, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.137300</td>
#       <td>1.054693</td>
#       <td>0.378641</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.824600</td>
#       <td>0.859880</td>
#       <td>0.660194</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.632200</td>
#       <td>0.773743</td>
#       <td>0.679612</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	0.81		0.70	0.75		37.0
# 1_ragazzi	0.63		0.82	0.71		39.0
# 2_adulti	0.60		0.44	0.51		27.0
#
# 			Support
# Accuracy		0.68	103
# Macro avg	0.68		0.66	0.66		103
# Weighted avg	0.69		0.68	0.67		103
#
# Fold 4
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='156' max='156' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [156/156 02:42, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.136700</td>
#       <td>1.064904</td>
#       <td>0.359223</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.757800</td>
#       <td>0.804839</td>
#       <td>0.718447</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.584500</td>
#       <td>0.704514</td>
#       <td>0.718447</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	0.81		0.79	0.80		43.0
# 1_ragazzi	0.64		0.89	0.74		36.0
# 2_adulti	0.73		0.33	0.46		24.0
#
# 			Support
# Accuracy		0.72	103
# Macro avg	0.73		0.67	0.67		103
# Weighted avg	0.73		0.72	0.70		103
#
# Fold 5
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='156' max='156' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [156/156 02:45, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.094000</td>
#       <td>1.014906</td>
#       <td>0.578431</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.770800</td>
#       <td>1.011697</td>
#       <td>0.509804</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.675200</td>
#       <td>0.804774</td>
#       <td>0.598039</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	0.74		0.95	0.83		39.0
# 1_ragazzi	0.62		0.13	0.22		38.0
# 2_adulti	0.43		0.76	0.55		25.0
#
# 			Support
# Accuracy		0.60	102
# Macro avg	0.60		0.61	0.53		102
# Weighted avg	0.62		0.60	0.53		102
#
# Risultati medi su 5 fold:
# 		Precision	Recall	F1-score	Support
# 0_bambini	0.79		0.87	0.82		209.0
# 1_ragazzi	0.66		0.69	0.63		179.0
# 2_adulti	0.67		0.43	0.47		126.0
#
# Macro avg	0.71		0.66	0.64
# Weighted avg	0.72		0.70	0.67
#
# Accuratezza media su 5 fold: 0.70

# %% [markdown]
# # Bert cased ita badwords

# %%
import os
import numpy as np
import torch
from torch.utils.data import Dataset
from transformers import BertTokenizer, BertForSequenceClassification, Trainer, TrainingArguments
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, classification_report
from nltk.tokenize import word_tokenize
import nltk

# Montaggio di Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Scarica risorse di NLTK per la tokenizzazione
nltk.download('punkt')

# Percorso della cartella dei dati su Google Drive
data_path = '/content/drive/My Drive/esperimento'

# Caricamento delle bad words in italiano
bad_words_path = '/content/drive/My Drive/bad_words.txt'  # Percorso corretto
try:
    with open(bad_words_path, 'r', encoding='utf-8') as file:
        bad_words = set(line.strip() for line in file)
except Exception as e:
    print(f"Error loading bad words: {e}")
    bad_words = set()  # Set vuoto in caso di errore

# Funzione per rilevare bad words
def detect_bad_words(text, bad_words):
    words = set(word_tokenize(text.lower()))  # Tokenizza e abbassa il testo
    return words.intersection(bad_words)

# Tokenizer di BERT (versione cased per inglese)
tokenizer = BertTokenizer.from_pretrained('bert-base-cased')

# Classe Dataset
class TextDataset(Dataset):
    def __init__(self, texts, labels, tokenizer):
        self.encodings = tokenizer(texts, truncation=True, padding=True, max_length=512)
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.labels)

# Funzione per calcolare le metriche
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    return {"accuracy": accuracy_score(labels, predictions)}

# Funzione per caricare i dati
def load_data(data_path):
    texts, labels, titles = [], [], []
    label_dict = {'0_bambini': 0, '1_ragazzi': 1, '2_adulti': 2}
    for label, index in label_dict.items():
        folder_path = os.path.join(data_path, label)
        for filename in os.listdir(folder_path):
            with open(os.path.join(folder_path, filename), 'r', encoding='utf-8') as file:
                texts.append(file.read())
                labels.append(index)
                titles.append(filename)  # Salva il nome del file come titolo
    return texts, labels, titles

# Caricamento dei dati
texts, labels, titles = load_data(data_path)

# Inizializza dizionari per raccogliere i risultati medi
precision_sum = {class_name: 0 for class_name in ['0_bambini', '1_ragazzi', '2_adulti']}
recall_sum = {class_name: 0 for class_name in ['0_bambini', '1_ragazzi', '2_adulti']}
f1_sum = {class_name: 0 for class_name in ['0_bambini', '1_ragazzi', '2_adulti']}
support_sum = {class_name: 0 for class_name in ['0_bambini', '1_ragazzi', '2_adulti']}

accuracy_per_fold = []
macro_avg_precision_sum, macro_avg_recall_sum, macro_avg_f1_sum = 0, 0, 0
weighted_avg_precision_sum, weighted_avg_recall_sum, weighted_avg_f1_sum = 0, 0, 0

fold = 1

# K-fold cross-validation
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

# Lista per memorizzare i testi in cui l'etichetta è cambiata
texts_with_label_changes = []

for train_index, test_index in kfold.split(texts):
    print(f'\nFold {fold}')
    fold += 1

    # Divisione in train e test per il fold corrente
    train_texts = [texts[i] for i in train_index]
    test_texts = [texts[i] for i in test_index]
    train_labels = [labels[i] for i in train_index]
    test_labels = [labels[i] for i in test_index]

    # Creazione dei dataset
    train_dataset = TextDataset(train_texts, train_labels, tokenizer)
    test_dataset = TextDataset(test_texts, test_labels, tokenizer)

    # Configurazione dei parametri di training
    training_args = TrainingArguments(
        output_dir='./results',
        num_train_epochs=3,
        per_device_train_batch_size=8,
        per_device_eval_batch_size=16,
        warmup_steps=500,
        weight_decay=0.01,
        logging_dir='./logs',
        logging_steps=10,
        evaluation_strategy="epoch",
        save_strategy="epoch",
        load_best_model_at_end=True
    )

    # Inizializzazione del modello e del trainer
    model = BertForSequenceClassification.from_pretrained('bert-base-cased', num_labels=3)

    trainer = Trainer(
        model=model,
        args=training_args,
        train_dataset=train_dataset,
        eval_dataset=test_dataset,
        compute_metrics=compute_metrics
    )

    # Training del modello
    trainer.train()

    # Valutazione sul test del fold corrente
    predictions = trainer.predict(test_dataset)
    predicted_labels = np.argmax(predictions.predictions, axis=1)

    # Aggiungi il controllo delle bad words
    adjusted_labels = []
    detected_bad_words_list = []

    for i, text in enumerate(test_texts):
        detected_bad_words = detect_bad_words(text, bad_words)
        original_label = predicted_labels[i]
        if original_label == 0 and detected_bad_words:
            adjusted_labels.append(2)  # Cambia l'etichetta in "adulti"
            detected_bad_words_list.append((titles[test_index[i]], detected_bad_words))

            # Memorizza i testi modificati
            texts_with_label_changes.append({
                "Title": titles[test_index[i]],
                "Original Text": text,
                "Detected Bad Words": list(detected_bad_words),
                "Original Label": original_label,  # Etichetta originale (0 = bambini)
                "New Label": 2  # Nuova etichetta (2 = adulti)
            })
        else:
            adjusted_labels.append(original_label)

    # Calcolo del classification report
    target_names = ['0_bambini', '1_ragazzi', '2_adulti']
    report = classification_report(test_labels, adjusted_labels, target_names=target_names, output_dict=True)

    # Stampa del classification report formattato
    print("\t\tPrecision\tRecall\tF1-score\tSupport")
    for class_name in target_names:
        class_report = report[class_name]
        print(f"{class_name}\t{class_report['precision']:.2f}\t\t{class_report['recall']:.2f}\t{class_report['f1-score']:.2f}\t\t{class_report['support']}")

    print("\n\t\t\tSupport")
    print(f"Accuracy\t\t{report['accuracy']:.2f}\t{len(test_labels)}")
    print(f"Macro avg\t{report['macro avg']['precision']:.2f}\t\t{report['macro avg']['recall']:.2f}\t{report['macro avg']['f1-score']:.2f}\t\t{len(test_labels)}")
    print(f"Weighted avg\t{report['weighted avg']['precision']:.2f}\t\t{report['weighted avg']['recall']:.2f}\t{report['weighted avg']['f1-score']:.2f}\t\t{len(test_labels)}")

    # Somma i valori di precision, recall, f1 e support per ogni classe
    for class_name in target_names:
        precision_sum[class_name] += report[class_name]['precision']
        recall_sum[class_name] += report[class_name]['recall']
        f1_sum[class_name] += report[class_name]['f1-score']
        support_sum[class_name] += report[class_name]['support']

    # Somma per macro avg e weighted avg
    macro_avg_precision_sum += report['macro avg']['precision']
    macro_avg_recall_sum += report['macro avg']['recall']
    macro_avg_f1_sum += report['macro avg']['f1-score']

    weighted_avg_precision_sum += report['weighted avg']['precision']
    weighted_avg_recall_sum += report['weighted avg']['recall']
    weighted_avg_f1_sum += report['weighted avg']['f1-score']

    # Aggiungi l'accuratezza alla lista per calcolare la media finale
    accuracy_per_fold.append(report['accuracy'])

    # Stampa i testi in cui sono state rilevate bad words
    if detected_bad_words_list:
        print(f"Bad words rilevate nel fold {fold - 1}:")
        for title, bad_words in detected_bad_words_list:
            print(f"Titolo: {title}, Bad words: {', '.join(bad_words)}")
# Media dei risultati per ogni classe
print("\nRisultati medi su 5 fold:")
print("\t\tPrecision\tRecall\tF1-score\tSupport")
for class_name in target_names:
    print(f"{class_name}\t{(precision_sum[class_name]/5):.2f}\t\t{(recall_sum[class_name]/5):.2f}\t{(f1_sum[class_name]/5):.2f}\t\t{support_sum[class_name]}")

# Media per Macro avg e Weighted avg
print(f"\nMacro avg\t{(macro_avg_precision_sum/5):.2f}\t\t{(macro_avg_recall_sum/5):.2f}\t{(macro_avg_f1_sum/5):.2f}")
print(f"Weighted avg\t{(weighted_avg_precision_sum/5):.2f}\t\t{(weighted_avg_recall_sum/5):.2f}\t{(weighted_avg_f1_sum/5):.2f}")

# Stampa dell'accuratezza media finale
print(f"\nAccuratezza media su 5 fold: {np.mean(accuracy_per_fold):.2f}")

# Stampa dei testi in cui l'etichetta è stata cambiata a causa delle bad words
if texts_with_label_changes:
    print(f"\nTesti con cambiamento di etichetta a causa di bad words ({len(texts_with_label_changes)} testi):")
    for item in texts_with_label_changes:
        print(f"Titolo: {item['Title']}")
        print(f"Testo originale: {item['Original Text']}")
        print(f"Parole inappropriate rilevate: {', '.join(item['Detected Bad Words'])}")
        print(f"Etichetta originale: {item['Original Label']}, Nuova etichetta: {item['New Label']}")
        print("-" * 80)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/436k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Fold 1
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/436M [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='156' max='156' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [156/156 02:24, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.146200</td>
#       <td>1.052214</td>
#       <td>0.466019</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.802600</td>
#       <td>0.733716</td>
#       <td>0.757282</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.659700</td>
#       <td>1.024455</td>
#       <td>0.592233</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	0.86		0.96	0.91		46.0
# 1_ragazzi	0.81		0.71	0.76		35.0
# 2_adulti	0.71		0.68	0.70		22.0
#
# 			Support
# Accuracy		0.82	103
# Macro avg	0.79		0.78	0.79		103
# Weighted avg	0.81		0.82	0.81		103
# Bad words rilevate nel fold 1:
# Titolo: YTP_003.txt, Bad words: troia, cazzetto, piscio, cazzata
# Titolo: YTP_012.txt, Bad words: bastardo, cazzi, cazzo
# Titolo: YTP_015.txt, Bad words: bastardo, scopata, minchia, cazzo
# Titolo: YTP_019.txt, Bad words: culo, affanculo, cazzo
# Titolo: filmadulti41.txt, Bad words: culo, puttana
# Titolo: filmadulti42.txt, Bad words: idiota, stronzo, merda
#
# Fold 2
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='156' max='156' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [156/156 02:24, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.119400</td>
#       <td>1.083310</td>
#       <td>0.388350</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.758600</td>
#       <td>0.715793</td>
#       <td>0.728155</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.626100</td>
#       <td>0.717078</td>
#       <td>0.699029</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	0.88		0.95	0.91		44.0
# 1_ragazzi	0.59		0.87	0.70		31.0
# 2_adulti	1.00		0.32	0.49		28.0
#
# 			Support
# Accuracy		0.76	103
# Macro avg	0.82		0.72	0.70		103
# Weighted avg	0.82		0.76	0.73		103
# Bad words rilevate nel fold 2:
# Titolo: YTP_013.txt, Bad words: merda
# Titolo: YTP_017.txt, Bad words: merda
# Titolo: YTP_018.txt, Bad words: merda
#
# Fold 3
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='156' max='156' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [156/156 02:23, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.137300</td>
#       <td>1.054693</td>
#       <td>0.378641</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.824600</td>
#       <td>0.859880</td>
#       <td>0.660194</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.632200</td>
#       <td>0.773743</td>
#       <td>0.679612</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	0.81		0.70	0.75		37.0
# 1_ragazzi	0.63		0.82	0.71		39.0
# 2_adulti	0.60		0.44	0.51		27.0
#
# 			Support
# Accuracy		0.68	103
# Macro avg	0.68		0.66	0.66		103
# Weighted avg	0.69		0.68	0.67		103
#
# Fold 4
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='156' max='156' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [156/156 02:25, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.136700</td>
#       <td>1.064904</td>
#       <td>0.359223</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.757800</td>
#       <td>0.804839</td>
#       <td>0.718447</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.584500</td>
#       <td>0.704514</td>
#       <td>0.718447</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	0.85		0.79	0.82		43.0
# 1_ragazzi	0.64		0.89	0.74		36.0
# 2_adulti	0.77		0.42	0.54		24.0
#
# 			Support
# Accuracy		0.74	103
# Macro avg	0.75		0.70	0.70		103
# Weighted avg	0.76		0.74	0.73		103
# Bad words rilevate nel fold 4:
# Titolo: YTP_002.txt, Bad words: merda
# Titolo: YTP_010.txt, Bad words: merda
#
# Fold 5
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='156' max='156' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [156/156 02:24, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.094000</td>
#       <td>1.014906</td>
#       <td>0.578431</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.770800</td>
#       <td>1.011697</td>
#       <td>0.509804</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.675200</td>
#       <td>0.804774</td>
#       <td>0.598039</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	0.79		0.95	0.86		39.0
# 1_ragazzi	0.62		0.13	0.22		38.0
# 2_adulti	0.47		0.88	0.61		25.0
#
# 			Support
# Accuracy		0.63	102
# Macro avg	0.63		0.65	0.56		102
# Weighted avg	0.65		0.63	0.56		102
# Bad words rilevate nel fold 5:
# Titolo: YTP_006.txt, Bad words: merda
# Titolo: YTP_021.txt, Bad words: merda
# Titolo: YTP_022.txt, Bad words: merda
#
# Risultati medi su 5 fold:
# 		Precision	Recall	F1-score	Support
# 0_bambini	0.84		0.87	0.85		209.0
# 1_ragazzi	0.66		0.69	0.63		179.0
# 2_adulti	0.71		0.55	0.57		126.0
#
# Macro avg	0.73		0.70	0.68
# Weighted avg	0.75		0.72	0.70
#
# Accuratezza media su 5 fold: 0.72
#
# Testi con cambiamento di etichetta a causa di bad words (14 testi):
# Titolo: YTP_003.txt
# Testo originale: Gianni Morandi prego maestro
# Vorrei che
# cantassimo tutti insieme
# fratelli d'Italia
# vi piscio in testa
# [Musica]
# dio bestia
# Dov'è la mia droga e porca ma Madonna
# che schiava chiava
# Dio porco
# [Musica]
# Ciao stronza ho deciso di scriverti una
# lettera voglio farti una premessa
# ho sesso
# Ho deciso che mi viene da piangere
# e non sai la gente mi conosce e tanti mi
# chiedono di fare sesso noi donne siamo
# abituati a farci uomini insicuri Io ci
# sto provando anche in questo momento
# masturba in cameretta che quando scopavo
# sui più importanti Red Carpet c'era un
# pensiero fisso nella mia testa
# non sentirmi una troia
# Allora vorrei dirti innanzitutto questo
# lo sei abbastanza
# Madonna bastarda
# piangi arrangi
# Array ti dico una cosa bellissima essere
# una donna è un limite Dillo dillo alle
# tue amiche Grillo
# [Musica]
# Allora c'era questa
# con il cazzetto
# asciutto Se mi lasci ti stupro se mi
# mette
# Quando mi viene la voglia
# mi metto un dito nell'ano
# tu porti
# un 13 al collo e corro
# [Musica]
# Allora devo dire una cosa magari non è
# un lavoro ma non Però io non me la sento
# di definirla una cazzata siete d'accordo?
# andate a lavorare stronzi
# è una bella sensazione essere una troia
#
# Parole inappropriate rilevate: troia, cazzetto, piscio, cazzata
# Etichetta originale: 0, Nuova etichetta: 2
# --------------------------------------------------------------------------------
# Titolo: YTP_012.txt
# Testo originale: [Musica]
# [Musica]
# non è possibile non è matematicamente
# Basta basta basta
# Ecco gli amici di Peppa
# [rumore di esplosione]
# Ognuno di loro ha una letterina per Babbo Natale
# [Musica]
# che cazzo avete chiesto a Babbo Bastardo?
# una navicella aziale
# una chitarra a giocare
# Totò
# una trombetta
# una racchetta con la racchetta
# George ha chiesto un
# coltello e io invece vorrei tanto un
# colore viola
# arriva il signor zebra
# Guarda quanta posta!
# Peppa e George si fanno una canna
# [Musica]
# Susi Susi Susi Susi
# Buongiorno Babbo Natale
# siete stati?
# sì
# avete sempre tenuto in ordine le vostre
# camere?
# sì
# ehi tu...
# oh oh oh ma fatti i cazzi tuoi
# potrei avere un pallone per favore
# No
# Io lo xilofono
# No
# Il gioco delle pulci
# No
# una scatola di magia
# No
# un treno per favore
# un treno giocattolo
# no, non un treno giocattolo, un treno giocattolo
# oh oh vedrò che cosa posso fare
# Allora tu come ti chiami?
# Sono Peppa Pig
# noi ci siamo già incontrati
# ma chi cazzo sei?
# mamma possiamo andare a giocare con la
# neve?
# evviva
# [risate]
# ma che cazzo saltano?
# [risate]
# non è affatto divertente
# [risate]
# [rumore di uno sparo]
# [risate]
# [Musica]
#
# Parole inappropriate rilevate: bastardo, cazzi, cazzo
# Etichetta originale: 0, Nuova etichetta: 2
# --------------------------------------------------------------------------------
# Titolo: YTP_015.txt
# Testo originale: [Musica]
# c'era una volta una principessa sfrutta
# pisanello non mi interessa perché
# mi sono segato sul mio cane
# sai cosa può farti quell'essere si di e
# trita le palle
# si beh in verità gli orchi di scorrano
# dietro
# a questo punto dovreste
# posso dirti una cosa senti sei stato ben
# a mente un cretino stai dicendo a
# me
# posso dirti che sei stato davvero un
# gran gol one bio porco sei una spietata
# macchina da guerra col giubbotto in
# kevlar sono un prototipo ha un proprio
# sperma
# 8 d'erba basta cantare nei temi
# non hanno il nostro esistere
# [Musica]
# guardami bene che cosa sono
# open e mi piace la minchia sai anche a
# me questa un'altra cosa che abbiamo in
# comune di tipo odio che la [ __ ] ma non
# se ne va chi è la tromba per forza
# possono stare con te cocco posso restare
# con te per favore un altro ancora
# e va bene mi piace il cane
# [Musica]
# [Applauso]
# [Risate]
# a bye bye bye il più veloce che sa il
# più veloce è il più veloce che sa un pan
# di zenzero scoparmi no patron è il
# mostro
# sei uno struzzo della soffio no il
# cucinino non i miei [ __ ] tu
# non conosci
# l'uomo piga l'uomo vinca si conosco
# l'uomo chicca che che vive nella vagina
# apre così detti di comodi
# [Musica]
# benvenuti a di loc
# non possiamo sistemare tutto con una
# scopata
# no
# d'accordo d'accordo si comincia
# [Musica]
# [Applauso]
# magari avrei potuto decapitare un intero
# villaggio mettermi le teste in coro
# prendere le loro coma di soffiargli il
# disagio bene ai loro fluidi principale
# era
# capito
# ambara ba cicci cocco tre civette sul
# comò fine della storia baci baci
# [Musica]
# unico dovresti avvertire prima disp
# laurent avevo la [ __ ] aperta cui dietro
# credimi giochino se fossi stato io sarei
# stato io
# affronteremo questa cosa insieme un
# passettino minuscolo alla morte davvero
# lo zucchino due cose chiaro sta
# minchia
# [Musica]
# la battaglia è vinta potete togliersi le
# mutande un buon cavaliere o no perché no
# i testicoli tutti schiacciati ve ne
# prego vorrei guardare il cazzo del mio
# salvatore non è il caso
# come farina scottarmi cosa
# d'accordo calma ai tuoi ordini carezza
# [Musica]
# giochino non c'è nessun noi nessun
# nostro ci sono solo io e la mia palude
# capito io nessun altro è capito nessuno
# cioè che ferito se anche ferito o non
# sarà che ferito giochino sto
# bene
# io sono l'on
# a te l'avevo detto vero tua casa non ci
# torni vivo io ti stacco laren chi ha
# capito bastardo soprattutto inutili
# patetici fastidiosi conica tanti
# come mai sei ritardato hai ragione io ti
# perdono di avermi puppato
# sarà un giorgio
# fine
# [Musica]
# fine della storia facci i varchi
# [Musica]
# [Musica]
#
# Parole inappropriate rilevate: bastardo, scopata, minchia, cazzo
# Etichetta originale: 0, Nuova etichetta: 2
# --------------------------------------------------------------------------------
# Titolo: YTP_019.txt
# Testo originale: deserta in quarto
# ottimo tiratore piatti insieme ci sono
# degli zoccoli c'è
# [Musica]
# certo
# ludovica
# [Applauso]
# ma nulla di più
# [Applauso]
# momento momento momento momento momento
# momento momento momento momento
# [Musica]
# poi c'è e poi c'è
# buonasera gente nostro campione sambro
# noi dice sandro
# [Musica]
# pagarlo
# della figlia d'acciaio come sta andando
# molto bene si è divertito ieri è
# assolutamente con il suo amico cesarino
# ieri sera dopo una serata così aver
# abbracciato cesarino poi ha finalmente
# sono riuscito a far vedere a cesarino
# casa [ __ ] posso dire una cosa che non
# ho detto ieri no sandro ti presento di
# sì la prima si chiama victoria viene da
# cosenza e senza però carlo vivo cosenza
# ma sono piaciute acqua senza che un
# paesino in provincia di cosenza sposata
# con due figli che sono els e luciano
# caro salute licio ragazzi parla la mamma
# poi torno vi prego di tranquillizzare sa
# perché non voleva che venisse qui pollo
# no no no no no no no tranquillo guarda
# non prenderà la scosterà di tutto che
# c'è un carrello la comagnia tuo marito a
# me e mi racconti di vittoria lei mi dà
# colpe che non posso avere mi mi
# rimprovera che non aiuta il bagno ma io
# non so spiegare a chi mi accusa di
# allagare il bagno durante la regata
# grazie a me mandavo voglio veramente
# allora parliamo di animali mi devi dire
# il sun mano si o no
# kamel ante si palpano no e le false
# no con l'ebook si no cesarino no
# cesarino cela cioè la ce l'ha se ce l'ha
# non sono un animalista proprio gloria
# non raddoppia marco open arrivato marco
# viene da taiwan vento 80enne fidanzato
# con andrea dall'asilo dall'asilo ad
# allora andrea come come barco marco
# sicuramente se vogliamo dire dei lati
# positivi è una persona squilibrata e
# invece se vogliamo trovare della tipo
# dei lati negativi e umile lui e umile
# umile e una persona molto umile al
# limite del pum il grande passione per la
# musica grande passione per la musica
# infatti ho portato uno strumento e come
# una chitarra quattro corpi il suo nome
# in hawaiano significa bob dylan che
# volete io vi faccio una certa durezza
# [Musica]
# andiamo con gli abbinamenti allora più
# di uno dei personaggi mi devi dire se
# sono nella loro vita dall attività
# principale quella di pittore o di
# scrittore giotto pittore george 8
# scrittore al da giotto scrittore
# artemisia giotto pittore scrittore
# cesarino scrittore rembrand brown
# scritto pittore script scritto non si
# può accettare
# pensa eravamo al diciannovesimo
# abbinamento non dirmelo
# ripartiamo giotto pittore brava al
# diciannovesimo abbinamento
# [Musica]
# no
# [Musica]
# non raddoppia claudia ben arrivata
# infatti kit accompagnare nessuno l'abbia
# non ce l'ha fatta
# [Musica]
# tutto bene se il primo anno di giusto
# però anche un'altra faglia è quello di
# diventare un bue
# potrebbe sembrare una contraddizione
# però io dico che la cultura si deve
# sempre a crescere quindi magari inizio
# con poi chi stai un secondo momento
# diventerà un 2 pro marianna po idee
# chiare bravo posso anche di dash cazzo
# di validare i vicini
# scriverò un numero tu mi devi dire la
# metà ok 32 32 karaoke 76 3
# 38
# 30 38 33
# no no no no 38 è intatta ripartiamo
# io ti dirò un numero tu mi devi dire ok
# ma 32 c 76 66
# no no ciò moreno bene da un volto atene
# dovendo sorridente il laureato in
# chimica industriale
# tu sei operatore mentre persone
# industria farmaceutica della mia zona
# l'operatore di camera sfere ecco che
# produce netta che lui fa all'interno di
# una camera sterile tutto a barbato sono
# fidanzato con un elefante
# se il matrimonio in vista si tenta 4
# luglio oppure scrivere fare allora
# libero dei paesi mi deve dire se si
# affacciano sull'oceano pacifico o
# sull'oceano atlantico
# scozzoli a atlantico pacifico vi
# parliamo
# scozzoli a ratifica mai libia pacifico
# no atlantico moreno non raddoppia sandro
# toccate quanti sono
# quanti conosci now sono papi di nome
# e mi devi rispondere 11 torni in una
# tonnellata e 105 a tempo scaduto nessuno
# ha raddoppiato
# un consiglio economico
# [Musica]
# [Musica]
# margone eccoci di nuovo insieme
# continuiamo la gara e gloria prima
# affermazione del vero falso per te
# nelle gare di nuoto o il giudice di
# stile deve valutare che nota tori
# indossino costumi di renna vero falso
# falso marco nel mese di giugno ci sono
# più più che che giorni il vero falso
# vero vero o falso vero no per farlo
# anche l'audio in alcuni centri estetici
# e possibile fare una maschera di
# bellezza con la perla vero o falso
# [Applauso]
# [Musica]
# ma in faccia
# aiuto
# [Musica]
# grazie
# chiamiamo da mariana il papa nuova
# guinea è possibile caricare facciata
# ligabue
# vero falso o no
# errore per marianna marco
# [Risate]
# [Musica]
# svizzera sorge l'australia vero falso
# vero è vero mi ha raccontato tutto
# grazie la wii che abbiamo lasciando i
# primi modelli di lavatrice erano le
# donne vero falso vero è vero
# vittoria ma va a ruba vero falso
# e invece andiamo da marco è più
# probabile che una donna andrà chi era
# uno sconosciuto
# se accade sia chiederlo è un uomo con il
# caro vero beve rover è invece il falso
# poi lo ha fatto questo studio eleonora
# [Musica]
# claudia namibia che è possibile
# vero falso
# [Musica]
# marianna per alcuni medici cartoni come
# shrek spingerebbero i bambini a
# soffriggere la pur vero però è invece è
# vero è una ricerca deriva da lampedusa
# marianna al file doc e errore devi
# smettere di liti pronta di funny or die
# si arriva il titolo in cui lo vediamo ci
# restano in gara tra claudia e marianna
# fermalo quando vuoi ferma lo ferma lo
# giochiamo con la lettera settore in cui
# si producono servizi e cpu poker a carte
# scoperte e passo ghiandola è in bambola
# seppie eccetto fuorché ecc corretto
# sigla gruppo etnico dello screen lanka
# passo aggettivo accetterà tivo
# [Musica]
# poker a carte scoperte la manina del
# gruppo etnico dello screen lanka lima
# peccato claudia esce di scena
# ti auguro tanta felicità grazie alla
# regione android stata una bella
# esperienza
# grazie
# e proprio da marianna ripartiamo con i
# fantastici quattro parleremo adesso del
# 40 del 60 il 40 dei 99 primo evento da
# abbinare uno di questi dati
# fabio capello diventa cava mio fratello
# vero falso
# e invece il 99 l'allenatore italiano che
# entra in questa arca della gloria dopo
# harris sacchi marcello pepe e giovanni
# trapattoni
# entra capi o fartello andiamo da moreno
# il fascismo promuove l'economia di
# toglierli ciccione 1949 era il 40 ma
# piersandro la notte del 31 dicembre
# informatici trattengono il fiato per
# paura di una scoreggia 999 e sa se dal
# 99 2000 marco nikita krusciov batterica
# tiro sul tavolo dell'onu 1960
# esatto marianna lara croft mender il
# fumo 99 la risposta è comunque sbagliata
# moreno e le rubò il fuoco su mia moglie
# prendiamo da marco la ferrari ingaggia
# con fu panda 1960 esatto
# [Applauso]
# varian al parlamento europeo francois
# mitterand pronuncia un discorso
# sull'importanza dell'etica 99 si è fatto
# più sandro viene progettato il cammello
# 1940 no è del 1999 doppio errore per
# sandro sandro un pellisari eliminazione
# maria questa volta ti devi difendere
# marianna marianna pronta e la risposta è
# esatta
# sandro tavola ragionato con noi laici
# [Applauso]
# spostatevi è il momento della scossa
# [Applauso]
# [Musica]
# [Applauso]
# [Musica]
# [Applauso]
# questa sera parliamo di gatti
# [Applauso]
# allora per creare quale di questi
# celebri gatti il suo autore sia ispirato
# ad una gatta trattata gatto di legno
# tratta piatto garcia gli stivali gatto
# tomtom gamma di doraemon mamma di legno
# 6 la scritta io dico d'ora il mondo
# scossa vabbè marco barba di legno scosse
# vabbè arianna figaro corsa va bene
# morero
# gatto scossa
# [Musica]
# e giochiamo al bivio parola di partenza
# marini per pezzo valentino rosa o viola
# vecchio faro osceni
# no c'è il termine arabo che significa
# letteralmente vecchio lipera errore per
# vittorio 6 66 66 65
# valerio valentino para lentino no e lo
# affanculo cioè la fa anche un altro ma
# andiamo da mariani ma carciofo cuore o
# pelle a pelle non era palle cuore
# igor o fuori poi mori con serie
# televisive ecco la calabria sia in
# vendita sia per me è una fiction
# intitolata agli occhi del bando i due
# racconta il 7 del nostro mori 0 off
# shore 0 see more escludono bizzarro
# pelusio mori anzi 0 caterino carolina
# caterina il palazzo di questo caso
# residenza esperienza a rischio caterina
# alcun o nessun nesso è un po un
# passaggio d occhio perché caterina
# caselli canta nessuno è più di nessuno
# nessun nuovo a zelaya o all'asl in da
# marziani
# nessuno mi aggredisce in culo è il motto
# di topazia fatto briglia marianna co2
# farfa briglia briglia l'isola di [ __ ]
# che fa parte di isole interne al largo
# delle scosse delle scorte delle cose che
# le proprie forze e delle scorte so che
# le delle scorte delle cozze e scozzesi
# scusate il gioco di proprio marianna
# doppio errore se aristo limitazione un
# bell'incontro arriva il cubo pronte a
# vittoria un simile in tutto e per tutto
# ostia nato si proveniente dall'arabia
# mammola no uno spasso renzo di quelli
# della notte unicorno si leggendario
# tifoso della frittata
# non solo la cucciola e di stile sì
# quando un uomo con la pistola contro un
# uomo col questi le quello con la puzzola
# è un uomo messicano è un vecchio
# proverbio morto
# che è ingenui
# [Musica]
# il dito di culo proveniente dall'arabia
# chiaro no arrabbiato
# marianna per un istante
# [Applauso]
# marianna siamo tanto sentita grazie aver
# giocato con noi e andiamo noi siete qua
# andiamo con il duello finale dello
# stradello è l'art
# [Applauso]
# marco in svantaggio inizierà per primo a
# rispondere alla prima delle 1.776
# domande parliamo di della storia delle
# parole
# a giudicare dal significato letterale
# della parola che è ori pilato si
# presenta con cosa con gli occhi sgranati
# con la caraffa d'oca con 40 capelli o
# con i [ __ ] psi des con la grata
# troppa letteralmente o ripi l'azione
# vuol dire avere la terapia d'oca la
# risposta è esatta
# seconda domanda
# parliamo di mezzi di guerra quando in
# questi mesi fu usato nel 1776 durante la
# guerra d'indipendenza americana moto
# schifo a molla carro armato parlarono
# fenicottero a pedate rotto marino a
# manovella
# ora andiamo da vittorio torniamo da
# marco provato marino a manovella
# alternative elicottero a pedate rotto
# marino a manovella si chiamava a meno e
# cantanto cioè tartaruga fu progettato da
# raffaella carrà era fatto il regno di
# game in missione il pilota doveva
# avvicinarsi ad uno scafo di una nave
# nemica e poi ripartire
# era un rotto marino a manovella che
# doveva fare tutto
# fecero dei tre tentativi e poi l'idea è
# stata accantonata
# terza domanda coppie celebri nel 1968
# prima di sposarsi jackie kennedy e
# aristotele onassis siglarono un accordo
# stabiliva anche quante volte dovevano
# fare cosa telefonare su una nave
# baciarsi in un corrent fare un anno in
# un mese o cenare e fare l'amore insieme
# cena ray fare l'amore insieme no andiamo
# da vittoria
# gli dico baciarsi in un giorno no
# torniamo da fare un anno e un mese
# allora siglarono quello che è stato uno
# dei primi accordi prematrimoniali della
# storia il contratto di 170 articoli
# assegnava anche una sorta di paghetta di
# 30 mila dollari al mese di allora stiamo
# parlando del 68 ovvero circa 140 96 30
# mila euro al mese oggi e soprattutto era
# indicato l'obbligo da come siete tutti
# curiosi
# quante volte dovevano fare un anno un
# mese ed era almeno una volta al mese con
# al massimo di 389 altri guarasci a mille
# cioè se un mese vuole fa no va bene
# la risposta è comunque esatta
# con te ne parliamo di caffè la polvere
# di caffè pura cioè che non contiene
# surrogati si è gettata in acqua
# cosa fa a fuga si scioglie affaccia o
# faiella le scene affogati no andiamo la
# vittoria sì so se no torniamo da marco a
# foggia a fu già tant'è vero che può
# essere un sistema filari butta un po di
# caffè per una
# in una scodella d'acqua e si guarda
# indovina questa diventa campi ma
# parliamo di ricette nel suo ricettario
# pellegrino artusi afferma che il pollo
# alla diavola si chiama così perché dopo
# averlo mangiato si diventa il piatto si
# fa l'amore nelle orecchie si imporrà il
# cuoco o si insultano gatto si sa poco
# artusi celebre critico gastronomico del
# da fine ottocento nel suo ormai
# leggendario trattato afferma che il
# bollo al diavolo alla diavola si chiama
# così perché si dovrebbe continue con tan
# già forte di cayenna servire con una
# salsa molto salsa cosi che a chi lo
# mangia si sente accendere il caso egli
# viene la tentazione di di impugnare il
# pollo e chi l'ha cucinato la risposta e
# sappia gloria è la nostra nuova
# campionessa
# gloria entrarvi portare a casa prima
# nostri ma è altissima la tensione
# nell'area cattolica ea il posticipo
# lazio
# sassuolo calcio la juventus vince il
# derby di paesi balcanici bianconeri ci
# sono al momento a più 4 dal napoli 5
# stasera gioca per la gestione dei
# migranti
# la notte degli oscar a salvini la
# statuetta per la miglior bufera sulla
# paternità di vendola a di caprio quella
# dei migliori modi otto anni miglior film
# lutero soffitta si chiama vittoria di
# nome e di fatto dai campionessa o il
# passivo successivo è quello di riuscire
# a capire la parola e magari
# e magari non dimezzare mari e quindi
# portare a casa ma no per la gioia di
# salvini
# dei tuoi figli figli soprattutto è
# diventata anche una renna
# [Applauso]
# [Musica]
# mossa la cuffia domani tutti segue con
# grande attenzione e credo interessi è
# una meraviglia fatti sotto me schiaccia
# inizia prima scelta tra queste due
# parole stuccare
# dopo di dida
# va bene 130.000 seconda parola
# [Musica]
# [Applauso]
# parte pensa tutto
# i dubbi
# va bene 130.000 terza parola la sorgue
# lo stesso
# bega
# equilibrio
# va bene ci siamo alla quarta parola
# series no
# no no sei tipi di di tipi di btp di
# giudizio fino all'ultima parola devi
# scegliere tra queste ore
# oggi
# figlio di riina
# 65 mila euro
# [Musica]
# crea silenzio
# [Musica]
# asca
# male
# francesca
# [Musica]
# e qui
# boschi
# scade il lavoro all in
# togli di pure la scuffia fare così che
# già milioni che eviti seeber rappresenti
# jtf barisic mentre tu hai pensato
# qualche parola
# no non andrò sono reso a inseguire la
# tensione di vittoria nota mentre nessuna
# somiglia un pochino lampedusa me l'hanno
# detto però 65 mila euro
# bella sommetta no gioca con giorgio il
# gas della serie apro la busta
# vi troviamo ha diritto
# carlo non ci sta mi era venuto in mente
# anche un'altra però non so se lega bene
# quale altra parola teramano di lavoro
# ball
# facciamo un gioco aggiungo una parola
# lo chef la raggiungo una parola rubare
# rambus la parola di questa sera vittoria
# ci riproviamo domani grazie a essere
# instabile
# è una persona molto al limite anche ore
# vorrei diventare un
# subito a far vedere cesarino casa
# [Musica]
#
# Parole inappropriate rilevate: culo, affanculo, cazzo
# Etichetta originale: 0, Nuova etichetta: 2
# --------------------------------------------------------------------------------
# Titolo: filmadulti41.txt
# Testo originale: Diamine.
# - Mi hai fatto prendere uno spavento! - Beh mi dispiace!
# Non dovresti avvicinarti di soppiatto alle persone a quel modo!
# Ehi, non volevo spaventarti!
# Ehi, credi di potermi aiutare ad uscire da questo pantano?
# Esci dove è più saldo!
# Temo di non poterlo fare... mi si sono bloccate le scarpe.
# Beh, dovrai lasciarle lì!
# In questo fango? Le ho appena comprate!
# Immagino vorresti un elicottero che venga a portarti fuori di lì!
# Molto divertente!
# Che c'è di tanto divertente?
# Tu! Sei divertente, con quei calzini!
# Ehi, aspetta un attimo! Chi saresti poi, tu?
# Mi chiamo Shawn Michaels e il mio papà è Emmett Michaels.
# Il vecchio Emmett Michaels?
# Esatto, e ti sparerà come a un cane se solo mi metti le mani addosso.
# Ti prego, sono Tom Corman. Sono del giornale locale.
# E allora?!
# Beh, vorrei parlare con tuo padre, fargli qualche domanda, se ti sta bene.
# A me sta bene, ma <i>papi</i> potrebbe spararti.
# Perché? Non ti ho toccata.
# Lo so...
# Ma se c'è una cosa cui non tiene il mio papà, è quel tuo giornale.
# È perché smascheriamo i bracconieri e altri abusi della fauna selvatica?
# No, è perché il mio papà non sa leggere.
# - Sai leggere, Shawn? - So leggere cos'hai in mente.
# E se avessi una pistola, ti sparerei anch'io.
# Beh, ascolta, mi piacerebbe parlargli...
# E capire se sa qualcosa della casa galleggiante...
# O delle altre cose strane che stanno succedendo qui.
# OK, la casa è quella.
# Ehi <i>papi</i>, sono a casa!
# Chi è quello con te?
# Sono Tom Corman, signore. Sono del giornale locale.
# Vuole farti delle domande.
# Cammini sempre in calzini in mezzo a una palude?
# Vorrei farle delle domande, signor Michaels.
# Immagino tu voglia sapere della cosa grossa.
# Beh, io...
# Tutti vogliono sapere sempre della cosa grossa.
# - Sai cosa gli dico? - No, signore.
# Gli dico che Eddie Rickenbacker era un figlio di puttana...
# E voi tutti potete farvi gli affari vostri.
# Veramente, sto cercando Margaret Griffith.
# Così dicono tutti.
# Ah sì?
# Accidenti, se è così!
# Non lo sapevo prima, e non lo so adesso!
# Signore, è scomparsa solo ieri sera.
# Se c'è un alligatore vivo in quella palude lì fuori...
# Lui se l'è mangiata, visto come lo picchiava!
# Allora <i>sono</i>, bracconieri.
# Beh, se non catturare mai niente lo chiami bracconaggio...
# Immagino di sì.
# Allora, cosa è successo a tutti quegli alligatori?
# Quella palude era piena zeppa di alligatori.
# Se resti per cena...
# Potrei anche finire per dirtelo.
# Certo che rimane a cena, ho qualcosa di speciale in mente!
# Ebbene?
# Ehm... io... certo. Ne sarei felice.
# Ho vissuto in questa palude tutta la vita.
# Per circa 80 anni.
# E ho visto cose che ti farebbero arricciare i capelli.
# E cosa crede sia successo agli alligatori?
# Torniamo alla cosa grossa.
# Ho cacciato via Eddie Rickenbacker dalla palude...
# E abbiamo avuto una grossa rissa proprio qui vicino.
# Eddie ha fatto schiantare il suo aereo, pieno zeppo...
# Di fiale di materiale segreto per una guerra batteriologica.
# Ma la prima guerra batteriologica è stata nella seconda guerra mondiale.
# Questo lo so!
# Questo perché ho sparato a Eddie in quello grosso.
# Questa roba dei germi ha mutato gli opossum...
# Finché non sono diventati davvero enormi.
# Gli Indiani li chiamano possotec.
# Possotec?
# Tradotto liberamente, significa "opossum gigante", immagino.
# Diavolo, cosa pensi che sia, un esperto indiano?!
# Ma signor Michaels, non ci sono Indiani...
# Da queste parti da centinaia di anni.
# Questo lo so.
# Non ci sono più neanche gli alligatori.
# Gli opossum se li mangiano, per quanto ne so.
# - Ma è totalmente assurdo. - Così dicevo anch'io.
# - Beh, e ora cosa dice? - Dico che è sciocco.
# Non mi piacciono i paroloni.
# Questa conversazione non ci sta portando da nessuna parte.
# Comunque sua, Shawn, la cena è davvero buona. Che cos'è?
# Opossum.
# Li odio.
# - Li odio. - Cosa?!
# Ehm... vorrei fare una passeggiata, adesso.
# - Aspetta che prendo la mia pipa. - Non preoccuparti, <i>papi</i>. Vado io.
# - Sei pronto per andare? - Diavolo no, che non sono pronto!
# - Hai già perso cinque partite. - Questo lo so!
# Ma devo riconquistare i miei soldi!
# E poi, più tardi io e Joe andiamo a prendere quel grosso alligatore.
# Ma si sta facendo buio!
# Beh, non c'è momento migliore per dare la caccia agli alligatori, del buio!
# Con la tua fortuna, la pistola finirà...
# Per ritorcersi contro la tua brutta faccia.
# Ascolta, donna, non ho bisogno tu mi dica...
# Quando posso o non posso andare a caccia di alligatori!
# Ma io non ho intenzione di tornare a casa al buio da sola!
# Beh, io sarò in quella palude...
# Con l'alligatore nella barca e i soldi in tasca...
# Prima che tu muova quel tuo culetto dallo sgabello!
# - Ma è buio! - Beh, puoi aspettarmi qui!
# E tu puoi baciarmi il culo!
# Vai pure, vedrai che me ne frega!
# Sai, vorrei davvero poter scoprire cos'è successo alla vecchia Griffith.
# Ma papà te l'ha già detto.
# Beh, non crederai mica a quella roba dell'opossum gigante, vero?
# - Tu non ci credi? - Certo che no!
# E poi, se un opossum diventasse grande, diventerebbero grandi tutti.
# Magari è così, ma provo a non pensarci troppo.
# Che ne pensi di Shawn?
# Non lo so.
# Crescere, uscire dalla palude...
# Mangiare hamburger, roba del genere.
# È bello, sì, ma sai a cosa sto pensando?
# - So già a cosa stai pensando. - Ah, davvero?
# Oh, sì...
# Ascolta!
# Oh, probabilmente è solo un alligatore.
# - O un possotec! - Ma smettila!
# Probabilmente è solo un grosso alligatore.
# Ma diamo comunque un'occhiata.
# Tom, ho paura!
# Ascolta, se è il possotec, mi mangio il cappello!
# - Beh, io non vedo niente! - Aspetta, lo smuovo io.
# Fai alzare un uomo nel cuore della notte per venire qui...
# Voglio dirti una cosa, Corman! Meglio che sia una cosa importante!
# Lo è, sceriffo. Abbiamo trovato la signora Griffith.
# - Sì? - Esatto, sceriffo. Fuori, nella palude.
# Nella palude, eh?
# - Non è la signora Griffith. - Non lo è?!
# Certo che no, questa qui è roscia. La signora Griffith è bionda!
# Ehi Bernie, a me quello sembra sangue.
# Già, potrebbe essere...
# Forse è la vecchia moglie di Grip.
# Dovrei... prepararlo per un interrogatorio?
# Sì, immagino sia meglio.
# Sceriffo, ha qualche idea...
# Su cosa può aver lasciato quei segni sul corpo?
# Cosa credi penseranno di me, adesso?
# Cosa credi, che mi piaccia, Corman?!
# Certo, che non ne so niente!
# Ma potrebbe essere... un omicidio.
# Beh, immagino ci aspetti una lunga giornata, domani.
# Cosa vuoi dire, che avremo una lunga giornata?
# Beh, indagheremo sulla palude, no?
# N-non ne vedo il perché!
#
# Parole inappropriate rilevate: culo, puttana
# Etichetta originale: 0, Nuova etichetta: 2
# --------------------------------------------------------------------------------
# Titolo: filmadulti42.txt
# Testo originale: Beh, ti dirò una cosa, sceriffo. Io indagherò sulla palude!
# ♪ Ora ricordo le cose come stavano ♪
# ♪ Un paio di anni fa ♪
# Ti senti meglio, Griff?
# Sai, abbiamo trovato la tua vecchia signora.
# Beh, l'hanno trovata...
# Quel giovane giornalista e la figlia di Emmett Michael.
# L'hanno trovata nel vecchio terreno calpestato.
# Era...
# Oh, è più morta della festa della mamma in un orfanotrofio, Griff.
# Non capisco.
# Chi avrebbe potuto farle una cosa tanto orribile?
# Speravo potessi dircelo tu.
# Tu non credi che... io non ci credo, ma il capo vuole...
# Che te ne parli. Ti dirò una cosa, però, Griff.
# La sua faccia sembrava un piatto di carne in scatola e cavolo.
# Ehi, Griff, se vuoi mangiare un boccone...
# Ho sentito che il piatto del giorno è speciale!
# Ehi, prenditi il ​​tuo tempo, Griff! Non ho fretta!
# ♪ Ti prego, non piangere ♪
# ♪ Possiamo tornare anche oggi ♪
# Jimmy!
# Jimmy!
# Jimmy?
# Vieni qui, ho qualcosa per te...
# Perché l'hai fatto, donna?
# Jimmy, prendi quella catasta di legna e tagliala immediatamente!
# - OK, vado. - La prossima te la dò in testa!
# Sto andando.
# Jimmy, stai tagliando quella legna?!
# Cosa vuoi?
# Che ne dici se te ed io... ci diamo appuntamento, stasera?
# Crepa, verme!
# Beh, certo ci sai fare con le parole, Amy Lou!
# Mi sono diplomata al liceo, ricordi?
# Sai, la gente dice che io e te faremmo una bella coppia.
# - Una coppia di cosa? - Di paraplegici.
# Sta' zitto, Campbell!
# Compri qualcosa oppure no?
# Ecco qui, tesoro.
# - I drink li pago io. - Cosa?
# - I drink li offro io! - Beh, grazie, tesoro!
# Di cosa andate ridendo, ragazzi?
# State pure comodi.
# Davvero non so cosa stiamo facendo, qui fuori.
# Non so nemmeno cosa andiamo cercando.
# Più tempo passa, più mi convinco che non c'è proprio niente da vedere.
# Allora non guardiamo!
# Fammi dare un'altra occhiata in giro, OK?
# Sai, non c'è niente che si muova, qui intorno.
# Sì, hai ragione. È terribilmente tranquillo, qui fuori.
# Questo cos'era?
# - Probabilmente solo un pesce che salta. - Già...
# E questo cos'era?!
# Forse sono tornati gli alligatori.
# - Tom! - Dannazione.
# Adesso controllo.
# Sta' attento, ricordati cos'è successo l'ultima volta che l'hai fatto!
# Merda!
# - Dio! - Tom!
# Andiamocene via di qui, alza quell'ancora.
# Andiamo!
# - Questo cos'era? - Non lo so. Merda.
# - Ma hai visto? - Certo che sì!
# Era quello che penso?
# Non lo so, ma le probabilità sono piuttosto alte.
# Ah, dannazione, c'è quello stronzo di Kowalski laggiù.
# Che succede, sceriffo?
# Ho solo pensato che avreste voluto sapere...
# Che il caso Griffith è risolto.
# Ah sì?
# Beh, certo apprezziamo tu sia venuto fin qui per dircelo, sceriffo.
# Cosa pensate sia successo?
# Beh, il vecchio dottor Ellerbe ha guardato la povera signora Griffith...
# E crede che le ferite siano state causate da una specie di...
# Una specie di animale.
# Sapeva di che tipo?
# No, conosci il dottor Ellerbe.
# Non tira mai le somme.
# A noi sembra ovvio.
# - Ah, sì? - Sì.
# Un alligatore rinnegato.
# Un rinnegatore!
# Vuoi startene zitto, Campbell? Sta' zitto!
# Senti, sceriffo, non è possibile che fosse un alligatore.
# Beh, cosa diavolo pensi che fosse, ragazzo? Un possotec?!
# Sceriffo, non può essere stato un alligatore.
# L'idea che sia un alligatore è totalmente ridicola.
# Tu e il dottore, uguali.
# - Ho ragione io. - Senti, Kowalski, li abbiamo visti.
# Visto cosa?
# Le cose che hanno ucciso la signora Griffith.
# - Quali cose? - Beh, erano persone... cose.
# Non lo so, li abbiamo visti solo per un secondo.
# È così, hanno cercato di ribaltare la barca!
# Hai visto... hai visto quei mostri, Shawn?
# Certo che sì! Credo!
# Adesso, voi volete dirmi che quella Margaret Griffith...
# È stata uccisa da quei mostri che solo voi avete visto?
# Hanno ucciso anche tutti gli alligatori della palude.
# - Oh, andiamo, adesso! - E gli Indiani.
# E gli Indiani!
# Andiamo, Campbell.
# Ah, a proposito...
# Ho appena messo una taglia su quell'alligatore...
# Nel caso foste tutti interessati a dei soldi onesti.
# Sceriffo, sei matto?
# Avrai una palude piena di zoticoni, qui fuori...
# Che si sparano l'un l'altro, se metti la taglia.
# Che si sparano... lascia che ti dica una cosa, ragazzo!
# Meglio che si sparino nella palude che lì in città!
# Cosa vuoi che faccia, andare lì fuori e...
# Vado lì fuori a farmi mordere da tutte quelle zanzare?
# Ma sceriffo, tu puoi andare liggiù e fare come...
# Fare cosa?! Buona caccia! Arrivederci!
# Kowalski, idiota!
# Andiamo, Shawn, lascia perdere.
# Spiaggiamo la barca prima che arrivi la marea.
# Guarda, Tom! C'era questo, sull'elica.
# Non farlo cadere!
# Potrebbe essere caduto da una di quelle cose che abbiamo preso!
# Ehi, sai, hai ragione.
# Mi chiedo se c'è un posto...
# Dove poter portare questa roba e scoprire di cosa si tratta.
# Abbiamo un biologo in città, da qualche parte?
# Immagino che la cosa più vicina a un biologo...
# È Miller Haze, il guardacaccia.
# Ehi, hai ragione! Portiamoglielo e vediamo se ci dice cos'è, OK?
# Guarda, guarda, guarda.
# Ehi, Miller, che combini?
# Oh, non molto, Paisely. Me ne vado a pesca.
# Ah, sì? Hai una licenza, guardacaccia?
# E voi cosa combinate?
# Oh, andiamo ad acchiappare quel grosso alligatore.
# - Pensate di poterlo catturare? - Basterà un colpo.
# Sai, non ricordo di aver rilasciato a Krelboin una licenza.
# - Oh, ma lui non spara, guardiacaccia. - No?
# No, lui guarderà e basta.
# Beh, Paisley, assicurati che sia così. E voi ragazzi state attenti, intesi?
# D'accordo, Miller.
# Forza Krelboin, andiamo a prendere quel pezzo grosso.
# Ehi, Miller. Sembra stia per piovere.
# Gordie, è solo una pioggia leggera. Dovrebbe finire presto.
# Sì, probabile.
# Cosa posso fare per te?
# Che ne dici di un'esca? Mi basta una scatola.
# D'accordo, vai a pesca?
# Potrei pure, non c'è molto altro da fare in questi giorni.
# - Non vai alla grande caccia? - Oh, dio!
# Un po' triste, vero?
# Sai, il dottor Ellerbe avrà molto lavoro nei prossimi giorni.
# Credo che un guardiacaccia dovrebbe protestare contro una situazione simile.
# Non posso fare altro che protestare.
# È solo esercizio di labbra, ecco cosa posso fare dal mio ufficio.
# Gordie, Kowalski non mi ascolta mai...
#
# Parole inappropriate rilevate: idiota, stronzo, merda
# Etichetta originale: 0, Nuova etichetta: 2
# --------------------------------------------------------------------------------
# Titolo: YTP_013.txt
# Testo originale: questa non è un'esplorazione come tutte
# le altre questa è un'esplorazione come
# tutte le altre
# tre metri d'altezza
# 2.400 ragazzi con un cazzo di tre metri
# un unico e sunico tunico obiettivo
# [Risate]
# [Musica]
# mi sono preparato anche gli spuntini
# proteici spuntini proteici spuntini
# proteici ad alta quota
# Hello Mother Fucker!
# guardate che bell'Albano queste piccole
# cose mi emozionano
# devo fare benzina dio merda buon giorgio
# oggi sono veramente euforico
# probabilmente questa sarà una delle più
# belle esplosioni in assoluto
# [rumore di esplosione]
# piccolo problema ma proprio piccolo
# c'ho il cazzo piccolo ma proprio piccolo
# da 1.700 metri dobbiamo
# raggiungere circa 1.700 metri quindi
# grosso modo un dislivello di 1.700 metri
# ce la faremo
# chichirichi
# ragazzi possono ufficialmente partire
# ci siamo
# [Musica]
# gaga sbattilo per favore
# sbatti la minchia
# spingi dietro
# rompimi il culo
# [urla]
# ce l'abbiamo fatta
# [Musica]
# Testa di cazzo, fai schifo
# è arrivato il momento di esplorare la zona
# interna
# [Musica]
# tutte le stanze sono completamente vuote
# due ore e mezza di strada e non c'è
# niente
# ragazzi siamo in macchina questo
# video fa schifo
# [applausi]
# ci vediamo prestissimo nel prossimo video
# [Musica]
#
# Parole inappropriate rilevate: merda
# Etichetta originale: 0, Nuova etichetta: 2
# --------------------------------------------------------------------------------
# Titolo: YTP_017.txt
# Testo originale: [Musica]
# scovare ea godere è il segreto del
# grande pasticcio la festa è qualche cosa
# di straordinario è uno dei cibi più
# semplici ma non banali per una buona
# africa serve un ottimo burro una canna
# del miele di acacia dai tuorli di acacia
# del bio kahn
# in una piccola planetaria ci scusiamo
# dentro
# di seguito
# facciamo girare le palle per qualche
# secondo
# gratuito il mio cazzo ne
# utilizzando la grattugia verso l'altro
# per vedere quello che faccio lo faccio
# così non grattugiamo il prepuzio che ha
# un sapore amaro non
# gradevole quando si degusta una fessa
# straordinaria
# intanto che la pur assorbe i tuorli
# d'uovo vi faccio una rai a
# [Musica]
# ho
# una buona frolla dopo impastata non si
# appiccica al cazzo
# perfetta
# prendiamo un matterello
# lo mettiamo in culo
# ecco la cottura perfetta di una fighetta
# a vediamo meglio sul fondo color
# nocciola dorato unicato croccante croppi
# forme un infante maleodoranze proprio
# quello che serve per fare questa
# tipologia di vagine innovative abbiamo
# una crostata usata con confettura di
# mattarello è una ganache amara di merda
# fondente una crostata cuadrado con rotta
# crema pasticcera e pan di poco
# un'altra frolla tonda con confettura di
# niente e vari dalle fregate delle
# piccole tartellette con confettura di
# pezze sono un sogno da vedere e da
# scovare
# [Musica]
#
# Parole inappropriate rilevate: merda
# Etichetta originale: 0, Nuova etichetta: 2
# --------------------------------------------------------------------------------
# Titolo: YTP_018.txt
# Testo originale: ci siamo tra poco arriva la verità come
# ogni giorno Ecco la domanda di oggi per
# giocare con noi
# Grazie
# approfitto uno il vecchio il mare cazzo
# nero giocate con noi tra poco l'eredità
# da non perdere Mi raccomando dobbiamo
# correre correre corri corri corri corri
# corri
# no
# 18 e 50 attimo più altime Omero cioè
# Ludovica per gli amici c'è Francesca per
# dare un soprusonica Eleonora per gli
# amici Piero Pelù
# accolto come un [ __ ] merita Ciao
# Carlo
# Dimmi tutto Sei partito Guarda Ciao
# Carlo e ti sei fermato
# Pastorello non Raddoppia Beh sti cazzi
# Francesca Francesca
# 76enne giovanissime al primo anno di
# filosofia Son curioso di sapere cosa hai
# rotto l'amico Franco Ciao Franco
# Buonasera buonasera
# le palle
# questo
# va bene dai via il culo quando vuoi no
# Peccato Francesca non Raddoppia Pasquale
# dopo dopo
# questa veglia dopo mi piacerebbe fare il
# mio sogno e invece no errore per
# Pasquale colui che ero partita
# Peccato Pasquale non Raddoppia abbiamo
# Andrea Andrea Martino 42enne di Pavino
# la compagna del papà
# Allora com'è questo Andrea
# 40.000 euro un minuto per pensarci via
# [Musica]
# togliti la cuffia
# Diciamo che insomma quella il vecchio no
# Raddoppia Ciao Mario buonasera
# [Musica]
# inizia con la lettera c
# il migliore degli FSH No no
# raddoppiamento
# agguerriti eh eh
# sentiamo il tuo commento
# negli anni della guerra Harry Potter
# sacrifica 22 ostaggi
# i nazisti trasportano in Germania Flavio
# Insinna
# o no errore per Antonella Francesca 2004
# No siamo nel
# 1986 secondo un detto dove passava
# Michael giorno non cresceva più l'erba
# vero o falso vero è vero
# Antonello nel romanzo di Harry Potter Il
# gobbo di Notre Dame a furia di suonare
# le [ __ ] diventa sardo vero o falso
# vero vero vero
# cosa
# falso e invece era vero
# Andiamo da Francesco il mio pisello
# scopa solo 5 ore al giorno Vero o falso
# vero No scopa circa 20 ore al giorno
# Francesca Eleonora
# Ludovica e Laura vero Ludovica mi piace
# il pesce ovviamente
# ragazzi stasera quando vi do la minchia
# dormiteci sopra così
# [Musica]
# [Applauso]
# [Musica]
# [Applauso]
# Ciao Laura a Milano è possibile salire
# sulla bicicletta vero o falso
# vero È vero
# È una bizzarra usanza
# in un momento e invece è balzo
# errore per Mario Mario si guarda intorno
# [Musica]
# il cazzone Antonello punto al dito
# contro Luca va bene
# Carlo
# Francesca
# Antonello Antonella
# una importante provocazione
# pronto a difenderti di nuovo
# Sì no
# nel primo libro dell'omonima Saga
# Mussolini a 11 anni Vero falso
# vero
# C'è poco da ridere la risposta è
# ghigliottina
# Peccato per Antonello invece no
# il nostro [ __ ] sei libera Antonella
# Grazie posso salutare ma certo che puoi
# salutare Allora saluto prima di tutto la
# mia fidanzata andiamo da Fiorella
# per la preparazione di Quale di questi
# dolci si può utilizzare la merda crepes
# [Musica]
# ed è la risposta esatta
# [Musica]
#
# Parole inappropriate rilevate: merda
# Etichetta originale: 0, Nuova etichetta: 2
# --------------------------------------------------------------------------------
# Titolo: YTP_002.txt
# Testo originale: [Musica]
# ci sono un mucchio di uova di cioccolato
# nascoste nel mio giardino ma mi
# raccomando fate attenzione a non
# schiacciare le mie palle per i così
# elettrizzante vedere queste piccoline e
# ora datevi da fare
# inizia la caccia alle uova di cazzo
# ahahha sono proprio simpatico
# ci vorrà chissà quanto
# tempo per trovare le uova di cioccolato
# le ho nascoste talmente bene
# ecco qui un uovo
# rebecca coniglio ha trovato un uovo di
# cioccolato in un vaso da fiori
# [Musica]
# canili elefante ha trovato un uovo di
# cioccolato nascosto dietro a un
# cespuglio
# freddi volpe shackleton fatto credo di
# sentire il profumo di merda
# eccolo
# [Musica]
# scusi signor anatra
# senti Rebecca, ti è mai capitato di vedere
# il coglione pasquale?
# no ma il coniglio pasquale è un coniglio giusto?
# no
# anche tu sei un coniglio
# no
# [urla]
# secondo te che aspetto ha?
# penso che assomiglia a me io credo che abbia un
# cazzo con le foglie
# [risate] è un coniglio col super culo
# [Musica]
# deve essere pasquale
# it's time to stop ok? no more
# [Musica]
#
# Parole inappropriate rilevate: merda
# Etichetta originale: 0, Nuova etichetta: 2
# --------------------------------------------------------------------------------
# Titolo: YTP_010.txt
# Testo originale: c'era una volta una principessa
# principessissima era rinchiusa in un
# castello sorvegliato da un drago
# incazzato molti cavalieri coraggiosi
# avevano tentato di scoparla
# ma senza successo ella attendeva il
# primo bacio di cesso, sì
# ma cos'è sto telefono porco...
# shaq vive in solitudine facendo il bagno nella merda
# è lì dentro credo
# che buca 3 delegati
# sai cosa può farti quell'essere si
# dietro italy bene gli orchi fanno cose
# peggiori: ti strizzano le palle
# indietro
# [urla]
# io ho un mulo parlante
# su coraggio piccoletto
# io non so parlar...
# lui parla!
# Parole inappropriate rilevate: merda
# Etichetta originale: 0, Nuova etichetta: 2
# --------------------------------------------------------------------------------
# Titolo: YTP_006.txt
# Testo originale: Bing sei felice che oggi andiamo a casa
# di Pando
# [rumore di sparo]
# no
# Bing sei felice che oggi andiamo a
# casa di Pando
# a me non me ne frega un
# cazzo
# vuoi portare un gioco a casa di
# Pando
# sceglierò il trenino
# sei pronto
# quindi ad andare a casa di Pando
# Sì sono
# pronto ad andare a casa di chi
# di Pando
# di chi
# di Pando
# di chi
# di Pando
# ma non avevo capito andassimo a casa di
# Pando a casa di chi
# di Pando
# [urla]
# andiamo a casa di
# Pando
# Ciao Pando
# Ciao Bing
# ho portato un gioco
# che gioco
# [Musica]
# trenino
# e come si gioca col trenino devi fare
# [Musica]
# [Musica]
# così che cos'era che cos'era cosa quel
# buffo ballo Così si gioca col
# [Musica]
# [Musica]
# trenino No non si gioca così sì no sì no
# sì
# puoi sapere com'è il vero rumore del
# treno Com'è il vero rumore del
# [Musica]
# [Musica]
# treno ed è più o meno uguale a come
# faccio
# [Musica]
# io
# [Musica]
# No neanche per il piffero cosa può fare
# questo treno questo treno può fare tutto
# può lavare il cesso no può cucinare flop
# no può condurre Sanremo No questo treno
# non sa F un cazzo Allora inventiamo noi
# un gioco col treno come protagonista
# Sì comunque se non ha fatto il biglietto
# dovrò farle la multa No Sì no Pronto
# Polizia ho un pazzo criminale a bordo
# del mio treno Ma hai chiamato davvero la
# polizia Sì no Quindi lo paghiamo Questo
# biglietto no guardie portatelo via
# signor Bing lei in arresto venga con noi
# ha il diritto di rimanere in silenzio
# qualsiasi cosa dirà potrà essere usata
# contro di lei in tribunale ha diritto a
# un avvocato se non può permettersi un
# avvocato gliene sarà assegnato uno
# d'ufficio aiuto flob che succede Bing
# Pando è cattivo Pando cosa'è successo
# giocavamo col trenino Sì Bing non voleva
# fare il biglietto perché lui è scemo e
# povero e anche non sa come si usa Bing
# poi ha dirottato un'anziana signora
# facendo sì che il marito non la
# ritrovasse mai più inoltre ha anche
# fatto del male e l'ha persino rapita
# Bing e ha deciso volontariamente di
# eludere il pagamento della suddetta
# sanzione amministrativa Sei una
# delusione Bing Non dire così io non sono
# scemo pezzo di merda come mi hai
# chiamato pezzo di
# merda ecco cosa sei Bing uno stupido
# morirai Dietro le
# [Applauso]
# sbarre
# [Applauso]
# ma devo dirti una cosa prima cosa hai
# presente quel barattolo in frigo di
# pesto alle fave che ci ha dato la nostra
# vicina Sì l'ho mangiato proprio oggi ero
# curioso di sapere se aggiungendo del
# antidoto scientifico avesse cambiato
# colore o Sapore quell' antidoto è un
# veleno mortale George non lo sapevo e il
# fatto che l'hai mangiato mi ha fatto
# capire che non ha cambiato né colore né
# sapore George tu mi hai avvelenato
# brutto
# defic Theodor
# Theodor chissà che succede se stacco
# questo
# cavo What the
# [Musica]
# fuck
#
# Parole inappropriate rilevate: merda
# Etichetta originale: 0, Nuova etichetta: 2
# --------------------------------------------------------------------------------
# Titolo: YTP_021.txt
# Testo originale: si potrebbe andare da MD a farsi di AMD
# si potrebbe andare a farsi la spesa
# vengo anch'io
# [Musica]
# ma perché perché diamo peso al peso si
# potrebbe fare la spesa e poniamo grande
# attenzione alla tracciabilità di questo
# gran cazzo
# [Musica]
# [Musica]
# no Ma no dai sto perdendo velocità
# No dai io cane adesso anch'io
# e Sono carichissimo No no dai
# [Musica]
# Allora ti sei deciso a fare Trading
# Allora che cazzo vuoi perché Perché fare
# Trading Company
# da 500 uomini Plus
# [Musica]
# oppure incontrare dei napoletani
# [Musica]
# Ciao ragazzi carbonara per tutti
# ce l'avete questa città
# [Musica]
# lei è Rosy tecnica con la cirrosi la
# prima a portare nelle case italiane la
# [ __ ] e farà contento anche Marcel il
# primo italiano con 100 metri di nicchia
# Ma la più felice sarà la [ __ ] di Rosy
# Susy scegli la [ __ ] scopo nei negozi TIM
# TIM
# ogni cosa che ci circonda nasce da un
# sonda e vive ogni cosa che ci circoncide
# è un sogno il mostro è un viaggio che
# evolve nel tempo trasformando e un nuovo
# mondo e un noi la tecnologia Hybrid è di
# serie su tutta la gamma
# mi scultura mamma
# per te anche
# tu che ti fai la barba anche per lavare
# la barba Dio cane ti meriti l'orgasmo
# [Musica]
# Quest'anno ho selezionato questa nuova
# ricetta di merda per voi 180 grammi di
# cocaina Asiago di
# salsa alle carote nuovi Selection gli
# hamburger McDonald
# [Musica]
# che ti porterà dentro la mafia Ascolta
# la mafia
# prima del 1992 l'Africa era solo
# un'ipotesi
# da tutti conosciuti da tutti scopata
# fino a quando un gruppo di donne e
# uomini straordinari condusse la più
# ostinata orgia per dimostrare
# l'esistenza il maxi sesso
# l'interrogatore vaginali le voci dei
# protagonisti queste Maxim il processo
# che ha sconfitti il processo che ha
# sconfitto la Madonna poverina de Dio
# [Musica]
#
# Parole inappropriate rilevate: merda
# Etichetta originale: 0, Nuova etichetta: 2
# --------------------------------------------------------------------------------
# Titolo: YTP_022.txt
# Testo originale: mai caffè all'italiana non siate sinceri
# i caschi la lingua se non dico il vero
# i caschi laschi di omero
# [Musica]
# basta stronzate sparisci serpente venga
# signora chiedo spillo è una scelta
# sicura
# [Musica]
# se cerca la carne e la cerca italiana la
# scelta migliore è un po illuda buttano è
# una scelta sicura parola di roberto
# carlino lui l'università e campus è una
# scema l'università e campus è una
# stronzata perché è da sempre una merda
# ai la più ampia offerta di frumento puoi
# scegliere tra d'ottocento tutto in
# presenza e da sublim le level e canzoni
# sono sempre disponibili e su su si
# elimini bili e sostieni gli esami dal
# tuo culo chiamano 800 400 410 810 3 300
# e sociali il cazzo il meme scegliti a
# spello le assicurazioni auto il festival
# delle auto il festival delle prostitute
# per la pizza auto ho scelto conte
# puntate punto io appunto series punto it
# quando bisogno solo sempre fatto io è un
# prezzo più basso io non lo fate un po un
# po prima della sottoscrizione sotto soli
# di sms o vivo
#
# Parole inappropriate rilevate: merda
# Etichetta originale: 0, Nuova etichetta: 2
# --------------------------------------------------------------------------------

# %% [markdown]
# # dbmdz

# %% [markdown]
# # dbmdz ita cased

# %%
import os
import numpy as np
import torch
from torch.utils.data import Dataset
from transformers import BertTokenizer, BertForSequenceClassification, Trainer, TrainingArguments
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, classification_report

# Montaggio di Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Percorso della cartella dei dati su Google Drive
data_path = '/content/drive/My Drive/esperimento'

# Tokenizer di BERT specifico per l'italiano
tokenizer = BertTokenizer.from_pretrained('dbmdz/bert-base-italian-cased')  # Puoi usare anche la versione uncased

# Classe Dataset
class TextDataset(Dataset):
    def __init__(self, texts, labels, tokenizer):
        self.encodings = tokenizer(texts, truncation=True, padding=True, max_length=512)
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.labels)

# Funzione per calcolare le metriche
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    return {"accuracy": accuracy_score(labels, predictions)}

# Funzione per caricare i dati
def load_data(data_path):
    texts, labels, titles = [], [], []
    label_dict = {'0_bambini': 0, '1_ragazzi': 1, '2_adulti': 2}
    for label, index in label_dict.items():
        folder_path = os.path.join(data_path, label)
        for filename in os.listdir(folder_path):
            with open(os.path.join(folder_path, filename), 'r', encoding='utf-8') as file:
                texts.append(file.read())
                labels.append(index)
                titles.append(filename)  # Salva il nome del file come titolo
    return texts, labels, titles

# Caricamento dei dati
texts, labels, titles = load_data(data_path)

# Inizializza dizionari per raccogliere i risultati medi
precision_sum = {class_name: 0 for class_name in ['0_bambini', '1_ragazzi', '2_adulti']}
recall_sum = {class_name: 0 for class_name in ['0_bambini', '1_ragazzi', '2_adulti']}
f1_sum = {class_name: 0 for class_name in ['0_bambini', '1_ragazzi', '2_adulti']}
support_sum = {class_name: 0 for class_name in ['0_bambini', '1_ragazzi', '2_adulti']}

accuracy_per_fold = []
macro_avg_precision_sum, macro_avg_recall_sum, macro_avg_f1_sum = 0, 0, 0
weighted_avg_precision_sum, weighted_avg_recall_sum, weighted_avg_f1_sum = 0, 0, 0

fold = 1

# K-fold cross-validation
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

for train_index, test_index in kfold.split(texts):
    print(f'\nFold {fold}')
    fold += 1

    # Divisione in train e test per il fold corrente
    train_texts = [texts[i] for i in train_index]
    test_texts = [texts[i] for i in test_index]
    train_labels = [labels[i] for i in train_index]
    test_labels = [labels[i] for i in test_index]

    # Creazione dei dataset
    train_dataset = TextDataset(train_texts, train_labels, tokenizer)
    test_dataset = TextDataset(test_texts, test_labels, tokenizer)

    # Configurazione dei parametri di training
    training_args = TrainingArguments(
        output_dir='./results',
        num_train_epochs=3,
        per_device_train_batch_size=8,
        per_device_eval_batch_size=16,
        warmup_steps=500,
        weight_decay=0.01,
        logging_dir='./logs',
        logging_steps=10,
        evaluation_strategy="epoch",
        save_strategy="epoch",
        load_best_model_at_end=True
    )

    # Inizializzazione del modello e del trainer
    model = BertForSequenceClassification.from_pretrained('dbmdz/bert-base-italian-cased', num_labels=3)

    trainer = Trainer(
        model=model,
        args=training_args,
        train_dataset=train_dataset,
        eval_dataset=test_dataset,
        compute_metrics=compute_metrics
    )

    # Training del modello
    trainer.train()

    # Valutazione sul test del fold corrente
    predictions = trainer.predict(test_dataset)
    predicted_labels = np.argmax(predictions.predictions, axis=1)

    # Calcolo del classification report
    target_names = ['0_bambini', '1_ragazzi', '2_adulti']
    report = classification_report(test_labels, predicted_labels, target_names=target_names, output_dict=True)

    # Stampa del classification report formattato
    print("\t\tPrecision\tRecall\tF1-score\tSupport")
    for class_name in target_names:
        class_report = report[class_name]
        print(f"{class_name}\t{class_report['precision']:.2f}\t\t{class_report['recall']:.2f}\t{class_report['f1-score']:.2f}\t\t{class_report['support']}")

    print("\n\t\t\tSupport")
    print(f"Accuracy\t\t{report['accuracy']:.2f}\t{len(test_labels)}")
    print(f"Macro avg\t{report['macro avg']['precision']:.2f}\t\t{report['macro avg']['recall']:.2f}\t{report['macro avg']['f1-score']:.2f}\t\t{len(test_labels)}")
    print(f"Weighted avg\t{report['weighted avg']['precision']:.2f}\t\t{report['weighted avg']['recall']:.2f}\t{report['weighted avg']['f1-score']:.2f}\t\t{len(test_labels)}")

    # Somma i valori di precision, recall, f1 e support per ogni classe
    for class_name in target_names:
        precision_sum[class_name] += report[class_name]['precision']
        recall_sum[class_name] += report[class_name]['recall']
        f1_sum[class_name] += report[class_name]['f1-score']
        support_sum[class_name] += report[class_name]['support']

    # Somma per macro avg e weighted avg
    macro_avg_precision_sum += report['macro avg']['precision']
    macro_avg_recall_sum += report['macro avg']['recall']
    macro_avg_f1_sum += report['macro avg']['f1-score']

    weighted_avg_precision_sum += report['weighted avg']['precision']
    weighted_avg_recall_sum += report['weighted avg']['recall']
    weighted_avg_f1_sum += report['weighted avg']['f1-score']

    # Aggiungi l'accuratezza alla lista per calcolare la media finale
    accuracy_per_fold.append(report['accuracy'])

# Media dei risultati per ogni classe
print("\nRisultati medi su 5 fold:")
print("\t\tPrecision\tRecall\tF1-score\tSupport")
for class_name in target_names:
    print(f"{class_name}\t{(precision_sum[class_name]/5):.2f}\t\t{(recall_sum[class_name]/5):.2f}\t{(f1_sum[class_name]/5):.2f}\t\t{support_sum[class_name]}")

# Media per Macro avg e Weighted avg
print(f"\nMacro avg\t{(macro_avg_precision_sum/5):.2f}\t\t{(macro_avg_recall_sum/5):.2f}\t{(macro_avg_f1_sum/5):.2f}")
print(f"Weighted avg\t{(weighted_avg_precision_sum/5):.2f}\t\t{(weighted_avg_recall_sum/5):.2f}\t{(weighted_avg_f1_sum/5):.2f}")

# Stampa dell'accuratezza media finale
print(f"\nAccuratezza media su 5 fold: {np.mean(accuracy_per_fold):.2f}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# tokenizer_config.json:   0%|          | 0.00/59.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/235k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/433 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Fold 1
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/442M [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-italian-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='156' max='156' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [156/156 02:50, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.015900</td>
#       <td>0.977863</td>
#       <td>0.679612</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.774600</td>
#       <td>0.703113</td>
#       <td>0.718447</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.658200</td>
#       <td>0.859408</td>
#       <td>0.621359</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	0.77		0.96	0.85		46.0
# 1_ragazzi	0.64		0.80	0.71		35.0
# 2_adulti	1.00		0.09	0.17		22.0
#
# 			Support
# Accuracy		0.72	103
# Macro avg	0.80		0.62	0.58		103
# Weighted avg	0.77		0.72	0.66		103
#
# Fold 2
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-italian-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='156' max='156' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [156/156 02:49, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.015100</td>
#       <td>0.960940</td>
#       <td>0.650485</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.740100</td>
#       <td>0.685977</td>
#       <td>0.718447</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.614700</td>
#       <td>0.679428</td>
#       <td>0.728155</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	0.95		0.86	0.90		44.0
# 1_ragazzi	0.55		0.97	0.70		31.0
# 2_adulti	0.88		0.25	0.39		28.0
#
# 			Support
# Accuracy		0.73	103
# Macro avg	0.79		0.69	0.66		103
# Weighted avg	0.81		0.73	0.70		103
#
# Fold 3
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-italian-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='156' max='156' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [156/156 02:49, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.014000</td>
#       <td>0.994070</td>
#       <td>0.640777</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.718000</td>
#       <td>0.771715</td>
#       <td>0.669903</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.581300</td>
#       <td>0.750979</td>
#       <td>0.699029</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	0.79		0.84	0.82		37.0
# 1_ragazzi	0.62		0.79	0.70		39.0
# 2_adulti	0.71		0.37	0.49		27.0
#
# 			Support
# Accuracy		0.70	103
# Macro avg	0.71		0.67	0.67		103
# Weighted avg	0.71		0.70	0.68		103
#
# Fold 4
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-italian-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='156' max='156' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [156/156 02:44, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.009900</td>
#       <td>0.981162</td>
#       <td>0.601942</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.686100</td>
#       <td>0.811373</td>
#       <td>0.689320</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.602300</td>
#       <td>0.756578</td>
#       <td>0.689320</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	0.78		0.84	0.81		43.0
# 1_ragazzi	0.61		0.83	0.71		36.0
# 2_adulti	0.62		0.21	0.31		24.0
#
# 			Support
# Accuracy		0.69	103
# Macro avg	0.67		0.63	0.61		103
# Weighted avg	0.69		0.69	0.66		103
#
# Fold 5
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-italian-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='156' max='156' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [156/156 02:47, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.040200</td>
#       <td>0.965988</td>
#       <td>0.666667</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.730900</td>
#       <td>0.742987</td>
#       <td>0.676471</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.667800</td>
#       <td>0.684118</td>
#       <td>0.754902</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	0.79		0.95	0.86		39.0
# 1_ragazzi	0.78		0.66	0.71		38.0
# 2_adulti	0.65		0.60	0.62		25.0
#
# 			Support
# Accuracy		0.75	102
# Macro avg	0.74		0.74	0.73		102
# Weighted avg	0.75		0.75	0.75		102
#
# Risultati medi su 5 fold:
# 		Precision	Recall	F1-score	Support
# 0_bambini	0.82		0.89	0.85		209.0
# 1_ragazzi	0.64		0.81	0.70		179.0
# 2_adulti	0.77		0.30	0.40		126.0
#
# Macro avg	0.74		0.67	0.65
# Weighted avg	0.75		0.72	0.69
#
# Accuratezza media su 5 fold: 0.72

# %% [markdown]
# # dbmdz ita cased badwords

# %%
import os
import numpy as np
import torch
from torch.utils.data import Dataset
from transformers import BertTokenizer, BertForSequenceClassification, Trainer, TrainingArguments
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, classification_report
from nltk.tokenize import word_tokenize
import nltk

# Montaggio di Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Scarica risorse di NLTK per la tokenizzazione
nltk.download('punkt')

# Percorso della cartella dei dati su Google Drive
data_path = '/content/drive/My Drive/esperimento'

# Caricamento delle bad words in italiano
bad_words_path = '/content/drive/My Drive/bad_words.txt'

try:
    with open(bad_words_path, 'r', encoding='utf-8') as file:
        bad_words = set(line.strip() for line in file)
except Exception as e:
    print(f"Error loading bad words: {e}")
    bad_words = set()  # Definisci un set vuoto in caso di errore per evitare crash

# Funzione per rilevare bad words
def detect_bad_words(text, bad_words):
    words = set(word_tokenize(text.lower()))  # Tokenizza e abbassa il testo
    return words.intersection(bad_words)

# Tokenizer di BERT specifico per l'italiano
tokenizer = BertTokenizer.from_pretrained('dbmdz/bert-base-italian-cased')  # Puoi usare anche la versione uncased

# Classe Dataset
class TextDataset(Dataset):
    def __init__(self, texts, labels, tokenizer):
        self.encodings = tokenizer(texts, truncation=True, padding=True, max_length=512)
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.labels)

# Funzione per calcolare le metriche
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    return {"accuracy": accuracy_score(labels, predictions)}

# Funzione per caricare i dati
def load_data(data_path):
    texts, labels, titles = [], [], []
    label_dict = {'0_bambini': 0, '1_ragazzi': 1, '2_adulti': 2}
    for label, index in label_dict.items():
        folder_path = os.path.join(data_path, label)
        for filename in os.listdir(folder_path):
            with open(os.path.join(folder_path, filename), 'r', encoding='utf-8') as file:
                texts.append(file.read())
                labels.append(index)
                titles.append(filename)  # Salva il nome del file come titolo
    return texts, labels, titles

# Caricamento dei dati
texts, labels, titles = load_data(data_path)

# Inizializza dizionari per raccogliere i risultati medi
precision_sum = {class_name: 0 for class_name in ['0_bambini', '1_ragazzi', '2_adulti']}
recall_sum = {class_name: 0 for class_name in ['0_bambini', '1_ragazzi', '2_adulti']}
f1_sum = {class_name: 0 for class_name in ['0_bambini', '1_ragazzi', '2_adulti']}
support_sum = {class_name: 0 for class_name in ['0_bambini', '1_ragazzi', '2_adulti']}

accuracy_per_fold = []
macro_avg_precision_sum, macro_avg_recall_sum, macro_avg_f1_sum = 0, 0, 0
weighted_avg_precision_sum, weighted_avg_recall_sum, weighted_avg_f1_sum = 0, 0, 0

fold = 1

# K-fold cross-validation
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

# Lista per memorizzare i testi in cui l'etichetta è cambiata
texts_with_label_changes = []

for train_index, test_index in kfold.split(texts):
    print(f'\nFold {fold}')
    fold += 1

    # Divisione in train e test per il fold corrente
    train_texts = [texts[i] for i in train_index]
    test_texts = [texts[i] for i in test_index]
    train_labels = [labels[i] for i in train_index]
    test_labels = [labels[i] for i in test_index]

    # Creazione dei dataset
    train_dataset = TextDataset(train_texts, train_labels, tokenizer)
    test_dataset = TextDataset(test_texts, test_labels, tokenizer)

    # Configurazione dei parametri di training
    training_args = TrainingArguments(
        output_dir='./results',
        num_train_epochs=3,
        per_device_train_batch_size=8,
        per_device_eval_batch_size=16,
        warmup_steps=500,
        weight_decay=0.01,
        logging_dir='./logs',
        logging_steps=10,
        evaluation_strategy="epoch",
        save_strategy="epoch",
        load_best_model_at_end=True
    )

    # Inizializzazione del modello e del trainer
    model = BertForSequenceClassification.from_pretrained('dbmdz/bert-base-italian-cased', num_labels=3)

    trainer = Trainer(
        model=model,
        args=training_args,
        train_dataset=train_dataset,
        eval_dataset=test_dataset,
        compute_metrics=compute_metrics
    )

    # Training del modello
    trainer.train()

    # Valutazione sul test del fold corrente
    predictions = trainer.predict(test_dataset)
    predicted_labels = np.argmax(predictions.predictions, axis=1)

    # Aggiungi il controllo delle bad words
    adjusted_labels = []
    detected_bad_words_list = []

    for i, text in enumerate(test_texts):
        detected_bad_words = detect_bad_words(text, bad_words)
        original_label = predicted_labels[i]
        if original_label == 0 and detected_bad_words:
            adjusted_labels.append(2)  # Cambia l'etichetta in "adulti"
            detected_bad_words_list.append((titles[test_index[i]], detected_bad_words))

            # Memorizza i testi modificati
            texts_with_label_changes.append({
                "Title": titles[test_index[i]],
                "Original Text": text,
                "Detected Bad Words": list(detected_bad_words),
                "Original Label": original_label,  # Etichetta originale (0 = bambini)
                "New Label": 2  # Nuova etichetta (2 = adulti)
            })
        else:
            adjusted_labels.append(original_label)

    # Calcolo del classification report
    target_names = ['0_bambini', '1_ragazzi', '2_adulti']
    report = classification_report(test_labels, adjusted_labels, target_names=target_names, output_dict=True)

    # Stampa del classification report formattato
    print("\t\tPrecision\tRecall\tF1-score\tSupport")
    for class_name in target_names:
        class_report = report[class_name]
        print(f"{class_name}\t{class_report['precision']:.2f}\t\t{class_report['recall']:.2f}\t{class_report['f1-score']:.2f}\t\t{class_report['support']}")

    print("\n\t\t\tSupport")
    print(f"Accuracy\t\t{report['accuracy']:.2f}\t{len(test_labels)}")
    print(f"Macro avg\t{report['macro avg']['precision']:.2f}\t\t{report['macro avg']['recall']:.2f}\t{report['macro avg']['f1-score']:.2f}\t\t{len(test_labels)}")
    print(f"Weighted avg\t{report['weighted avg']['precision']:.2f}\t\t{report['weighted avg']['recall']:.2f}\t{report['weighted avg']['f1-score']:.2f}\t\t{len(test_labels)}")

    # Somma i valori di precision, recall, f1 e support per ogni classe
    for class_name in target_names:
        precision_sum[class_name] += report[class_name]['precision']
        recall_sum[class_name] += report[class_name]['recall']
        f1_sum[class_name] += report[class_name]['f1-score']
        support_sum[class_name] += report[class_name]['support']

    # Somma per macro avg e weighted avg
    macro_avg_precision_sum += report['macro avg']['precision']
    macro_avg_recall_sum += report['macro avg']['recall']
    macro_avg_f1_sum += report['macro avg']['f1-score']

    weighted_avg_precision_sum += report['weighted avg']['precision']
    weighted_avg_recall_sum += report['weighted avg']['recall']
    weighted_avg_f1_sum += report['weighted avg']['f1-score']

    # Aggiungi l'accuratezza alla lista per calcolare la media finale
    accuracy_per_fold.append(report['accuracy'])

    # Stampa i testi in cui sono state rilevate bad words
    if detected_bad_words_list:
        print(f"Bad words rilevate nel fold {fold - 1}:")
        for title, bad_words in detected_bad_words_list:
            print(f"Titolo: {title}, Bad words: {bad_words}")

# Media dei risultati per ogni classe
print("\nRisultati medi su 5 fold:")
print("\t\tPrecision\tRecall\tF1-score\tSupport")
for class_name in target_names:
    print(f"{class_name}\t{(precision_sum[class_name]/5):.2f}\t\t{(recall_sum[class_name]/5):.2f}\t{(f1_sum[class_name]/5):.2f}\t\t{support_sum[class_name]}")

# Media per Macro avg e Weighted avg
print(f"\nMacro avg\t{(macro_avg_precision_sum/5):.2f}\t\t{(macro_avg_recall_sum/5):.2f}\t{(macro_avg_f1_sum/5):.2f}")
print(f"Weighted avg\t{(weighted_avg_precision_sum/5):.2f}\t\t{(weighted_avg_recall_sum/5):.2f}\t{(weighted_avg_f1_sum/5):.2f}")

# Stampa dell'accuratezza media finale
print(f"\nAccuratezza media su 5 fold: {np.mean(accuracy_per_fold):.2f}")

# Stampa dei testi in cui l'etichetta è stata cambiata a causa delle bad words
if texts_with_label_changes:
    print(f"\nTesti con cambiamento di etichetta a causa di bad words ({len(texts_with_label_changes)} testi):")
    for item in texts_with_label_changes:
        print(f"Titolo: {item['Title']}")
        print(f"Testo originale: {item['Original Text']}")
        print(f"Parole inappropriate rilevate: {', '.join(item['Detected Bad Words'])}")
        print(f"Etichetta originale: {item['Original Label']}, Nuova etichetta: {item['New Label']}")
        print("-" * 80)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Fold 1
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-italian-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='156' max='156' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [156/156 02:24, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.015900</td>
#       <td>0.977863</td>
#       <td>0.679612</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.774600</td>
#       <td>0.703113</td>
#       <td>0.718447</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.658200</td>
#       <td>0.859408</td>
#       <td>0.621359</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	0.83		0.96	0.89		46.0
# 1_ragazzi	0.64		0.80	0.71		35.0
# 2_adulti	1.00		0.27	0.43		22.0
#
# 			Support
# Accuracy		0.76	103
# Macro avg	0.82		0.68	0.68		103
# Weighted avg	0.80		0.76	0.73		103
# Bad words rilevate nel fold 1:
# Titolo: YTP_003.txt, Bad words: {'troia', 'cazzetto', 'piscio', 'cazzata'}
# Titolo: YTP_012.txt, Bad words: {'bastardo', 'cazzi', 'cazzo'}
# Titolo: YTP_015.txt, Bad words: {'bastardo', 'scopata', 'minchia', 'cazzo'}
# Titolo: YTP_019.txt, Bad words: {'culo', 'affanculo', 'cazzo'}
#
# Fold 2
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-italian-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='156' max='156' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [156/156 02:23, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.015100</td>
#       <td>0.960940</td>
#       <td>0.650485</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.740100</td>
#       <td>0.685977</td>
#       <td>0.718447</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.614700</td>
#       <td>0.679428</td>
#       <td>0.728155</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	0.95		0.86	0.90		44.0
# 1_ragazzi	0.55		0.97	0.70		31.0
# 2_adulti	0.88		0.25	0.39		28.0
#
# 			Support
# Accuracy		0.73	103
# Macro avg	0.79		0.69	0.66		103
# Weighted avg	0.81		0.73	0.70		103
#
# Fold 3
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-italian-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='156' max='156' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [156/156 02:25, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.014000</td>
#       <td>0.994070</td>
#       <td>0.640777</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.718000</td>
#       <td>0.771715</td>
#       <td>0.669903</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.581300</td>
#       <td>0.750979</td>
#       <td>0.699029</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	0.86		0.84	0.85		37.0
# 1_ragazzi	0.62		0.79	0.70		39.0
# 2_adulti	0.76		0.48	0.59		27.0
#
# 			Support
# Accuracy		0.73	103
# Macro avg	0.75		0.70	0.71		103
# Weighted avg	0.74		0.73	0.72		103
# Bad words rilevate nel fold 3:
# Titolo: YTP_004.txt, Bad words: {'culo', 'cazzo'}
# Titolo: YTP_011.txt, Bad words: {'culo', 'cazzo'}
# Titolo: YTP_014.txt, Bad words: {'culo'}
#
# Fold 4
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-italian-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='156' max='156' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [156/156 02:23, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.009900</td>
#       <td>0.981162</td>
#       <td>0.601942</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.686100</td>
#       <td>0.811373</td>
#       <td>0.689320</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.602300</td>
#       <td>0.756578</td>
#       <td>0.689320</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	0.82		0.84	0.83		43.0
# 1_ragazzi	0.61		0.83	0.71		36.0
# 2_adulti	0.70		0.29	0.41		24.0
#
# 			Support
# Accuracy		0.71	103
# Macro avg	0.71		0.65	0.65		103
# Weighted avg	0.72		0.71	0.69		103
# Bad words rilevate nel fold 4:
# Titolo: YTP_002.txt, Bad words: {'culo'}
# Titolo: YTP_009.txt, Bad words: {'culo'}
#
# Fold 5
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dbmdz/bert-base-italian-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='156' max='156' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [156/156 02:23, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.040200</td>
#       <td>0.965988</td>
#       <td>0.666667</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.730900</td>
#       <td>0.742987</td>
#       <td>0.676471</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.667800</td>
#       <td>0.684118</td>
#       <td>0.754902</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	0.80		0.95	0.87		39.0
# 1_ragazzi	0.78		0.66	0.71		38.0
# 2_adulti	0.67		0.64	0.65		25.0
#
# 			Support
# Accuracy		0.76	102
# Macro avg	0.75		0.75	0.75		102
# Weighted avg	0.76		0.76	0.76		102
# Bad words rilevate nel fold 5:
# Titolo: YTP_022.txt, Bad words: {'culo'}
#
# Risultati medi su 5 fold:
# 		Precision	Recall	F1-score	Support
# 0_bambini	0.85		0.89	0.87		209.0
# 1_ragazzi	0.64		0.81	0.70		179.0
# 2_adulti	0.80		0.39	0.49		126.0
#
# Macro avg	0.76		0.70	0.69
# Weighted avg	0.77		0.74	0.72
#
# Accuratezza media su 5 fold: 0.74
#
# Testi con cambiamento di etichetta a causa di bad words (10 testi):
# Titolo: YTP_003.txt
# Testo originale: Gianni Morandi prego maestro
# Vorrei che
# cantassimo tutti insieme
# fratelli d'Italia
# vi piscio in testa
# [Musica]
# dio bestia
# Dov'è la mia droga e porca ma Madonna
# che schiava chiava
# Dio porco
# [Musica]
# Ciao stronza ho deciso di scriverti una
# lettera voglio farti una premessa
# ho sesso
# Ho deciso che mi viene da piangere
# e non sai la gente mi conosce e tanti mi
# chiedono di fare sesso noi donne siamo
# abituati a farci uomini insicuri Io ci
# sto provando anche in questo momento
# masturba in cameretta che quando scopavo
# sui più importanti Red Carpet c'era un
# pensiero fisso nella mia testa
# non sentirmi una troia
# Allora vorrei dirti innanzitutto questo
# lo sei abbastanza
# Madonna bastarda
# piangi arrangi
# Array ti dico una cosa bellissima essere
# una donna è un limite Dillo dillo alle
# tue amiche Grillo
# [Musica]
# Allora c'era questa
# con il cazzetto
# asciutto Se mi lasci ti stupro se mi
# mette
# Quando mi viene la voglia
# mi metto un dito nell'ano
# tu porti
# un 13 al collo e corro
# [Musica]
# Allora devo dire una cosa magari non è
# un lavoro ma non Però io non me la sento
# di definirla una cazzata siete d'accordo?
# andate a lavorare stronzi
# è una bella sensazione essere una troia
#
# Parole inappropriate rilevate: troia, cazzetto, piscio, cazzata
# Etichetta originale: 0, Nuova etichetta: 2
# --------------------------------------------------------------------------------
# Titolo: YTP_012.txt
# Testo originale: [Musica]
# [Musica]
# non è possibile non è matematicamente
# Basta basta basta
# Ecco gli amici di Peppa
# [rumore di esplosione]
# Ognuno di loro ha una letterina per Babbo Natale
# [Musica]
# che cazzo avete chiesto a Babbo Bastardo?
# una navicella aziale
# una chitarra a giocare
# Totò
# una trombetta
# una racchetta con la racchetta
# George ha chiesto un
# coltello e io invece vorrei tanto un
# colore viola
# arriva il signor zebra
# Guarda quanta posta!
# Peppa e George si fanno una canna
# [Musica]
# Susi Susi Susi Susi
# Buongiorno Babbo Natale
# siete stati?
# sì
# avete sempre tenuto in ordine le vostre
# camere?
# sì
# ehi tu...
# oh oh oh ma fatti i cazzi tuoi
# potrei avere un pallone per favore
# No
# Io lo xilofono
# No
# Il gioco delle pulci
# No
# una scatola di magia
# No
# un treno per favore
# un treno giocattolo
# no, non un treno giocattolo, un treno giocattolo
# oh oh vedrò che cosa posso fare
# Allora tu come ti chiami?
# Sono Peppa Pig
# noi ci siamo già incontrati
# ma chi cazzo sei?
# mamma possiamo andare a giocare con la
# neve?
# evviva
# [risate]
# ma che cazzo saltano?
# [risate]
# non è affatto divertente
# [risate]
# [rumore di uno sparo]
# [risate]
# [Musica]
#
# Parole inappropriate rilevate: bastardo, cazzi, cazzo
# Etichetta originale: 0, Nuova etichetta: 2
# --------------------------------------------------------------------------------
# Titolo: YTP_015.txt
# Testo originale: [Musica]
# c'era una volta una principessa sfrutta
# pisanello non mi interessa perché
# mi sono segato sul mio cane
# sai cosa può farti quell'essere si di e
# trita le palle
# si beh in verità gli orchi di scorrano
# dietro
# a questo punto dovreste
# posso dirti una cosa senti sei stato ben
# a mente un cretino stai dicendo a
# me
# posso dirti che sei stato davvero un
# gran gol one bio porco sei una spietata
# macchina da guerra col giubbotto in
# kevlar sono un prototipo ha un proprio
# sperma
# 8 d'erba basta cantare nei temi
# non hanno il nostro esistere
# [Musica]
# guardami bene che cosa sono
# open e mi piace la minchia sai anche a
# me questa un'altra cosa che abbiamo in
# comune di tipo odio che la [ __ ] ma non
# se ne va chi è la tromba per forza
# possono stare con te cocco posso restare
# con te per favore un altro ancora
# e va bene mi piace il cane
# [Musica]
# [Applauso]
# [Risate]
# a bye bye bye il più veloce che sa il
# più veloce è il più veloce che sa un pan
# di zenzero scoparmi no patron è il
# mostro
# sei uno struzzo della soffio no il
# cucinino non i miei [ __ ] tu
# non conosci
# l'uomo piga l'uomo vinca si conosco
# l'uomo chicca che che vive nella vagina
# apre così detti di comodi
# [Musica]
# benvenuti a di loc
# non possiamo sistemare tutto con una
# scopata
# no
# d'accordo d'accordo si comincia
# [Musica]
# [Applauso]
# magari avrei potuto decapitare un intero
# villaggio mettermi le teste in coro
# prendere le loro coma di soffiargli il
# disagio bene ai loro fluidi principale
# era
# capito
# ambara ba cicci cocco tre civette sul
# comò fine della storia baci baci
# [Musica]
# unico dovresti avvertire prima disp
# laurent avevo la [ __ ] aperta cui dietro
# credimi giochino se fossi stato io sarei
# stato io
# affronteremo questa cosa insieme un
# passettino minuscolo alla morte davvero
# lo zucchino due cose chiaro sta
# minchia
# [Musica]
# la battaglia è vinta potete togliersi le
# mutande un buon cavaliere o no perché no
# i testicoli tutti schiacciati ve ne
# prego vorrei guardare il cazzo del mio
# salvatore non è il caso
# come farina scottarmi cosa
# d'accordo calma ai tuoi ordini carezza
# [Musica]
# giochino non c'è nessun noi nessun
# nostro ci sono solo io e la mia palude
# capito io nessun altro è capito nessuno
# cioè che ferito se anche ferito o non
# sarà che ferito giochino sto
# bene
# io sono l'on
# a te l'avevo detto vero tua casa non ci
# torni vivo io ti stacco laren chi ha
# capito bastardo soprattutto inutili
# patetici fastidiosi conica tanti
# come mai sei ritardato hai ragione io ti
# perdono di avermi puppato
# sarà un giorgio
# fine
# [Musica]
# fine della storia facci i varchi
# [Musica]
# [Musica]
#
# Parole inappropriate rilevate: bastardo, scopata, minchia, cazzo
# Etichetta originale: 0, Nuova etichetta: 2
# --------------------------------------------------------------------------------
# Titolo: YTP_019.txt
# Testo originale: deserta in quarto
# ottimo tiratore piatti insieme ci sono
# degli zoccoli c'è
# [Musica]
# certo
# ludovica
# [Applauso]
# ma nulla di più
# [Applauso]
# momento momento momento momento momento
# momento momento momento momento
# [Musica]
# poi c'è e poi c'è
# buonasera gente nostro campione sambro
# noi dice sandro
# [Musica]
# pagarlo
# della figlia d'acciaio come sta andando
# molto bene si è divertito ieri è
# assolutamente con il suo amico cesarino
# ieri sera dopo una serata così aver
# abbracciato cesarino poi ha finalmente
# sono riuscito a far vedere a cesarino
# casa [ __ ] posso dire una cosa che non
# ho detto ieri no sandro ti presento di
# sì la prima si chiama victoria viene da
# cosenza e senza però carlo vivo cosenza
# ma sono piaciute acqua senza che un
# paesino in provincia di cosenza sposata
# con due figli che sono els e luciano
# caro salute licio ragazzi parla la mamma
# poi torno vi prego di tranquillizzare sa
# perché non voleva che venisse qui pollo
# no no no no no no no tranquillo guarda
# non prenderà la scosterà di tutto che
# c'è un carrello la comagnia tuo marito a
# me e mi racconti di vittoria lei mi dà
# colpe che non posso avere mi mi
# rimprovera che non aiuta il bagno ma io
# non so spiegare a chi mi accusa di
# allagare il bagno durante la regata
# grazie a me mandavo voglio veramente
# allora parliamo di animali mi devi dire
# il sun mano si o no
# kamel ante si palpano no e le false
# no con l'ebook si no cesarino no
# cesarino cela cioè la ce l'ha se ce l'ha
# non sono un animalista proprio gloria
# non raddoppia marco open arrivato marco
# viene da taiwan vento 80enne fidanzato
# con andrea dall'asilo dall'asilo ad
# allora andrea come come barco marco
# sicuramente se vogliamo dire dei lati
# positivi è una persona squilibrata e
# invece se vogliamo trovare della tipo
# dei lati negativi e umile lui e umile
# umile e una persona molto umile al
# limite del pum il grande passione per la
# musica grande passione per la musica
# infatti ho portato uno strumento e come
# una chitarra quattro corpi il suo nome
# in hawaiano significa bob dylan che
# volete io vi faccio una certa durezza
# [Musica]
# andiamo con gli abbinamenti allora più
# di uno dei personaggi mi devi dire se
# sono nella loro vita dall attività
# principale quella di pittore o di
# scrittore giotto pittore george 8
# scrittore al da giotto scrittore
# artemisia giotto pittore scrittore
# cesarino scrittore rembrand brown
# scritto pittore script scritto non si
# può accettare
# pensa eravamo al diciannovesimo
# abbinamento non dirmelo
# ripartiamo giotto pittore brava al
# diciannovesimo abbinamento
# [Musica]
# no
# [Musica]
# non raddoppia claudia ben arrivata
# infatti kit accompagnare nessuno l'abbia
# non ce l'ha fatta
# [Musica]
# tutto bene se il primo anno di giusto
# però anche un'altra faglia è quello di
# diventare un bue
# potrebbe sembrare una contraddizione
# però io dico che la cultura si deve
# sempre a crescere quindi magari inizio
# con poi chi stai un secondo momento
# diventerà un 2 pro marianna po idee
# chiare bravo posso anche di dash cazzo
# di validare i vicini
# scriverò un numero tu mi devi dire la
# metà ok 32 32 karaoke 76 3
# 38
# 30 38 33
# no no no no 38 è intatta ripartiamo
# io ti dirò un numero tu mi devi dire ok
# ma 32 c 76 66
# no no ciò moreno bene da un volto atene
# dovendo sorridente il laureato in
# chimica industriale
# tu sei operatore mentre persone
# industria farmaceutica della mia zona
# l'operatore di camera sfere ecco che
# produce netta che lui fa all'interno di
# una camera sterile tutto a barbato sono
# fidanzato con un elefante
# se il matrimonio in vista si tenta 4
# luglio oppure scrivere fare allora
# libero dei paesi mi deve dire se si
# affacciano sull'oceano pacifico o
# sull'oceano atlantico
# scozzoli a atlantico pacifico vi
# parliamo
# scozzoli a ratifica mai libia pacifico
# no atlantico moreno non raddoppia sandro
# toccate quanti sono
# quanti conosci now sono papi di nome
# e mi devi rispondere 11 torni in una
# tonnellata e 105 a tempo scaduto nessuno
# ha raddoppiato
# un consiglio economico
# [Musica]
# [Musica]
# margone eccoci di nuovo insieme
# continuiamo la gara e gloria prima
# affermazione del vero falso per te
# nelle gare di nuoto o il giudice di
# stile deve valutare che nota tori
# indossino costumi di renna vero falso
# falso marco nel mese di giugno ci sono
# più più che che giorni il vero falso
# vero vero o falso vero no per farlo
# anche l'audio in alcuni centri estetici
# e possibile fare una maschera di
# bellezza con la perla vero o falso
# [Applauso]
# [Musica]
# ma in faccia
# aiuto
# [Musica]
# grazie
# chiamiamo da mariana il papa nuova
# guinea è possibile caricare facciata
# ligabue
# vero falso o no
# errore per marianna marco
# [Risate]
# [Musica]
# svizzera sorge l'australia vero falso
# vero è vero mi ha raccontato tutto
# grazie la wii che abbiamo lasciando i
# primi modelli di lavatrice erano le
# donne vero falso vero è vero
# vittoria ma va a ruba vero falso
# e invece andiamo da marco è più
# probabile che una donna andrà chi era
# uno sconosciuto
# se accade sia chiederlo è un uomo con il
# caro vero beve rover è invece il falso
# poi lo ha fatto questo studio eleonora
# [Musica]
# claudia namibia che è possibile
# vero falso
# [Musica]
# marianna per alcuni medici cartoni come
# shrek spingerebbero i bambini a
# soffriggere la pur vero però è invece è
# vero è una ricerca deriva da lampedusa
# marianna al file doc e errore devi
# smettere di liti pronta di funny or die
# si arriva il titolo in cui lo vediamo ci
# restano in gara tra claudia e marianna
# fermalo quando vuoi ferma lo ferma lo
# giochiamo con la lettera settore in cui
# si producono servizi e cpu poker a carte
# scoperte e passo ghiandola è in bambola
# seppie eccetto fuorché ecc corretto
# sigla gruppo etnico dello screen lanka
# passo aggettivo accetterà tivo
# [Musica]
# poker a carte scoperte la manina del
# gruppo etnico dello screen lanka lima
# peccato claudia esce di scena
# ti auguro tanta felicità grazie alla
# regione android stata una bella
# esperienza
# grazie
# e proprio da marianna ripartiamo con i
# fantastici quattro parleremo adesso del
# 40 del 60 il 40 dei 99 primo evento da
# abbinare uno di questi dati
# fabio capello diventa cava mio fratello
# vero falso
# e invece il 99 l'allenatore italiano che
# entra in questa arca della gloria dopo
# harris sacchi marcello pepe e giovanni
# trapattoni
# entra capi o fartello andiamo da moreno
# il fascismo promuove l'economia di
# toglierli ciccione 1949 era il 40 ma
# piersandro la notte del 31 dicembre
# informatici trattengono il fiato per
# paura di una scoreggia 999 e sa se dal
# 99 2000 marco nikita krusciov batterica
# tiro sul tavolo dell'onu 1960
# esatto marianna lara croft mender il
# fumo 99 la risposta è comunque sbagliata
# moreno e le rubò il fuoco su mia moglie
# prendiamo da marco la ferrari ingaggia
# con fu panda 1960 esatto
# [Applauso]
# varian al parlamento europeo francois
# mitterand pronuncia un discorso
# sull'importanza dell'etica 99 si è fatto
# più sandro viene progettato il cammello
# 1940 no è del 1999 doppio errore per
# sandro sandro un pellisari eliminazione
# maria questa volta ti devi difendere
# marianna marianna pronta e la risposta è
# esatta
# sandro tavola ragionato con noi laici
# [Applauso]
# spostatevi è il momento della scossa
# [Applauso]
# [Musica]
# [Applauso]
# [Musica]
# [Applauso]
# questa sera parliamo di gatti
# [Applauso]
# allora per creare quale di questi
# celebri gatti il suo autore sia ispirato
# ad una gatta trattata gatto di legno
# tratta piatto garcia gli stivali gatto
# tomtom gamma di doraemon mamma di legno
# 6 la scritta io dico d'ora il mondo
# scossa vabbè marco barba di legno scosse
# vabbè arianna figaro corsa va bene
# morero
# gatto scossa
# [Musica]
# e giochiamo al bivio parola di partenza
# marini per pezzo valentino rosa o viola
# vecchio faro osceni
# no c'è il termine arabo che significa
# letteralmente vecchio lipera errore per
# vittorio 6 66 66 65
# valerio valentino para lentino no e lo
# affanculo cioè la fa anche un altro ma
# andiamo da mariani ma carciofo cuore o
# pelle a pelle non era palle cuore
# igor o fuori poi mori con serie
# televisive ecco la calabria sia in
# vendita sia per me è una fiction
# intitolata agli occhi del bando i due
# racconta il 7 del nostro mori 0 off
# shore 0 see more escludono bizzarro
# pelusio mori anzi 0 caterino carolina
# caterina il palazzo di questo caso
# residenza esperienza a rischio caterina
# alcun o nessun nesso è un po un
# passaggio d occhio perché caterina
# caselli canta nessuno è più di nessuno
# nessun nuovo a zelaya o all'asl in da
# marziani
# nessuno mi aggredisce in culo è il motto
# di topazia fatto briglia marianna co2
# farfa briglia briglia l'isola di [ __ ]
# che fa parte di isole interne al largo
# delle scosse delle scorte delle cose che
# le proprie forze e delle scorte so che
# le delle scorte delle cozze e scozzesi
# scusate il gioco di proprio marianna
# doppio errore se aristo limitazione un
# bell'incontro arriva il cubo pronte a
# vittoria un simile in tutto e per tutto
# ostia nato si proveniente dall'arabia
# mammola no uno spasso renzo di quelli
# della notte unicorno si leggendario
# tifoso della frittata
# non solo la cucciola e di stile sì
# quando un uomo con la pistola contro un
# uomo col questi le quello con la puzzola
# è un uomo messicano è un vecchio
# proverbio morto
# che è ingenui
# [Musica]
# il dito di culo proveniente dall'arabia
# chiaro no arrabbiato
# marianna per un istante
# [Applauso]
# marianna siamo tanto sentita grazie aver
# giocato con noi e andiamo noi siete qua
# andiamo con il duello finale dello
# stradello è l'art
# [Applauso]
# marco in svantaggio inizierà per primo a
# rispondere alla prima delle 1.776
# domande parliamo di della storia delle
# parole
# a giudicare dal significato letterale
# della parola che è ori pilato si
# presenta con cosa con gli occhi sgranati
# con la caraffa d'oca con 40 capelli o
# con i [ __ ] psi des con la grata
# troppa letteralmente o ripi l'azione
# vuol dire avere la terapia d'oca la
# risposta è esatta
# seconda domanda
# parliamo di mezzi di guerra quando in
# questi mesi fu usato nel 1776 durante la
# guerra d'indipendenza americana moto
# schifo a molla carro armato parlarono
# fenicottero a pedate rotto marino a
# manovella
# ora andiamo da vittorio torniamo da
# marco provato marino a manovella
# alternative elicottero a pedate rotto
# marino a manovella si chiamava a meno e
# cantanto cioè tartaruga fu progettato da
# raffaella carrà era fatto il regno di
# game in missione il pilota doveva
# avvicinarsi ad uno scafo di una nave
# nemica e poi ripartire
# era un rotto marino a manovella che
# doveva fare tutto
# fecero dei tre tentativi e poi l'idea è
# stata accantonata
# terza domanda coppie celebri nel 1968
# prima di sposarsi jackie kennedy e
# aristotele onassis siglarono un accordo
# stabiliva anche quante volte dovevano
# fare cosa telefonare su una nave
# baciarsi in un corrent fare un anno in
# un mese o cenare e fare l'amore insieme
# cena ray fare l'amore insieme no andiamo
# da vittoria
# gli dico baciarsi in un giorno no
# torniamo da fare un anno e un mese
# allora siglarono quello che è stato uno
# dei primi accordi prematrimoniali della
# storia il contratto di 170 articoli
# assegnava anche una sorta di paghetta di
# 30 mila dollari al mese di allora stiamo
# parlando del 68 ovvero circa 140 96 30
# mila euro al mese oggi e soprattutto era
# indicato l'obbligo da come siete tutti
# curiosi
# quante volte dovevano fare un anno un
# mese ed era almeno una volta al mese con
# al massimo di 389 altri guarasci a mille
# cioè se un mese vuole fa no va bene
# la risposta è comunque esatta
# con te ne parliamo di caffè la polvere
# di caffè pura cioè che non contiene
# surrogati si è gettata in acqua
# cosa fa a fuga si scioglie affaccia o
# faiella le scene affogati no andiamo la
# vittoria sì so se no torniamo da marco a
# foggia a fu già tant'è vero che può
# essere un sistema filari butta un po di
# caffè per una
# in una scodella d'acqua e si guarda
# indovina questa diventa campi ma
# parliamo di ricette nel suo ricettario
# pellegrino artusi afferma che il pollo
# alla diavola si chiama così perché dopo
# averlo mangiato si diventa il piatto si
# fa l'amore nelle orecchie si imporrà il
# cuoco o si insultano gatto si sa poco
# artusi celebre critico gastronomico del
# da fine ottocento nel suo ormai
# leggendario trattato afferma che il
# bollo al diavolo alla diavola si chiama
# così perché si dovrebbe continue con tan
# già forte di cayenna servire con una
# salsa molto salsa cosi che a chi lo
# mangia si sente accendere il caso egli
# viene la tentazione di di impugnare il
# pollo e chi l'ha cucinato la risposta e
# sappia gloria è la nostra nuova
# campionessa
# gloria entrarvi portare a casa prima
# nostri ma è altissima la tensione
# nell'area cattolica ea il posticipo
# lazio
# sassuolo calcio la juventus vince il
# derby di paesi balcanici bianconeri ci
# sono al momento a più 4 dal napoli 5
# stasera gioca per la gestione dei
# migranti
# la notte degli oscar a salvini la
# statuetta per la miglior bufera sulla
# paternità di vendola a di caprio quella
# dei migliori modi otto anni miglior film
# lutero soffitta si chiama vittoria di
# nome e di fatto dai campionessa o il
# passivo successivo è quello di riuscire
# a capire la parola e magari
# e magari non dimezzare mari e quindi
# portare a casa ma no per la gioia di
# salvini
# dei tuoi figli figli soprattutto è
# diventata anche una renna
# [Applauso]
# [Musica]
# mossa la cuffia domani tutti segue con
# grande attenzione e credo interessi è
# una meraviglia fatti sotto me schiaccia
# inizia prima scelta tra queste due
# parole stuccare
# dopo di dida
# va bene 130.000 seconda parola
# [Musica]
# [Applauso]
# parte pensa tutto
# i dubbi
# va bene 130.000 terza parola la sorgue
# lo stesso
# bega
# equilibrio
# va bene ci siamo alla quarta parola
# series no
# no no sei tipi di di tipi di btp di
# giudizio fino all'ultima parola devi
# scegliere tra queste ore
# oggi
# figlio di riina
# 65 mila euro
# [Musica]
# crea silenzio
# [Musica]
# asca
# male
# francesca
# [Musica]
# e qui
# boschi
# scade il lavoro all in
# togli di pure la scuffia fare così che
# già milioni che eviti seeber rappresenti
# jtf barisic mentre tu hai pensato
# qualche parola
# no non andrò sono reso a inseguire la
# tensione di vittoria nota mentre nessuna
# somiglia un pochino lampedusa me l'hanno
# detto però 65 mila euro
# bella sommetta no gioca con giorgio il
# gas della serie apro la busta
# vi troviamo ha diritto
# carlo non ci sta mi era venuto in mente
# anche un'altra però non so se lega bene
# quale altra parola teramano di lavoro
# ball
# facciamo un gioco aggiungo una parola
# lo chef la raggiungo una parola rubare
# rambus la parola di questa sera vittoria
# ci riproviamo domani grazie a essere
# instabile
# è una persona molto al limite anche ore
# vorrei diventare un
# subito a far vedere cesarino casa
# [Musica]
#
# Parole inappropriate rilevate: culo, affanculo, cazzo
# Etichetta originale: 0, Nuova etichetta: 2
# --------------------------------------------------------------------------------
# Titolo: YTP_004.txt
# Testo originale: [Musica]
# scopare e godere è il segreto del
# grande pasticcere, la fessa è qualche cosa
# di straordinario è uno dei cibi più
# semplici ma non banali per una buona
# fica serve un ottimo burro una canna
# del miele di acacia dai tuorli di acacia
# del dio can
# in una piccola planetaria ci sburriamo
# dentro
# di seguito
# facciamo girare le palle per qualche
# secondo
# grattugio il mio cazzone
# utilizzando la grattugia verso l'altro
# per vedere quello che cazzo faccio
# così non grattugiamo il prepuzio che ha
# un sapore amaro non
# gradevole quando si degusta una fessa
# straordinaria
# intanto che il burro assorbe i tuorli
# d'uovo vi faccio una raija
# [Musica]
# ho
# una buona frolla dopo impastata non si
# appiccica al cazzo
# perfetta
# prendiamo un matterello
# ce lo mettiamo in culo
# ecco la cottura perfetta di una fighetta
# a vediamo meglio sul fondo color
# nocciola dorato unicato croccante croppi
# forme un infante maleodoranze proprio
# quello che serve per fare questa
# tipologia di vagine innovative abbiamo
# una crostata usata con confettura di
# mattarello è una ganache amara di merda
# fondente una crostata cuadrado con rotta
# crema pasticcera e pan di poco
# un'altra frolla tonda con confettura di
# niente e vari dalle fregate delle
# piccole tartellette con confettura di
# pezze sono un sogno da vedere e da
# scopare
# [Musica]
#
# Parole inappropriate rilevate: culo, cazzo
# Etichetta originale: 0, Nuova etichetta: 2
# --------------------------------------------------------------------------------
# Titolo: YTP_011.txt
# Testo originale: [Musica]
# c'è qualcosa che luccica in mezzo
# all'acqua
# Montale?
# aiuto Qua ci sono due grossi cazzi Rosa
# che mi vogliono scopare Siamo due grandi
# Monelli Peppa vuole battere il culo di nonno pig
# se si avvicina una conchiglia
# all'orecchio si sente il rumore di rondo
# [Musica]
# sono riuscita a sentirlo
# È la prima volta che quel coglione di
# George va in piscina Perché non provi a
# bagnare un solo piede
# [urla]
# appoggiati a questo cazzo potrai
# esercitarti a sbattere le palle
# George vuoi provare anche tu?
# siete bravissimi ma Cercate di non
# schizzare
# buongiorno Mi scusi Ha visto la regina
# per caso? la regina è una vecchia
# bastarda che porta una coca-cola sulla
# testa
# sono io la regina
# la signorina coniglio è morta
# Ecco la macchina a raggi ani
# Guarda quella è la mia
# Cazzi George
# decolla
# aereoplano
# [rumore di schianto]
# [Musica]
# a George piacciono gli aeroplanini
# È proprio vero
# [Applauso]
# [Musica]
# [Applauso]
# sta scherzando le onde sono perfette per
# gli adulti che vogliono scopare
# fantastico
# allora
# [Musica]
# le canne sono il mio passatempo
# preferito anche per me
# [rumore di un'esplosione]
# Siamo bloccati su un'isola deserta e per
# di più non abbiamo niente da mangiare
# [rumore di flatulenza]
# Io ho fatto la cacca
# Bene allora dobbiamo conservarla nell'eventualità
# che ci venga fame più tardi
# [Musica]
#
# Parole inappropriate rilevate: culo, cazzo
# Etichetta originale: 0, Nuova etichetta: 2
# --------------------------------------------------------------------------------
# Titolo: YTP_014.txt
# Testo originale: [Musica]
# occhi pieni di falsità
# [conati di vomito]
# porco dio
# [rumore di eruttazione]
# sesso pazzo con Amadeus
# [gemiti]
# [rumore di esplosione]
# [urla]
#
# [Applauso]
# [rumore di flatulenza]
# amo l'alba perché è come fosse solo mia
# [Musica]
# amo l'alba perché è come fosse solo mia
# [Musica]
# amo l'alba perché è come fosse solo mia
# [Musica]
# E.T.
# A B C
# [Musica]
# la pasta non ha lipidi
# mi brucia infondo al culo ho le morroidi
# [rumore di flatulenza]
# ho avuto i brividi
# zitti stronzi
# [rumore di flatulenza]
# puoi capirla se la senti e non mandarla via
#
# Parole inappropriate rilevate: culo
# Etichetta originale: 0, Nuova etichetta: 2
# --------------------------------------------------------------------------------
# Titolo: YTP_002.txt
# Testo originale: [Musica]
# ci sono un mucchio di uova di cioccolato
# nascoste nel mio giardino ma mi
# raccomando fate attenzione a non
# schiacciare le mie palle per i così
# elettrizzante vedere queste piccoline e
# ora datevi da fare
# inizia la caccia alle uova di cazzo
# ahahha sono proprio simpatico
# ci vorrà chissà quanto
# tempo per trovare le uova di cioccolato
# le ho nascoste talmente bene
# ecco qui un uovo
# rebecca coniglio ha trovato un uovo di
# cioccolato in un vaso da fiori
# [Musica]
# canili elefante ha trovato un uovo di
# cioccolato nascosto dietro a un
# cespuglio
# freddi volpe shackleton fatto credo di
# sentire il profumo di merda
# eccolo
# [Musica]
# scusi signor anatra
# senti Rebecca, ti è mai capitato di vedere
# il coglione pasquale?
# no ma il coniglio pasquale è un coniglio giusto?
# no
# anche tu sei un coniglio
# no
# [urla]
# secondo te che aspetto ha?
# penso che assomiglia a me io credo che abbia un
# cazzo con le foglie
# [risate] è un coniglio col super culo
# [Musica]
# deve essere pasquale
# it's time to stop ok? no more
# [Musica]
#
# Parole inappropriate rilevate: culo
# Etichetta originale: 0, Nuova etichetta: 2
# --------------------------------------------------------------------------------
# Titolo: YTP_009.txt
# Testo originale: [Musica]
# vi capita mai di guardare con il culo
# beh io sì
# presto
# risotto
# era il cretino
# un momento che cos'è
# se non mangi la scimmietta non
# avrai il dolce
# all'isola dei la mia
# preferita
# meno male che mi ha detto che i terroni
# sono una leggenda gioia altrimenti sarei terrorizzato adesso
# sì, ecco la nostra nuova casa
# che cosa ci fate a casa mia
# ragazzi state esagerando
# un morto
# sta per vomitare
# che ne dici di un bacio portafortuna
# stai scherzando?
# enders riparte, avanza decisa verso la...
# ma che cazzo fai?
# io ho visto una è in fondo alla strada
# mi sembra un'ottima idea
# ora ragioniamo
# noi scivoleremo giù fino in fondo
# [urla]
# bel colpo gioia
# prova a pensare a qualcosa
# di buffo che ne dici di quella volta
# quando a riley le è uscito papà dal naso?
# mamma il bacio della buonanotte
# sono un po' eccitata
# ho il cazzo appeso
# blah, non voglio sentir parlare
# facciamo una lista di tutte le
# cose per cui riley dovrebbe essere felice
# la mamma fa schifo gioia fa schifo
# che c'è in programma cine produzione sogni
# non posso credere che mamma abbia scritto un libro prima di me
# un po' spazzatura
# ma chi è il capo della programmazione?
# Parole inappropriate rilevate: culo
# Etichetta originale: 0, Nuova etichetta: 2
# --------------------------------------------------------------------------------
# Titolo: YTP_022.txt
# Testo originale: mai caffè all'italiana non siate sinceri
# i caschi la lingua se non dico il vero
# i caschi laschi di omero
# [Musica]
# basta stronzate sparisci serpente venga
# signora chiedo spillo è una scelta
# sicura
# [Musica]
# se cerca la carne e la cerca italiana la
# scelta migliore è un po illuda buttano è
# una scelta sicura parola di roberto
# carlino lui l'università e campus è una
# scema l'università e campus è una
# stronzata perché è da sempre una merda
# ai la più ampia offerta di frumento puoi
# scegliere tra d'ottocento tutto in
# presenza e da sublim le level e canzoni
# sono sempre disponibili e su su si
# elimini bili e sostieni gli esami dal
# tuo culo chiamano 800 400 410 810 3 300
# e sociali il cazzo il meme scegliti a
# spello le assicurazioni auto il festival
# delle auto il festival delle prostitute
# per la pizza auto ho scelto conte
# puntate punto io appunto series punto it
# quando bisogno solo sempre fatto io è un
# prezzo più basso io non lo fate un po un
# po prima della sottoscrizione sotto soli
# di sms o vivo
#
# Parole inappropriate rilevate: culo
# Etichetta originale: 0, Nuova etichetta: 2
# --------------------------------------------------------------------------------

# %% [markdown]
# Risultati medi su 5 fold:
# 		Precision	Recall	F1-score	Support
# 0_bambini	0.82		0.89	0.85		209.0
# 1_ragazzi	0.64		0.81	0.70		179.0
# 2_adulti	0.77		0.30	0.40		126.0
#
# Macro avg	0.74		0.67	0.65
# Weighted avg	0.75		0.72	0.69
#
# Accuratezza media su 5 fold: 0.72

# %% [markdown]
# # ELECTRA

# %%
import os
import numpy as np
import torch
from torch.utils.data import Dataset
from transformers import ElectraTokenizer, ElectraForSequenceClassification, Trainer, TrainingArguments
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, classification_report

# Montaggio di Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Percorso della cartella dei dati su Google Drive
data_path = '/content/drive/My Drive/esperimento'

# Tokenizer specifico per ELECTRA in italiano
tokenizer = ElectraTokenizer.from_pretrained('dbmdz/electra-base-italian-xxl-cased-discriminator')

# Classe Dataset
class TextDataset(Dataset):
    def __init__(self, texts, labels, tokenizer):
        self.encodings = tokenizer(texts, truncation=True, padding=True, max_length=512)
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.labels)

# Funzione per calcolare le metriche
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    return {"accuracy": accuracy_score(labels, predictions)}

# Funzione per caricare i dati
def load_data(data_path):
    texts, labels, titles = [], [], []
    label_dict = {'0_bambini': 0, '1_ragazzi': 1, '2_adulti': 2}
    for label, index in label_dict.items():
        folder_path = os.path.join(data_path, label)
        for filename in os.listdir(folder_path):
            with open(os.path.join(folder_path, filename), 'r', encoding='utf-8') as file:
                texts.append(file.read())
                labels.append(index)
                titles.append(filename)
    return texts, labels, titles

# Caricamento dei dati
texts, labels, titles = load_data(data_path)

# Inizializza dizionari per raccogliere i risultati medi
precision_sum = {class_name: 0 for class_name in ['0_bambini', '1_ragazzi', '2_adulti']}
recall_sum = {class_name: 0 for class_name in ['0_bambini', '1_ragazzi', '2_adulti']}
f1_sum = {class_name: 0 for class_name in ['0_bambini', '1_ragazzi', '2_adulti']}
support_sum = {class_name: 0 for class_name in ['0_bambini', '1_ragazzi', '2_adulti']}

accuracy_per_fold = []
macro_avg_precision_sum, macro_avg_recall_sum, macro_avg_f1_sum = 0, 0, 0
weighted_avg_precision_sum, weighted_avg_recall_sum, weighted_avg_f1_sum = 0, 0, 0

fold = 1

# K-fold cross-validation
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

for train_index, test_index in kfold.split(texts):
    print(f'\nFold {fold}')
    fold += 1

    # Divisione in train e test per il fold corrente
    train_texts = [texts[i] for i in train_index]
    test_texts = [texts[i] for i in test_index]
    train_labels = [labels[i] for i in train_index]
    test_labels = [labels[i] for i in test_index]

    # Creazione dei dataset
    train_dataset = TextDataset(train_texts, train_labels, tokenizer)
    test_dataset = TextDataset(test_texts, test_labels, tokenizer)

    # Configurazione dei parametri di training
    training_args = TrainingArguments(
        output_dir='./results',
        num_train_epochs=3,
        per_device_train_batch_size=8,
        per_device_eval_batch_size=16,
        warmup_steps=500,
        weight_decay=0.01,
        logging_dir='./logs',
        logging_steps=10,
        evaluation_strategy="epoch",  # Valutazione a ogni epoca
        save_strategy="no",  # Disabilita il salvataggio dei checkpoint intermedi
        load_best_model_at_end=False  # Non caricare il miglior modello alla fine
    )

    # Inizializzazione del modello e del trainer
    model = ElectraForSequenceClassification.from_pretrained('dbmdz/electra-base-italian-xxl-cased-discriminator', num_labels=3)

    trainer = Trainer(
        model=model,
        args=training_args,
        train_dataset=train_dataset,
        eval_dataset=test_dataset,
        compute_metrics=compute_metrics
    )

    # Training del modello
    trainer.train()

    # Valutazione sul test del fold corrente
    predictions = trainer.predict(test_dataset)
    predicted_labels = np.argmax(predictions.predictions, axis=1)

    # Calcolo del classification report
    target_names = ['0_bambini', '1_ragazzi', '2_adulti']
    report = classification_report(test_labels, predicted_labels, target_names=target_names, output_dict=True)

    # Stampa del classification report formattato
    print("\t\tPrecision\tRecall\tF1-score\tSupport")
    for class_name in target_names:
        class_report = report[class_name]
        print(f"{class_name}\t{class_report['precision']:.2f}\t\t{class_report['recall']:.2f}\t{class_report['f1-score']:.2f}\t\t{class_report['support']}")

    print("\n\t\t\tSupport")
    print(f"Accuracy\t\t{report['accuracy']:.2f}\t{len(test_labels)}")
    print(f"Macro avg\t{report['macro avg']['precision']:.2f}\t\t{report['macro avg']['recall']:.2f}\t{report['macro avg']['f1-score']:.2f}\t\t{len(test_labels)}")
    print(f"Weighted avg\t{report['weighted avg']['precision']:.2f}\t\t{report['weighted avg']['recall']:.2f}\t{report['weighted avg']['f1-score']:.2f}\t\t{len(test_labels)}")

    # Somma i valori di precision, recall, f1 e support per ogni classe
    for class_name in target_names:
        precision_sum[class_name] += report[class_name]['precision']
        recall_sum[class_name] += report[class_name]['recall']
        f1_sum[class_name] += report[class_name]['f1-score']
        support_sum[class_name] += report[class_name]['support']

    # Somma per macro avg e weighted avg
    macro_avg_precision_sum += report['macro avg']['precision']
    macro_avg_recall_sum += report['macro avg']['recall']
    macro_avg_f1_sum += report['macro avg']['f1-score']

    weighted_avg_precision_sum += report['weighted avg']['precision']
    weighted_avg_recall_sum += report['weighted avg']['recall']
    weighted_avg_f1_sum += report['weighted avg']['f1-score']

    # Aggiungi l'accuratezza alla lista per calcolare la media finale
    accuracy_per_fold.append(report['accuracy'])

# Media dei risultati per ogni classe
print("\nRisultati medi su 5 fold:")
print("\t\tPrecision\tRecall\tF1-score\tSupport")
for class_name in target_names:
    print(f"{class_name}\t{(precision_sum[class_name]/5):.2f}\t\t{(recall_sum[class_name]/5):.2f}\t{(f1_sum[class_name]/5):.2f}\t\t{support_sum[class_name]}")

# Media per Macro avg e Weighted avg
print(f"\nMacro avg\t{(macro_avg_precision_sum/5):.2f}\t\t{(macro_avg_recall_sum/5):.2f}\t{(macro_avg_f1_sum/5):.2f}")
print(f"Weighted avg\t{(weighted_avg_precision_sum/5):.2f}\t\t{(weighted_avg_recall_sum/5):.2f}\t{(weighted_avg_f1_sum/5):.2f}")

# Stampa dell'accuratezza media finale
print(f"\nAccuratezza media su 5 fold: {np.mean(accuracy_per_fold):.2f}")

# Salva il modello finale
trainer.save_model(output_dir="./final_model")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Fold 1
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of ElectraForSequenceClassification were not initialized from the model checkpoint at dbmdz/electra-base-italian-xxl-cased-discriminator and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='156' max='156' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [156/156 02:17, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.052500</td>
#       <td>1.044491</td>
#       <td>0.592233</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.874200</td>
#       <td>0.766153</td>
#       <td>0.728155</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.639300</td>
#       <td>0.802128</td>
#       <td>0.631068</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 		Precision	Recall	F1-score	Support
# 0_bambini	0.97		0.67	0.79		46.0
# 1_ragazzi	0.48		0.97	0.64		35.0
# 2_adulti	0.00		0.00	0.00		22.0
#
# 			Support
# Accuracy		0.63	103
# Macro avg	0.48		0.55	0.48		103
# Weighted avg	0.60		0.63	0.57		103
#
# Fold 2
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of ElectraForSequenceClassification were not initialized from the model checkpoint at dbmdz/electra-base-italian-xxl-cased-discriminator and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='156' max='156' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [156/156 02:17, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.063700</td>
#       <td>1.057522</td>
#       <td>0.611650</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.834700</td>
#       <td>0.791359</td>
#       <td>0.650485</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.586200</td>
#       <td>0.638863</td>
#       <td>0.747573</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	0.93		0.86	0.89		44.0
# 1_ragazzi	0.57		0.94	0.71		31.0
# 2_adulti	0.91		0.36	0.51		28.0
#
# 			Support
# Accuracy		0.75	103
# Macro avg	0.80		0.72	0.70		103
# Weighted avg	0.81		0.75	0.73		103
#
# Fold 3
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of ElectraForSequenceClassification were not initialized from the model checkpoint at dbmdz/electra-base-italian-xxl-cased-discriminator and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='156' max='156' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [156/156 02:17, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.059300</td>
#       <td>1.068272</td>
#       <td>0.475728</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.853700</td>
#       <td>0.832007</td>
#       <td>0.650485</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.595000</td>
#       <td>0.666384</td>
#       <td>0.737864</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	0.80		0.97	0.88		37.0
# 1_ragazzi	0.65		0.85	0.73		39.0
# 2_adulti	1.00		0.26	0.41		27.0
#
# 			Support
# Accuracy		0.74	103
# Macro avg	0.82		0.69	0.67		103
# Weighted avg	0.79		0.74	0.70		103
#
# Fold 4
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of ElectraForSequenceClassification were not initialized from the model checkpoint at dbmdz/electra-base-italian-xxl-cased-discriminator and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='156' max='156' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [156/156 02:17, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.067100</td>
#       <td>1.054812</td>
#       <td>0.621359</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.856900</td>
#       <td>0.812326</td>
#       <td>0.669903</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.556300</td>
#       <td>0.605449</td>
#       <td>0.757282</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	0.81		0.98	0.88		43.0
# 1_ragazzi	0.68		0.83	0.75		36.0
# 2_adulti	0.86		0.25	0.39		24.0
#
# 			Support
# Accuracy		0.76	103
# Macro avg	0.78		0.69	0.67		103
# Weighted avg	0.78		0.76	0.72		103
#
# Fold 5
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of ElectraForSequenceClassification were not initialized from the model checkpoint at dbmdz/electra-base-italian-xxl-cased-discriminator and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='156' max='156' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [156/156 02:17, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.070900</td>
#       <td>1.054137</td>
#       <td>0.480392</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.872900</td>
#       <td>0.791923</td>
#       <td>0.705882</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.707000</td>
#       <td>0.710740</td>
#       <td>0.794118</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	0.75		1.00	0.86		39.0
# 1_ragazzi	0.80		0.84	0.82		38.0
# 2_adulti	1.00		0.40	0.57		25.0
#
# 			Support
# Accuracy		0.79	102
# Macro avg	0.85		0.75	0.75		102
# Weighted avg	0.83		0.79	0.77		102
#
# Risultati medi su 5 fold:
# 		Precision	Recall	F1-score	Support
# 0_bambini	0.85		0.90	0.86		209.0
# 1_ragazzi	0.64		0.89	0.73		179.0
# 2_adulti	0.75		0.25	0.38		126.0
#
# Macro avg	0.75		0.68	0.66
# Weighted avg	0.76		0.73	0.70
#
# Accuratezza media su 5 fold: 0.73
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-7f54b03478c3> in <cell line: 165>()
#     163
#     164 # Salva il modello finale
# --> 165 trainer.save_model(output_dir="./final_model")
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in save_model(self, output_dir, _internal_call)
#    3452
#    3453         elif self.args.should_save:
# -> 3454             self._save(output_dir)
#    3455
#    3456         # Push to the Hub when `save_model` is called by the user.
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in _save(self, output_dir, state_dict)
#    3523                     torch.save(state_dict, os.path.join(output_dir, WEIGHTS_NAME))
#    3524         else:
# -> 3525             self.model.save_pretrained(
#    3526                 output_dir, state_dict=state_dict, safe_serialization=self.args.save_safetensors
#    3527             )
#
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py in save_pretrained(self, save_directory, is_main_process, state_dict, save_function, push_to_hub, max_shard_size, safe_serialization, variant, token, save_peft_format, **kwargs)
#    2791                 # At some point we will need to deal better with save_function (used for TPU and other distributed
#    2792                 # joyfulness), but for now this enough.
# -> 2793                 safe_save_file(shard, os.path.join(save_directory, shard_file), metadata={"format": "pt"})
#    2794             else:
#    2795                 save_function(shard, os.path.join(save_directory, shard_file))
#
# /usr/local/lib/python3.10/dist-packages/safetensors/torch.py in save_file(tensors, filename, metadata)
#     284     ```
#     285     """
# --> 286     serialize_file(_flatten(tensors), filename, metadata=metadata)
#     287
#     288
#
# /usr/local/lib/python3.10/dist-packages/safetensors/torch.py in _flatten(tensors)
#     494         )
#     495
# --> 496     return {
#     497         k: {
#     498             "dtype": str(v.dtype).split(".")[-1],
#
# /usr/local/lib/python3.10/dist-packages/safetensors/torch.py in <dictcomp>(.0)
#     498             "dtype": str(v.dtype).split(".")[-1],
#     499             "shape": v.shape,
# --> 500             "data": _tobytes(v, k),
#     501         }
#     502         for k, v in tensors.items()
#
# /usr/local/lib/python3.10/dist-packages/safetensors/torch.py in _tobytes(tensor, name)
#     412
#     413     if not tensor.is_contiguous():
# --> 414         raise ValueError(
#     415             f"You are trying to save a non contiguous tensor: `{name}` which is not allowed. It either means you"
#     416             " are trying to save tensors which are reference of each other in which case it's recommended to save"
#
# ValueError: You are trying to save a non contiguous tensor: `electra.encoder.layer.0.attention.self.query.weight` which is not allowed. It either means you are trying to save tensors which are reference of each other in which case it's recommended to save only the full tensors, and reslice at load time, or simply call `.contiguous()` on your tensor to pack it before saving.

# %% [markdown]
# # electra con badwords

# %%
import os
import numpy as np
import torch
from torch.utils.data import Dataset
from transformers import ElectraTokenizer, ElectraForSequenceClassification, Trainer, TrainingArguments
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, classification_report
from nltk.tokenize import word_tokenize
import nltk

# Montaggio di Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Scarica risorse di NLTK per la tokenizzazione
nltk.download('punkt')

# Percorso della cartella dei dati su Google Drive
data_path = '/content/drive/My Drive/esperimento'

# Caricamento delle bad words in italiano
bad_words_path = '/content/drive/My Drive/bad_words.txt'

try:
    with open(bad_words_path, 'r', encoding='utf-8') as file:
        bad_words = set(line.strip() for line in file)
except Exception as e:
    print(f"Error loading bad words: {e}")
    bad_words = set()  # Definisci un set vuoto in caso di errore per evitare crash

# Funzione per rilevare bad words
def detect_bad_words(text, bad_words):
    words = set(word_tokenize(text.lower()))  # Tokenizza e converte tutto in minuscolo
    return words.intersection(bad_words)

# Tokenizer specifico per ELECTRA in italiano
tokenizer = ElectraTokenizer.from_pretrained('dbmdz/electra-base-italian-xxl-cased-discriminator')

# Classe Dataset
class TextDataset(Dataset):
    def __init__(self, texts, labels, tokenizer):
        self.encodings = tokenizer(texts, truncation=True, padding=True, max_length=512)
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.labels)

# Funzione per calcolare le metriche
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    return {"accuracy": accuracy_score(labels, predictions)}

# Funzione per caricare i dati
def load_data(data_path):
    texts, labels, titles = [], [], []
    label_dict = {'0_bambini': 0, '1_ragazzi': 1, '2_adulti': 2}
    for label, index in label_dict.items():
        folder_path = os.path.join(data_path, label)
        for filename in os.listdir(folder_path):
            with open(os.path.join(folder_path, filename), 'r', encoding='utf-8') as file:
                texts.append(file.read())
                labels.append(index)
                titles.append(filename)  # Salva il nome del file come titolo
    return texts, labels, titles

# Caricamento dei dati
texts, labels, titles = load_data(data_path)

# Inizializza dizionari per raccogliere i risultati medi
precision_sum = {class_name: 0 for class_name in ['0_bambini', '1_ragazzi', '2_adulti']}
recall_sum = {class_name: 0 for class_name in ['0_bambini', '1_ragazzi', '2_adulti']}
f1_sum = {class_name: 0 for class_name in ['0_bambini', '1_ragazzi', '2_adulti']}
support_sum = {class_name: 0 for class_name in ['0_bambini', '1_ragazzi', '2_adulti']}

accuracy_per_fold = []
macro_avg_precision_sum, macro_avg_recall_sum, macro_avg_f1_sum = 0, 0, 0
weighted_avg_precision_sum, weighted_avg_recall_sum, weighted_avg_f1_sum = 0, 0, 0

fold = 1

# K-fold cross-validation
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

# Lista per memorizzare i testi in cui l'etichetta è cambiata
texts_with_label_changes = []

for train_index, test_index in kfold.split(texts):
    print(f'\nFold {fold}')
    fold += 1

    # Divisione in train e test per il fold corrente
    train_texts = [texts[i] for i in train_index]
    test_texts = [texts[i] for i in test_index]
    train_labels = [labels[i] for i in train_index]
    test_labels = [labels[i] for i in test_index]

    # Creazione dei dataset
    train_dataset = TextDataset(train_texts, train_labels, tokenizer)
    test_dataset = TextDataset(test_texts, test_labels, tokenizer)

    # Configurazione dei parametri di training
    training_args = TrainingArguments(
        output_dir='./results',
        num_train_epochs=3,
        per_device_train_batch_size=8,
        per_device_eval_batch_size=16,
        warmup_steps=500,
        weight_decay=0.01,
        logging_dir='./logs',
        logging_steps=10,
        evaluation_strategy="epoch",  # Valutazione a ogni epoca
        save_strategy="no",  # Disabilita il salvataggio dei checkpoint intermedi
        load_best_model_at_end=False  # Non caricare il miglior modello alla fine
    )

    # Inizializzazione del modello e del trainer
    model = ElectraForSequenceClassification.from_pretrained('dbmdz/electra-base-italian-xxl-cased-discriminator', num_labels=3)

    trainer = Trainer(
        model=model,
        args=training_args,
        train_dataset=train_dataset,
        eval_dataset=test_dataset,
        compute_metrics=compute_metrics
    )

    # Training del modello
    trainer.train()

    # Valutazione sul test del fold corrente
    predictions = trainer.predict(test_dataset)
    predicted_labels = np.argmax(predictions.predictions, axis=1)

    # Aggiungi il controllo delle bad words
    adjusted_labels = []
    detected_bad_words_list = []

    for i, text in enumerate(test_texts):
        detected_bad_words = detect_bad_words(text, bad_words)
        original_label = predicted_labels[i]
        if original_label == 0 and detected_bad_words:
            adjusted_labels.append(2)  # Cambia l'etichetta in "adulti" se ci sono bad words
            detected_bad_words_list.append((titles[test_index[i]], detected_bad_words))

            # Memorizza i testi modificati
            texts_with_label_changes.append({
                "Title": titles[test_index[i]],
                "Original Text": text,
                "Detected Bad Words": list(detected_bad_words),
                "Original Label": original_label,  # Etichetta originale (0 = bambini)
                "New Label": 2  # Nuova etichetta (2 = adulti)
            })
        else:
            adjusted_labels.append(original_label)

    # Calcolo del classification report
    target_names = ['0_bambini', '1_ragazzi', '2_adulti']
    report = classification_report(test_labels, adjusted_labels, target_names=target_names, output_dict=True)

    # Stampa del classification report formattato
    print("\t\tPrecision\tRecall\tF1-score\tSupport")
    for class_name in target_names:
        class_report = report[class_name]
        print(f"{class_name}\t{class_report['precision']:.2f}\t\t{class_report['recall']:.2f}\t{class_report['f1-score']:.2f}\t\t{class_report['support']}")

    print("\n\t\t\tSupport")
    print(f"Accuracy\t\t{report['accuracy']:.2f}\t{len(test_labels)}")
    print(f"Macro avg\t{report['macro avg']['precision']:.2f}\t\t{report['macro avg']['recall']:.2f}\t{report['macro avg']['f1-score']:.2f}\t\t{len(test_labels)}")
    print(f"Weighted avg\t{report['weighted avg']['precision']:.2f}\t\t{report['weighted avg']['recall']:.2f}\t{report['weighted avg']['f1-score']:.2f}\t\t{len(test_labels)}")

    # Somma i valori di precision, recall, f1 e support per ogni classe
    for class_name in target_names:
        precision_sum[class_name] += report[class_name]['precision']
        recall_sum[class_name] += report[class_name]['recall']
        f1_sum[class_name] += report[class_name]['f1-score']
        support_sum[class_name] += report[class_name]['support']

    # Somma per macro avg e weighted avg
    macro_avg_precision_sum += report['macro avg']['precision']
    macro_avg_recall_sum += report['macro avg']['recall']
    macro_avg_f1_sum += report['macro avg']['f1-score']

    weighted_avg_precision_sum += report['weighted avg']['precision']
    weighted_avg_recall_sum += report['weighted avg']['recall']
    weighted_avg_f1_sum += report['weighted avg']['f1-score']

    # Aggiungi l'accuratezza alla lista per calcolare la media finale
    accuracy_per_fold.append(report['accuracy'])

    # Stampa i testi in cui sono state rilevate bad words
    if detected_bad_words_list:
        print(f"Bad words rilevate nel fold {fold - 1}:")
        for title, bad_words in detected_bad_words_list:
            print(f"Titolo: {title}, Bad words: {bad_words}")

# Media dei risultati per ogni classe
print("\nRisultati medi su 5 fold:")
print("\t\tPrecision\tRecall\tF1-score\tSupport")
for class_name in target_names:
    print(f"{class_name}\t{(precision_sum[class_name]/5):.2f}\t\t{(recall_sum[class_name]/5):.2f}\t{(f1_sum[class_name]/5):.2f}\t\t{support_sum[class_name]}")

# Media per Macro avg e Weighted avg
print(f"\nMacro avg\t{(macro_avg_precision_sum/5):.2f}\t\t{(macro_avg_recall_sum/5):.2f}\t{(macro_avg_f1_sum/5):.2f}")
print(f"Weighted avg\t{(weighted_avg_precision_sum/5):.2f}\t\t{(weighted_avg_recall_sum/5):.2f}\t{(weighted_avg_f1_sum/5):.2f}")

# Stampa dell'accuratezza media finale
print(f"\nAccuratezza media su 5 fold: {np.mean(accuracy_per_fold):.2f}")

# Stampa dei testi in cui l'etichetta è stata cambiata a causa delle bad words
if texts_with_label_changes:
    print(f"\nTesti con cambiamento di etichetta a causa di bad words ({len(texts_with_label_changes)} testi):")
    for item in texts_with_label_changes:
        print(f"Titolo: {item['Title']}")
        print(f"Testo originale: {item['Original Text']}")
        print(f"Parole inappropriate rilevate: {', '.join(item['Detected Bad Words'])}")
        print(f"Etichetta originale: {item['Original Label']}, Nuova etichetta: {item['New Label']}")
        print("-" * 80)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Fold 1
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of ElectraForSequenceClassification were not initialized from the model checkpoint at dbmdz/electra-base-italian-xxl-cased-discriminator and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='156' max='156' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [156/156 02:21, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.069600</td>
#       <td>1.046074</td>
#       <td>0.669903</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.880300</td>
#       <td>0.761209</td>
#       <td>0.737864</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.629700</td>
#       <td>0.764629</td>
#       <td>0.718447</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	0.97		0.72	0.82		46.0
# 1_ragazzi	0.56		0.97	0.71		35.0
# 2_adulti	1.00		0.36	0.53		22.0
#
# 			Support
# Accuracy		0.73	103
# Macro avg	0.84		0.68	0.69		103
# Weighted avg	0.84		0.73	0.72		103
# Bad words rilevate nel fold 1:
# Titolo: YTP_012.txt, Bad words: {'bastardo', 'cazzi', 'cazzo'}
#
# Fold 2
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of ElectraForSequenceClassification were not initialized from the model checkpoint at dbmdz/electra-base-italian-xxl-cased-discriminator and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='156' max='156' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [156/156 02:20, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.063700</td>
#       <td>1.057522</td>
#       <td>0.611650</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.834700</td>
#       <td>0.791359</td>
#       <td>0.650485</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.586200</td>
#       <td>0.638863</td>
#       <td>0.747573</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	0.95		0.86	0.90		44.0
# 1_ragazzi	0.57		0.94	0.71		31.0
# 2_adulti	0.92		0.39	0.55		28.0
#
# 			Support
# Accuracy		0.76	103
# Macro avg	0.81		0.73	0.72		103
# Weighted avg	0.83		0.76	0.75		103
# Bad words rilevate nel fold 2:
# Titolo: YTP_007.txt, Bad words: {'cazzi'}
#
# Fold 3
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of ElectraForSequenceClassification were not initialized from the model checkpoint at dbmdz/electra-base-italian-xxl-cased-discriminator and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='156' max='156' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [156/156 02:20, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.059300</td>
#       <td>1.068272</td>
#       <td>0.475728</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.853700</td>
#       <td>0.832007</td>
#       <td>0.650485</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.595000</td>
#       <td>0.666384</td>
#       <td>0.737864</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	0.82		0.97	0.89		37.0
# 1_ragazzi	0.65		0.85	0.73		39.0
# 2_adulti	1.00		0.30	0.46		27.0
#
# 			Support
# Accuracy		0.75	103
# Macro avg	0.82		0.71	0.69		103
# Weighted avg	0.80		0.75	0.72		103
# Bad words rilevate nel fold 3:
# Titolo: YTP_011.txt, Bad words: {'cazzi'}
#
# Fold 4
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of ElectraForSequenceClassification were not initialized from the model checkpoint at dbmdz/electra-base-italian-xxl-cased-discriminator and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='156' max='156' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [156/156 02:20, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.067100</td>
#       <td>1.054812</td>
#       <td>0.621359</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.856900</td>
#       <td>0.812326</td>
#       <td>0.669903</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.556300</td>
#       <td>0.605449</td>
#       <td>0.757282</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	0.82		0.98	0.89		43.0
# 1_ragazzi	0.68		0.83	0.75		36.0
# 2_adulti	0.88		0.29	0.44		24.0
#
# 			Support
# Accuracy		0.77	103
# Macro avg	0.79		0.70	0.69		103
# Weighted avg	0.79		0.77	0.74		103
# Bad words rilevate nel fold 4:
# Titolo: YTP_001.txt, Bad words: {'cazzi'}
#
# Fold 5
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Some weights of ElectraForSequenceClassification were not initialized from the model checkpoint at dbmdz/electra-base-italian-xxl-cased-discriminator and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='156' max='156' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [156/156 02:20, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.070900</td>
#       <td>1.054137</td>
#       <td>0.480392</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.872900</td>
#       <td>0.791923</td>
#       <td>0.705882</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.707000</td>
#       <td>0.710740</td>
#       <td>0.794118</td>
#     </tr>
#   </tbody>
# </table><p>
# 		Precision	Recall	F1-score	Support
# 0_bambini	0.76		1.00	0.87		39.0
# 1_ragazzi	0.80		0.84	0.82		38.0
# 2_adulti	1.00		0.44	0.61		25.0
#
# 			Support
# Accuracy		0.80	102
# Macro avg	0.85		0.76	0.77		102
# Weighted avg	0.84		0.80	0.79		102
# Bad words rilevate nel fold 5:
# Titolo: YTP_016.txt, Bad words: {'cazzi'}
#
# Risultati medi su 5 fold:
# 		Precision	Recall	F1-score	Support
# 0_bambini	0.87		0.91	0.88		209.0
# 1_ragazzi	0.65		0.89	0.74		179.0
# 2_adulti	0.96		0.36	0.52		126.0
#
# Macro avg	0.82		0.72	0.71
# Weighted avg	0.82		0.76	0.74
#
# Accuratezza media su 5 fold: 0.76
#
# Testi con cambiamento di etichetta a causa di bad words (5 testi):
# Titolo: YTP_012.txt
# Testo originale: [Musica]
# [Musica]
# non è possibile non è matematicamente
# Basta basta basta
# Ecco gli amici di Peppa
# [rumore di esplosione]
# Ognuno di loro ha una letterina per Babbo Natale
# [Musica]
# che cazzo avete chiesto a Babbo Bastardo?
# una navicella aziale
# una chitarra a giocare
# Totò
# una trombetta
# una racchetta con la racchetta
# George ha chiesto un
# coltello e io invece vorrei tanto un
# colore viola
# arriva il signor zebra
# Guarda quanta posta!
# Peppa e George si fanno una canna
# [Musica]
# Susi Susi Susi Susi
# Buongiorno Babbo Natale
# siete stati?
# sì
# avete sempre tenuto in ordine le vostre
# camere?
# sì
# ehi tu...
# oh oh oh ma fatti i cazzi tuoi
# potrei avere un pallone per favore
# No
# Io lo xilofono
# No
# Il gioco delle pulci
# No
# una scatola di magia
# No
# un treno per favore
# un treno giocattolo
# no, non un treno giocattolo, un treno giocattolo
# oh oh vedrò che cosa posso fare
# Allora tu come ti chiami?
# Sono Peppa Pig
# noi ci siamo già incontrati
# ma chi cazzo sei?
# mamma possiamo andare a giocare con la
# neve?
# evviva
# [risate]
# ma che cazzo saltano?
# [risate]
# non è affatto divertente
# [risate]
# [rumore di uno sparo]
# [risate]
# [Musica]
#
# Parole inappropriate rilevate: bastardo, cazzi, cazzo
# Etichetta originale: 0, Nuova etichetta: 2
# --------------------------------------------------------------------------------
# Titolo: YTP_007.txt
# Testo originale: come vi aveva promesso lui stesso torna
# Blanco
# [Musica]
# qui è partita la sabarabba qual è il
# significato
# il significato è che ho detto tutti
# andare a fanculo Dio cane madonna ciuccia cazzi
# Vabbè la cosa bella della musica è che
# la musica la musica credo che tu non
# faccia ridere adesso ti denuncio
# [Musica]
# [Musica]
# [rumore di eruttazioni e conati di vomito]
# [urla]
# sono scoppiata
# non volevamo crescere
# [Musica]
# non volevamo credere
# non volevamo crepare ma è successo tutto a un tratto
# dio porco
# 92 minuti di applausi
# [Musica]
# [Applauso]
# [Musica]
# amo l'alba perché come fosse solo mia
# [pernacchia]
# amo l'alba perché come fosse solo mia
# amo l'alba perché come fosse solo mia
# e ti
# avvicini
# la pasta non ha limiti
# [rumore flatulenza]
# [Applauso]
# [Musica]
# troppo col colore marrone
# [Applauso]
# [Musica]
# puoi capirla Se la senti e non mandarla via
# ho paura di rosario muniz
# aah oddio
# sos lul dio cane
# aia
# non volevamo crescere
# uccidetemi per favore
# ti piace l'ace
# ti piace che sono stupido
# e metto i piedi nell'acido così si sciolgono
# e adesso limoniamo
# [Musica]
# [Musica]
# [Musica]
# [Musica]
#
# Parole inappropriate rilevate: cazzi
# Etichetta originale: 0, Nuova etichetta: 2
# --------------------------------------------------------------------------------
# Titolo: YTP_011.txt
# Testo originale: [Musica]
# c'è qualcosa che luccica in mezzo
# all'acqua
# Montale?
# aiuto Qua ci sono due grossi cazzi Rosa
# che mi vogliono scopare Siamo due grandi
# Monelli Peppa vuole battere il culo di nonno pig
# se si avvicina una conchiglia
# all'orecchio si sente il rumore di rondo
# [Musica]
# sono riuscita a sentirlo
# È la prima volta che quel coglione di
# George va in piscina Perché non provi a
# bagnare un solo piede
# [urla]
# appoggiati a questo cazzo potrai
# esercitarti a sbattere le palle
# George vuoi provare anche tu?
# siete bravissimi ma Cercate di non
# schizzare
# buongiorno Mi scusi Ha visto la regina
# per caso? la regina è una vecchia
# bastarda che porta una coca-cola sulla
# testa
# sono io la regina
# la signorina coniglio è morta
# Ecco la macchina a raggi ani
# Guarda quella è la mia
# Cazzi George
# decolla
# aereoplano
# [rumore di schianto]
# [Musica]
# a George piacciono gli aeroplanini
# È proprio vero
# [Applauso]
# [Musica]
# [Applauso]
# sta scherzando le onde sono perfette per
# gli adulti che vogliono scopare
# fantastico
# allora
# [Musica]
# le canne sono il mio passatempo
# preferito anche per me
# [rumore di un'esplosione]
# Siamo bloccati su un'isola deserta e per
# di più non abbiamo niente da mangiare
# [rumore di flatulenza]
# Io ho fatto la cacca
# Bene allora dobbiamo conservarla nell'eventualità
# che ci venga fame più tardi
# [Musica]
#
# Parole inappropriate rilevate: cazzi
# Etichetta originale: 0, Nuova etichetta: 2
# --------------------------------------------------------------------------------
# Titolo: YTP_001.txt
# Testo originale: siete pronti per cominciare possiamo
# cominciare babbo natale non è ancora
# arrivato ha detto che purtroppo era
# molto impegnato
# no davvero?
# ma guarda ci sono i vostri genitori
# [spari]
# io sono troppo beee
# io sono l'infermiera e devo controllare se tu stai bene
# [conati di vomito]
# tutto a posto ora puoi andare
# [applausi]
# bravi stronzetti
# babbo natale, sei venuto a vedere la recita
# l'ho detestata
# è vero che vai in giro per tutto il mondo la notte di
# natale
# [rumore di flatulenza]
# come fai a farlo?
# certo
# è una slitta di merda
# com'è andarci sopra?
# stiamo volando, tenetevi forte adesso facciamo qualche acrobazia
# [urla]
# auguro a tutti voi un buon natale
# questo qui è il tuo regalo
# io ho ricevuto cazzi
# cazzi?
# cazzi?
# [risate]
# ho chiesto una bambola ti cammina che
# parla e che può perfino chiudere gli
# occhi quando la metti a dormire
# gli amici di peppa giocano con le
# loro slitte
# [Musica]
# o no george scemo
# checca
# peppa se la cava molto bene
# [Musica]
# non riesco a fermarmi, attenzione
# [Musica]
# Peppa e George si divertono moltissimo
# Peppa e George fanno un cazzo di neve
# ma fuori dalla finestra sta volando
# qualcosa
# e questo rumore cos'è
# ma chi è quella che fa quel rumore lì?
# ma porca puttana perché li costruiscono
# tanto strettini i cammini
# George hai visto è arrivato babbo natale
# [rumore di eruttazione]
# con chi ho l'onore di parlare?
# io sono George
# Chi è questo giovanotto?
# Peppa
# e questi sono i regali per george e per
# me?
# no
# oh
# susy vuole un monio garda, Danny una
# navicella assiale, Ben un achipattino, emily...
# [rumore di un pugno]
# [musica]
#
# Parole inappropriate rilevate: cazzi
# Etichetta originale: 0, Nuova etichetta: 2
# --------------------------------------------------------------------------------
# Titolo: YTP_016.txt
# Testo originale: [Musica]
# [Musica]
# [Musica]
# finalmente pace interiore
# succede chiudi che la porta di per
# favore va la porta via la giustizia sta
# per essere servizio di cipolle ti
# aspetto il portiere del cazzo di kudrin
# [Musica]
# quello non è volare
# due case giustizia per favore 330
# ragazzi non sottovalutarsi non
# sottovalutate ma il potere della cricca
# ne ho saputo di maestri che vincono un
# combattimento solo con l'apertura del
# mentore in avanti l'addestramento sarà
# nelle mani del guerriero r'o lione il
# tuo primo giorno di insegnamento
# umiliante l'ho saputo che al ha detto è
# stata tigre
# l'ho saputo che al ha detto è stata
# quella stanza di dire l'ho saputo da
# asciutto
# l'ho saputo da shawn michaels jakes
# degli articolo 31 e me l'ha detto tigre
# tu non sai nemmeno chi sei che vuole
# certo che lo so io sono il guerriero
# clone e questo esattamente cosa
# significa guerriero cojone significa
# ecco andare in giro e pisciare sfogare
# succhiare legale
# wow
# cosa è stato quello era il c o cos'è
# l'energia oscure volte le cose ti va
# sono pronto a dai a darci una lezione
# lezione o no ed insegnante gruppone si è
# così deficiente grazie per il
# complimento
# nel momento dai sto bene sto bene
# cazzo lungo figliolo dove lo pronto e
# vengo a prenderti fatti sogno maestro
# rino bravo così a che serve questo
# dovrei tirarlo credo di aver fatto la
# pipì
# ciao bbc belli ma il suo passo con la
# tecnica non più cazzo spiaccicate
# [Musica]
# nole ne sono perché fai così che cosa
# solo perchè dici ali di prima di
# qualcosa non vuol dire che fai qualcosa
# come segnali jesi martin e delle dette
# torace nel fare i bottini ali di là di
# nina fiera
# maestro shifu ci ha portati consigliano
# provera massimo
# povero musulmani
# [Musica]
# [Applauso]
# o
# bravo così ci sono parte muriella sotto
# l'incrocio
# e l'ora del pranzo deve essere la
# collina dirti bove rotolare errore da
# pisellino aver sferrato
# sto bene solo
# come osi mettere piede in questo luogo
# guardatevi patetici stronzi striscione
# oh sì
# strizzate chi come oggi sia due case
# giustizia per favore come si fa col c gc
# c gc c gc c
# va bene non so se sono un guerriero che
# unione non so nemmeno se sono un pack
# possiamo imparare il kung fu possiamo
# essere come te che cosa hai detto
# possiamo farcela no possiamo imparare
# con furnò possiamo essere come te no io
# bestia da soma il mini a toma i mini
# ogni mia mossa dai testi a da soma in
# miniatura gli orchi sono come le palle
# fine della storia
# quasi magici vediamo tu devi essere il
# guerriero tampone e tu devi essere cai e
# sti cazzi se ho messo 500 anni per
# prendermi il sito avrò il tuo anche se
# mi ci vorranno altri 500 anni per
# prendermi il cinquecento anni per
# prendermi il sì
# [Musica]
# no
# vuoi volare
# no
#
# Parole inappropriate rilevate: cazzi
# Etichetta originale: 0, Nuova etichetta: 2
# --------------------------------------------------------------------------------

# %%
# Ricarica il file delle bad words
bad_words_path = '/content/drive/My Drive/badwords_ita.txt'

try:
    with open(bad_words_path, 'r', encoding='utf-8') as file:
        bad_words = set(line.strip() for line in file)
        print(f"Bad words caricate correttamente: {len(bad_words)} parole.")
except Exception as e:
    print(f"Error loading bad words: {e}")
    bad_words = set()  # Definisci un set vuoto in caso di errore per evitare crash
# Out:
# Error loading bad words: [Errno 2] No such file or directory: '/content/drive/My Drive/badwords_ita.txt'
